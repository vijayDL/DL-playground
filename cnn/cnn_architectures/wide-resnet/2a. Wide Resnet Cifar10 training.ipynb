# %% [markdown]
# # Wide Residual network using tensorflow
#
# paper: https://arxiv.org/pdf/1605.07146.pdf
# ________________________________
# > Classification of Cifar 10 dataset.
#
# > **The model that will be attempted is wide-dropout :**
#
# <img src='w-resnet.png'>

# %%
# load the necessary
import matplotlib.pylab as plt
# %matplotlib inline
import os
import numpy as np
import math as m
import sys
print('Python version:',sys.version)
import tensorflow as tf
print('TF version:',tf.__version__)
from data_utils import input_pipeline
slim = tf.contrib.slim
from tensorflow.contrib.layers.python.layers import initializers
from colorama import Fore, Style
from datetime import datetime
import time
import glob
# Out:
# Python version: 3.5.2 (default, Nov 23 2017, 16:37:01)
# [GCC 5.4.0 20160609]
# TF version: 1.8.0

# %% [markdown]
# ## Model definition

# %%
# Define the conv function
KEEP_PROB = 1.
WEIGHT_DECAY = 0.0005
def resnet_block(input_layer, out_features, training=True, scope=None):
    
    with tf.variable_scope(scope):
        
        with slim.arg_scope([slim.batch_norm],
                            is_training = training, scale=True,
                            decay=0.9, epsilon=1e-5,updates_collections=None,
                            param_initializers={
                                "beta": tf.constant_initializer(value=0),
                                "gamma": tf.random_normal_initializer(mean=1., stddev=0.01)}):

            # 1st Conv 3x3

            # batch norm        
            net = slim.batch_norm(input_layer)
            # Relu
            net = tf.nn.relu(net)
            #convolution
            net = slim.conv2d(net, out_features)
            #dropout
            net = slim.dropout(net,keep_prob=KEEP_PROB,is_training=training)

            # 2nd Conv 3x3
            # batch norm
            net = slim.batch_norm(net)
            # Relu
            net = tf.nn.relu(net)
            #convolution
            net = slim.conv2d(net, out_features)

            #concat with the input                    
            net += input_layer
    
    return net

def wide_resnet(inputs,
                num_classes=10,
                is_training=True,
                k = 6,
                depth = 22,
                scope='wide_resnet'):
    
    # number of filters at various stages
    filters = [16, 16*k, 32*k, 64*k]
    # from their code https://github.com/szagoruyko/wide-residual-networks/blob/master/models/wide-resnet.lua
    assert (depth - 4) % 6 == 0, 'depth should be 6n+4'
    n = int((depth - 4) / 6)
    
    # Set the weights to a small value initially and check whether the output is ln(num_of_classes) = ln(10) ~2.3
    #weights_initializer = tf.random_uniform_initializer(0,0.001)
    
    # He et all uniform weights
    #weights_initializer=tf.contrib.layers.variance_scaling_initializer(factor=2.0, 
    #                                       mode='FAN_IN', uniform=True)):
            
    with tf.variable_scope(scope, reuse=None):
        with tf.contrib.framework.arg_scope([slim.conv2d], 
                                             normalizer_fn=None,
                                             activation_fn=None,
                                             padding='SAME',
                                             kernel_size=(3,3),
                                             weights_initializer=initializers.variance_scaling_initializer(),
                                             weights_regularizer=slim.l2_regularizer(WEIGHT_DECAY),
                                             biases_initializer=None):


            #one conv at the beginning (spatial size: 32x32)
            net = slim.conv2d(inputs, filters[0], stride=(1,1), scope='first_conv' )
            # batch norm        
            net = slim.batch_norm(net, is_training =is_training, scale=True, updates_collections=None)
            # Relu
            net = tf.nn.relu(net)

            #block 1 -- Stage 1 (spatial size: 32x32)
            net = slim.conv2d(net,filters[1], stride=1)
            net = slim.repeat(net,n-1, resnet_block, filters[1], training=is_training, scope='block_1')
            print('block1:',net.get_shape().as_list())

            #block 2 -- Stage 2 (spatial size: 16x16)
            net = slim.conv2d(net,filters[2], stride=2)
            net = slim.repeat(net,n-1, resnet_block, filters[2], training=is_training, scope='block_2')
            print('block2:',net.get_shape().as_list())

            #block 3 -- Stage 3 (spatial size: 8x8)
            net = slim.conv2d(net,filters[3], stride=2)
            net = slim.repeat(net,n-1, resnet_block, filters[3], training=is_training, scope='block_3')
            print('block3:',net.get_shape().as_list())

            #average pooling 8x8
            net = slim.avg_pool2d(net, kernel_size=[8,8],padding='SAME',scope='avg_pool')

            # batch norm        
            net = slim.batch_norm(net, is_training =is_training, scale=True, updates_collections=None)
            # Relu
            net = tf.nn.relu(net)
            
            #flatten
            net = slim.flatten(net, scope='flatten')

            #logits
            net = slim.fully_connected(net, num_classes, activation_fn=None, scope='logits', 
                                       biases_regularizer=slim.l2_regularizer(WEIGHT_DECAY))

            return net

# %%
#checking the above graph
tf.reset_default_graph()
net = wide_resnet(tf.placeholder(tf.float32,(None, 32, 32, 3)),num_classes=10, is_training=True)
print('Variables in graph:')
for var in tf.global_variables():
    print(var.name)
# Out:
# block1: [None, 32, 32, 96]
# block2: [None, 16, 16, 192]
# block3: [None, 8, 8, 384]
# Variables in graph:
# wide_resnet/first_conv/weights:0
# wide_resnet/BatchNorm/beta:0
# wide_resnet/BatchNorm/gamma:0
# wide_resnet/BatchNorm/moving_mean:0
# wide_resnet/BatchNorm/moving_variance:0
# wide_resnet/Conv/weights:0
# wide_resnet/block_1/block_1_1/BatchNorm/beta:0
# wide_resnet/block_1/block_1_1/BatchNorm/gamma:0
# wide_resnet/block_1/block_1_1/BatchNorm/moving_mean:0
# wide_resnet/block_1/block_1_1/BatchNorm/moving_variance:0
# wide_resnet/block_1/block_1_1/Conv/weights:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/beta:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/gamma:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_1/block_1_1/Conv_1/weights:0
# wide_resnet/block_1/block_1_2/BatchNorm/beta:0
# wide_resnet/block_1/block_1_2/BatchNorm/gamma:0
# wide_resnet/block_1/block_1_2/BatchNorm/moving_mean:0
# wide_resnet/block_1/block_1_2/BatchNorm/moving_variance:0
# wide_resnet/block_1/block_1_2/Conv/weights:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/beta:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/gamma:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_1/block_1_2/Conv_1/weights:0
# wide_resnet/Conv_1/weights:0
# wide_resnet/block_2/block_2_1/BatchNorm/beta:0
# wide_resnet/block_2/block_2_1/BatchNorm/gamma:0
# wide_resnet/block_2/block_2_1/BatchNorm/moving_mean:0
# wide_resnet/block_2/block_2_1/BatchNorm/moving_variance:0
# wide_resnet/block_2/block_2_1/Conv/weights:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/beta:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/gamma:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_2/block_2_1/Conv_1/weights:0
# wide_resnet/block_2/block_2_2/BatchNorm/beta:0
# wide_resnet/block_2/block_2_2/BatchNorm/gamma:0
# wide_resnet/block_2/block_2_2/BatchNorm/moving_mean:0
# wide_resnet/block_2/block_2_2/BatchNorm/moving_variance:0
# wide_resnet/block_2/block_2_2/Conv/weights:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/beta:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/gamma:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_2/block_2_2/Conv_1/weights:0
# wide_resnet/Conv_2/weights:0
# wide_resnet/block_3/block_3_1/BatchNorm/beta:0
# wide_resnet/block_3/block_3_1/BatchNorm/gamma:0
# wide_resnet/block_3/block_3_1/BatchNorm/moving_mean:0
# wide_resnet/block_3/block_3_1/BatchNorm/moving_variance:0
# wide_resnet/block_3/block_3_1/Conv/weights:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/beta:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/gamma:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_3/block_3_1/Conv_1/weights:0
# wide_resnet/block_3/block_3_2/BatchNorm/beta:0
# wide_resnet/block_3/block_3_2/BatchNorm/gamma:0
# wide_resnet/block_3/block_3_2/BatchNorm/moving_mean:0
# wide_resnet/block_3/block_3_2/BatchNorm/moving_variance:0
# wide_resnet/block_3/block_3_2/Conv/weights:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/beta:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/gamma:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_3/block_3_2/Conv_1/weights:0
# wide_resnet/BatchNorm_1/beta:0
# wide_resnet/BatchNorm_1/gamma:0
# wide_resnet/BatchNorm_1/moving_mean:0
# wide_resnet/BatchNorm_1/moving_variance:0
# wide_resnet/logits/weights:0
# wide_resnet/logits/biases:0

# %% [markdown]
# ## Create the graph and run it in a session
# > The input pipelines for both train and validation can be dynamically switched.

# %%
#Create the graph
N_EPOCH = 200
NUM_CLASSES = 10
BATCH_SIZE = 128
LEARNING_RATE = 0.1 #3e-4 
WIDTH = 32
HEIGHT = 32
LOG_FREQ = 250
N_TRAIN_SAMPLES = 50000
CIFAR_LOCAL_FOLDER = '/home/vijay/datasets/image/cifar-10/cifar-10-batches-py'
MODEL_DIR = './slim_model/'

tf.reset_default_graph()

train_graph = tf.Graph()
with train_graph.as_default():
    global_step = tf.train.get_or_create_global_step()
    
    #-------------------------------------------
    #1. Create valid and train iterators
    #-------------------------------------------

    # placeholder for passing testing dataset
    test_filenames = tf.placeholder(tf.string, shape=[None], name='input')
    train_filenames = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'train*.tfrecords')))
    
    # Create valid and train iterators
    train_dataset = input_pipeline(train_filenames, BATCH_SIZE)
    test_dataset = input_pipeline(test_filenames, BATCH_SIZE*3,  validation=True)
    
    # A feedable iterator is defined by a handle placeholder and its structure.
    handle = tf.placeholder(tf.string, shape=[], name='handle')

    iterator = tf.data.Iterator.from_string_handle(handle, 
                                                   train_dataset.output_types, 
                                                   train_dataset.output_shapes)
    
    # Returns a batch of image and mask at every call
    image_batch, label_batch = iterator.get_next()
    
    image_batch = tf.identity(image_batch, 'images')
    label_batch = tf.identity(label_batch, 'labels')
    
    # Create a initializable iterator for valid dataset, 
    # so that the dataset is same for every valid loop.
    testing_iterator = test_dataset.make_initializable_iterator()
    training_iterator = train_dataset.make_initializable_iterator() #make_one_shot_iterator()
    
    
    # EDIT : the below not working for inference -https://github.com/tensorflow/tensorflow/issues/11679
    # Build the iterator SaveableObject.
    #saveable = tf.contrib.data.make_saveable_from_iterator(testing_iterator)

    # Save the iterator state by adding it to the saveable objects collection.
    #tf.add_to_collection(tf.GraphKeys.SAVEABLE_OBJECTS, saveable)
    
    #------------------------------------------------
    # 2. load Wide-resnet to the graph
    #------------------------------------------------
    
    # Placeholder definitions to handle incase of testing individual images
    X = tf.placeholder_with_default(image_batch, shape=[None,HEIGHT,WIDTH,3], name='X')
    y = tf.placeholder_with_default(label_batch, shape=[None], name='y')
    
    # A bool to switch between training loop and testing loop
    is_train = tf.placeholder(dtype=tf.bool, name='is_train')
    
    #wide-resnet logits
    logits = wide_resnet(X, num_classes=10, is_training=is_train)
    
    #------------------------------------------------
    # 3. Loss and accuracy
    #------------------------------------------------
        
    loss = tf.losses.softmax_cross_entropy(onehot_labels=tf.one_hot(y,NUM_CLASSES), logits=logits)
    
    #add regularization loss
    regularization_loss = tf.add_n(tf.losses.get_regularization_losses())
    loss += regularization_loss
        
    learning_rate = tf.placeholder(dtype=tf.float32, name='learning_rate')
    
    # use Momentum optimizer    
    solver = tf.train.MomentumOptimizer(learning_rate, 0.9, use_nesterov=True)

    # create the train op
    train_op = slim.learning.create_train_op(loss, solver, global_step=global_step)
    
    # Probabilities of the outputs
    prob = tf.nn.softmax(logits, name='prob')
    
    # Prediction 
    pred = tf.argmax(prob, 1, name='pred')

    #accuracy create two different ops
    with tf.name_scope('train_metrics'):
        train_acc_op, train_accuracy = tf.metrics.accuracy(labels=tf.cast(y, tf.int32), predictions=tf.cast(pred, tf.int32))
    
    with tf.name_scope('test_metrics'):
        test_acc_op, test_accuracy = tf.metrics.accuracy(labels=tf.cast(y, tf.int32), predictions=tf.cast(pred, tf.int32))
    
    # Select accuracy for saving
    accuracy = tf.cond(is_train, lambda:train_accuracy, lambda:test_accuracy)
    accuracy = tf.identity(accuracy,name='accuracy')
    
    # Create summaries
    tf.summary.scalar('loss', loss)
    tf.summary.scalar('accuracy', accuracy)    
    tf.summary.scalar('learning_rate', learning_rate)
    my_summary_op = tf.summary.merge_all()
# Out:
# block1: [None, 32, 32, 96]
# block2: [None, 16, 16, 192]
# block3: [None, 8, 8, 384]

# %%
# Run the graph in the session

def testing_loop(_handle, file_names, writer, test=False):
    """ Testing/validation loop between trainings"""
    # do validation at each epoch
    _loss = 0.
    count = 0
    # Reset the iterator at every valid call, to go through the validation set
    sess.run(testing_iterator.initializer, {test_filenames: file_names})

    while True:
        try:
            _summaries, _l, _acc, _,_pred, _label = sess.run([my_summary_op, loss,test_accuracy, test_acc_op, pred, y], 
                                               {learning_rate:LEARNING_RATE, is_train:False, handle:_handle})  
            count += len(_label)
            _loss += _l*len(_label)
        except tf.errors.OutOfRangeError:
            break

    _loss = _loss/count
    
    if test:
        tf.logging.info(Fore.CYAN + Style.BRIGHT +'Step:{}: Test Loss:{:.5f}: Test Accuracy:{:.5f}'  
                .format(step,_loss, _acc)+Fore.RESET+Style.RESET_ALL)  
    else:
        tf.logging.info(Fore.GREEN + Style.BRIGHT +'Step:{}: Valid Loss:{:.5f}:Valid Accuracy:{:.5f}'  
                .format(step,_loss, _acc)+Fore.RESET+Style.RESET_ALL)  

    #write validation summaries
    writer.add_summary(_summaries, step)
    return _loss

with tf.Session(graph=train_graph) as sess:
    sess.run([tf.global_variables_initializer(), tf.local_variables_initializer()])
    # The `Iterator.string_handle()` method returns a tensor that can be evaluated
    # and used to feed the `handle` placeholder.
    valid_files = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'valid*.tfrecords')))
    test_files = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'eval*.tfrecords')))
    train_handle = sess.run(training_iterator.string_handle())
    valid_handle = sess.run(testing_iterator.string_handle(), {test_filenames: valid_files})
    test_handle = sess.run(testing_iterator.string_handle(), {test_filenames: test_files})
    
    # variables for early exit
    best_v_loss = 10e10
    early_stopping = 0
    saver = tf.train.Saver()
    start_time = time.time()

    # Get the test/valid metrics variables to reset at each call
    stream_vars_test = [v for v in tf.local_variables() if 'test_metrics/' in v.name]
    # Get the train metrics variables to reset at each epoch
    stream_vars_train = [v for v in tf.local_variables() if 'train_metrics/' in v.name]

    #Summaries for validation and training
    summaries_dir = os.path.join(MODEL_DIR,'summaries')
    train_writer = tf.summary.FileWriter(summaries_dir + '/train', sess.graph)
    train_writer.flush()
    valid_writer = tf.summary.FileWriter(summaries_dir + '/valid', sess.graph)
    valid_writer.flush()
    test_writer = tf.summary.FileWriter(summaries_dir + '/test', sess.graph)
    test_writer.flush()

    lr = LEARNING_RATE    
    for e in range(N_EPOCH):
        
        # Learning rate changes
        if e > 60 and e <= 120:
            lr = 0.02
        elif e > 120 and e <= 160:
            lr = 0.004
        elif e > 160 :
            lr = 0.0008
        
        tf.logging.info(Fore.RED+ Style.BRIGHT +'Epoch:{}'.format(e)+Fore.RESET+Style.RESET_ALL)
        # initialize the training iterator at every epoch
        sess.run(training_iterator.initializer)              
        while True:

            try:
                # The train images are passed
                _, l, _, step = sess.run([train_op, loss, train_acc_op, global_step], {learning_rate:lr, is_train:True,handle:train_handle})  

                #print train logs
                if (step %LOG_FREQ) == 0:
                    train_summaries,acc, l, reg_loss = sess.run([my_summary_op, train_accuracy, loss,regularization_loss], 
                                                                {learning_rate:lr,is_train:True,handle:train_handle})  
                    #Print train logs
                    tf.logging.info(Fore.BLUE + Style.BRIGHT +'Step:{} Time:{:.5f} Reg Loss:{:.5f} Train Loss:{:.5f}: Accuracy:{:.5f}' 
                                    .format(step,time.time()-start_time,reg_loss,l,acc)+Fore.RESET+Style.RESET_ALL)
                    #train_pred, train_label = sess.run([pred, y], {is_train:True, handle:train_handle} )
                    start_time = time.time()

                    # write train summaries
                    train_writer.add_summary(train_summaries, step)


            except tf.errors.OutOfRangeError:
                break
        
        # do validation at each epoch
        valid_loss = testing_loop(valid_handle, valid_files, valid_writer)
                
        # reset train and validation statistics every epoch
        sess.run(tf.variables_initializer(stream_vars_train))
        sess.run(tf.variables_initializer(stream_vars_test))

        # Save the best model based on valid loss and test the model on the testing set
        if (best_v_loss > valid_loss) and (step > 0):
            tf.logging.info(Fore.RED+ Style.BRIGHT +'Saving the model...'+Fore.RESET+Style.RESET_ALL)
            saver.save(sess, os.path.join(MODEL_DIR, 'wide_resnet'))
            best_v_loss = valid_loss
            early_stopping = 0
            
            # test when the validation set has a new minimum loss 
            
            testing_loop(test_handle, test_files, test_writer, test=True)
       
            #reset test statistics
            sess.run(tf.variables_initializer(stream_vars_test))

        
        else:
            early_stopping += 1


        #if early_stopping > 3:
        #    tf.logging.info(Fore.RED+ Style.BRIGHT +'Stopping the training...'+Fore.RESET+Style.RESET_ALL)
        #    break
    #One final testing    
    testing_loop(test_handle, test_files, test_writer, test=True)
# Out:
# INFO:tensorflow:Epoch:0
# INFO:tensorflow:Step:0 Time:5.24136 Reg Loss:1.69910 Train Loss:21.68912: Accuracy:0.11719
# INFO:tensorflow:Step:250 Time:22.45802 Reg Loss:1.91426 Train Loss:3.90737: Accuracy:0.19531
# INFO:tensorflow:Step:500 Time:22.56979 Reg Loss:1.49333 Train Loss:3.42177: Accuracy:0.22396
# INFO:tensorflow:Step:621: Valid Loss:3.29116:Valid Accuracy:0.23315
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:621: Test Loss:3.28660: Test Accuracy:0.23870
# INFO:tensorflow:Epoch:1
# INFO:tensorflow:Step:750 Time:28.87526 Reg Loss:1.16951 Train Loss:2.98130: Accuracy:0.23904
# INFO:tensorflow:Step:1000 Time:22.55122 Reg Loss:0.91625 Train Loss:2.72598: Accuracy:0.23957
# INFO:tensorflow:Step:1244: Valid Loss:2.66959:Valid Accuracy:0.25907
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:1244: Test Loss:2.67048: Test Accuracy:0.25880
# INFO:tensorflow:Epoch:2
# INFO:tensorflow:Step:1250 Time:28.32624 Reg Loss:0.71814 Train Loss:2.47673: Accuracy:0.25908
# INFO:tensorflow:Step:1500 Time:22.56606 Reg Loss:0.56826 Train Loss:2.36495: Accuracy:0.26053
# INFO:tensorflow:Step:1750 Time:22.63688 Reg Loss:0.45046 Train Loss:2.30681: Accuracy:0.26136
# INFO:tensorflow:Step:1866: Valid Loss:2.48692:Valid Accuracy:0.26628
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:1866: Test Loss:2.49052: Test Accuracy:0.26030
# INFO:tensorflow:Epoch:3
# INFO:tensorflow:Step:2000 Time:28.34671 Reg Loss:0.36300 Train Loss:1.97497: Accuracy:0.26264
# INFO:tensorflow:Step:2250 Time:22.62459 Reg Loss:0.29494 Train Loss:2.03711: Accuracy:0.26414
# INFO:tensorflow:Step:2489: Valid Loss:2.41151:Valid Accuracy:0.14304
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:2489: Test Loss:2.41527: Test Accuracy:0.13100
# INFO:tensorflow:Epoch:4
# INFO:tensorflow:Step:2500 Time:28.40848 Reg Loss:0.24277 Train Loss:1.60527: Accuracy:0.13527
# INFO:tensorflow:Step:2750 Time:22.91355 Reg Loss:0.20887 Train Loss:1.47529: Accuracy:0.14080
# INFO:tensorflow:Step:3000 Time:22.62955 Reg Loss:0.18250 Train Loss:1.70027: Accuracy:0.14436
# INFO:tensorflow:Step:3111: Valid Loss:2.39414:Valid Accuracy:0.20358
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:3111: Test Loss:2.39582: Test Accuracy:0.19190
# INFO:tensorflow:Epoch:5
# INFO:tensorflow:Step:3250 Time:28.33451 Reg Loss:0.16646 Train Loss:1.49703: Accuracy:0.19639
# INFO:tensorflow:Step:3500 Time:22.65037 Reg Loss:0.15533 Train Loss:1.43321: Accuracy:0.19979
# INFO:tensorflow:Step:3734: Valid Loss:2.26465:Valid Accuracy:0.19072
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:3734: Test Loss:2.26372: Test Accuracy:0.18600
# INFO:tensorflow:Epoch:6
# INFO:tensorflow:Step:3750 Time:28.38372 Reg Loss:0.14866 Train Loss:1.11809: Accuracy:0.19224
# INFO:tensorflow:Step:4000 Time:22.63742 Reg Loss:0.14539 Train Loss:1.29574: Accuracy:0.19725
# INFO:tensorflow:Step:4250 Time:22.62717 Reg Loss:0.14415 Train Loss:1.37821: Accuracy:0.20146
# INFO:tensorflow:Step:4356: Valid Loss:2.27326:Valid Accuracy:0.15351
# INFO:tensorflow:Epoch:7
# INFO:tensorflow:Step:4500 Time:26.22799 Reg Loss:0.14358 Train Loss:1.20880: Accuracy:0.62500
# INFO:tensorflow:Step:4750 Time:22.62710 Reg Loss:0.14522 Train Loss:1.34391: Accuracy:0.59766
# INFO:tensorflow:Step:4979: Valid Loss:2.22760:Valid Accuracy:0.20583
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:4979: Test Loss:2.23458: Test Accuracy:0.19090
# INFO:tensorflow:Epoch:8
# INFO:tensorflow:Step:5000 Time:28.39638 Reg Loss:0.14820 Train Loss:0.76660: Accuracy:0.19866
# INFO:tensorflow:Step:5250 Time:22.66749 Reg Loss:0.15017 Train Loss:1.42442: Accuracy:0.20339
# INFO:tensorflow:Step:5500 Time:22.63120 Reg Loss:0.15466 Train Loss:1.45214: Accuracy:0.20763
# INFO:tensorflow:Step:5601: Valid Loss:2.08482:Valid Accuracy:0.33099
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:5601: Test Loss:2.08714: Test Accuracy:0.31530
# INFO:tensorflow:Epoch:9
# INFO:tensorflow:Step:5750 Time:29.43844 Reg Loss:0.15884 Train Loss:1.10575: Accuracy:0.32000
# INFO:tensorflow:Step:6000 Time:22.74683 Reg Loss:0.16357 Train Loss:1.20764: Accuracy:0.32362
# INFO:tensorflow:Step:6224: Valid Loss:2.02726:Valid Accuracy:0.29290
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:6224: Test Loss:2.03154: Test Accuracy:0.28120
# INFO:tensorflow:Epoch:10
# INFO:tensorflow:Step:6250 Time:28.48574 Reg Loss:0.16812 Train Loss:0.85474: Accuracy:0.28683
# INFO:tensorflow:Step:6500 Time:22.67927 Reg Loss:0.17238 Train Loss:1.21164: Accuracy:0.29134
# INFO:tensorflow:Step:6750 Time:22.70535 Reg Loss:0.17798 Train Loss:1.40240: Accuracy:0.29459
# INFO:tensorflow:Step:6846: Valid Loss:1.96301:Valid Accuracy:0.41188
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:6846: Test Loss:1.96463: Test Accuracy:0.39620
# INFO:tensorflow:Epoch:11
# INFO:tensorflow:Step:7000 Time:28.47881 Reg Loss:0.18058 Train Loss:0.75904: Accuracy:0.40156
# INFO:tensorflow:Step:7250 Time:22.72511 Reg Loss:0.18768 Train Loss:1.35855: Accuracy:0.40376
# INFO:tensorflow:Step:7469: Valid Loss:1.90741:Valid Accuracy:0.34438
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:7469: Test Loss:1.91120: Test Accuracy:0.33960
# INFO:tensorflow:Epoch:12
# INFO:tensorflow:Step:7500 Time:28.50446 Reg Loss:0.19053 Train Loss:0.63734: Accuracy:0.34627
# INFO:tensorflow:Step:7750 Time:22.68774 Reg Loss:0.19320 Train Loss:1.12884: Accuracy:0.35023
# INFO:tensorflow:Step:8000 Time:22.72539 Reg Loss:0.19854 Train Loss:1.32545: Accuracy:0.35295
# INFO:tensorflow:Step:8091: Valid Loss:1.62294:Valid Accuracy:0.48286
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:8091: Test Loss:1.63662: Test Accuracy:0.46850
# INFO:tensorflow:Epoch:13
# INFO:tensorflow:Step:8250 Time:28.46529 Reg Loss:0.20083 Train Loss:0.89554: Accuracy:0.47186
# INFO:tensorflow:Step:8500 Time:22.69945 Reg Loss:0.20655 Train Loss:1.21553: Accuracy:0.47358
# INFO:tensorflow:Step:8714: Valid Loss:1.52417:Valid Accuracy:0.52057
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:8714: Test Loss:1.53153: Test Accuracy:0.51410
# INFO:tensorflow:Epoch:14
# INFO:tensorflow:Step:8750 Time:28.54010 Reg Loss:0.21059 Train Loss:0.78926: Accuracy:0.51817
# INFO:tensorflow:Step:9000 Time:22.70428 Reg Loss:0.21450 Train Loss:0.99484: Accuracy:0.52135
# INFO:tensorflow:Step:9250 Time:22.72150 Reg Loss:0.21995 Train Loss:1.35700: Accuracy:0.52292
# INFO:tensorflow:Step:9336: Valid Loss:1.25510:Valid Accuracy:0.64282
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:9336: Test Loss:1.26876: Test Accuracy:0.63400
# INFO:tensorflow:Epoch:15
# INFO:tensorflow:Step:9500 Time:28.48169 Reg Loss:0.22137 Train Loss:0.74805: Accuracy:0.63626
# INFO:tensorflow:Step:9750 Time:22.71223 Reg Loss:0.22710 Train Loss:1.21663: Accuracy:0.63641
# INFO:tensorflow:Step:9959: Valid Loss:1.48144:Valid Accuracy:0.54368
# INFO:tensorflow:Epoch:16
# INFO:tensorflow:Step:10000 Time:26.32023 Reg Loss:0.23060 Train Loss:0.71753: Accuracy:0.85156
# INFO:tensorflow:Step:10250 Time:22.69041 Reg Loss:0.23531 Train Loss:1.21822: Accuracy:0.76562
# INFO:tensorflow:Step:10500 Time:22.69992 Reg Loss:0.23948 Train Loss:1.18226: Accuracy:0.74479
# INFO:tensorflow:Step:10581: Valid Loss:1.10738:Valid Accuracy:0.70830
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:10581: Test Loss:1.12680: Test Accuracy:0.70250
# INFO:tensorflow:Epoch:17
# INFO:tensorflow:Step:10750 Time:28.50953 Reg Loss:0.23915 Train Loss:0.79890: Accuracy:0.70389
# INFO:tensorflow:Step:11000 Time:22.72378 Reg Loss:0.24511 Train Loss:1.36133: Accuracy:0.70252
# INFO:tensorflow:Step:11204: Valid Loss:1.29438:Valid Accuracy:0.62646
# INFO:tensorflow:Epoch:18
# INFO:tensorflow:Step:11250 Time:26.33625 Reg Loss:0.24941 Train Loss:0.78431: Accuracy:0.80469
# INFO:tensorflow:Step:11500 Time:22.70111 Reg Loss:0.25121 Train Loss:1.03755: Accuracy:0.77344
# INFO:tensorflow:Step:11750 Time:22.69659 Reg Loss:0.25657 Train Loss:1.36256: Accuracy:0.72135
# INFO:tensorflow:Step:11826: Valid Loss:1.13919:Valid Accuracy:0.70483
# INFO:tensorflow:Epoch:19
# INFO:tensorflow:Step:12000 Time:26.26282 Reg Loss:0.25634 Train Loss:0.65269: Accuracy:0.85938
# INFO:tensorflow:Step:12250 Time:22.69360 Reg Loss:0.26262 Train Loss:1.18791: Accuracy:0.77734
# INFO:tensorflow:Step:12449: Valid Loss:1.30781:Valid Accuracy:0.65396
# INFO:tensorflow:Epoch:20
# INFO:tensorflow:Step:12500 Time:26.29432 Reg Loss:0.26584 Train Loss:0.72397: Accuracy:0.86719
# INFO:tensorflow:Step:12750 Time:22.71779 Reg Loss:0.26830 Train Loss:0.97715: Accuracy:0.81250
# INFO:tensorflow:Step:13000 Time:22.69930 Reg Loss:0.27323 Train Loss:0.92684: Accuracy:0.79427
# INFO:tensorflow:Step:13071: Valid Loss:1.38130:Valid Accuracy:0.64050
# INFO:tensorflow:Epoch:21
# INFO:tensorflow:Step:13250 Time:26.25348 Reg Loss:0.27213 Train Loss:0.91097: Accuracy:0.80469
# INFO:tensorflow:Step:13500 Time:22.72539 Reg Loss:0.27767 Train Loss:1.08077: Accuracy:0.77344
# INFO:tensorflow:Step:13694: Valid Loss:1.19491:Valid Accuracy:0.68662
# INFO:tensorflow:Epoch:22
# INFO:tensorflow:Step:13750 Time:26.29702 Reg Loss:0.27904 Train Loss:0.78168: Accuracy:0.84375
# INFO:tensorflow:Step:14000 Time:22.71131 Reg Loss:0.28246 Train Loss:1.12946: Accuracy:0.77734
# INFO:tensorflow:Step:14250 Time:22.72387 Reg Loss:0.28745 Train Loss:1.21490: Accuracy:0.73958
# INFO:tensorflow:Step:14316: Valid Loss:2.50682:Valid Accuracy:0.47265
# INFO:tensorflow:Epoch:23
# INFO:tensorflow:Step:14500 Time:26.31114 Reg Loss:0.28573 Train Loss:1.06479: Accuracy:0.72656
# INFO:tensorflow:Step:14750 Time:22.69496 Reg Loss:0.29156 Train Loss:1.10821: Accuracy:0.72266
# INFO:tensorflow:Step:14939: Valid Loss:1.17241:Valid Accuracy:0.70154
# INFO:tensorflow:Epoch:24
# INFO:tensorflow:Step:15000 Time:26.31202 Reg Loss:0.29221 Train Loss:0.63062: Accuracy:0.87500
# INFO:tensorflow:Step:15250 Time:22.72166 Reg Loss:0.29492 Train Loss:1.04146: Accuracy:0.81250
# INFO:tensorflow:Step:15500 Time:22.70983 Reg Loss:0.29794 Train Loss:1.12404: Accuracy:0.77344
# INFO:tensorflow:Step:15561: Valid Loss:1.53639:Valid Accuracy:0.61219
# INFO:tensorflow:Epoch:25
# INFO:tensorflow:Step:15750 Time:26.28036 Reg Loss:0.29739 Train Loss:0.82028: Accuracy:0.80469
# INFO:tensorflow:Step:16000 Time:22.71268 Reg Loss:0.30273 Train Loss:1.16558: Accuracy:0.76172
# INFO:tensorflow:Step:16184: Valid Loss:1.35929:Valid Accuracy:0.64557
# INFO:tensorflow:Epoch:26
# INFO:tensorflow:Step:16250 Time:26.30928 Reg Loss:0.30568 Train Loss:0.70305: Accuracy:0.85938
# INFO:tensorflow:Step:16500 Time:22.69245 Reg Loss:0.30744 Train Loss:1.00187: Accuracy:0.82422
# INFO:tensorflow:Step:16750 Time:22.71424 Reg Loss:0.31099 Train Loss:1.08141: Accuracy:0.79948
# INFO:tensorflow:Step:16806: Valid Loss:1.23850:Valid Accuracy:0.69212
# INFO:tensorflow:Epoch:27
# INFO:tensorflow:Step:17000 Time:26.28930 Reg Loss:0.31002 Train Loss:0.75535: Accuracy:0.82031
# INFO:tensorflow:Step:17250 Time:22.71214 Reg Loss:0.31493 Train Loss:1.24048: Accuracy:0.74609
# INFO:tensorflow:Step:17429: Valid Loss:1.27852:Valid Accuracy:0.69530
# INFO:tensorflow:Epoch:28
# INFO:tensorflow:Step:17500 Time:26.30932 Reg Loss:0.31630 Train Loss:0.62214: Accuracy:0.91406
# INFO:tensorflow:Step:17750 Time:22.68115 Reg Loss:0.31971 Train Loss:1.20128: Accuracy:0.77734
# INFO:tensorflow:Step:18000 Time:22.69787 Reg Loss:0.32383 Train Loss:1.17855: Accuracy:0.74479
# INFO:tensorflow:Step:18051: Valid Loss:1.17485:Valid Accuracy:0.70830
# INFO:tensorflow:Epoch:29
# INFO:tensorflow:Step:18250 Time:26.27472 Reg Loss:0.32151 Train Loss:0.87183: Accuracy:0.78125
# INFO:tensorflow:Step:18500 Time:22.70553 Reg Loss:0.32692 Train Loss:1.37456: Accuracy:0.66797
# INFO:tensorflow:Step:18674: Valid Loss:1.28834:Valid Accuracy:0.67161
# INFO:tensorflow:Epoch:30
# INFO:tensorflow:Step:18750 Time:26.29055 Reg Loss:0.32884 Train Loss:0.71520: Accuracy:0.85156
# INFO:tensorflow:Step:19000 Time:22.71068 Reg Loss:0.33062 Train Loss:1.21274: Accuracy:0.77344
# INFO:tensorflow:Step:19250 Time:22.69581 Reg Loss:0.33483 Train Loss:1.20783: Accuracy:0.73438
# INFO:tensorflow:Step:19296: Valid Loss:1.24174:Valid Accuracy:0.70936
# INFO:tensorflow:Epoch:31
# INFO:tensorflow:Step:19500 Time:26.33941 Reg Loss:0.32894 Train Loss:0.90432: Accuracy:0.78906
# INFO:tensorflow:Step:19750 Time:22.66402 Reg Loss:0.33581 Train Loss:1.21939: Accuracy:0.75391
# INFO:tensorflow:Step:19919: Valid Loss:1.07057:Valid Accuracy:0.74327
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:19919: Test Loss:1.08075: Test Accuracy:0.73880
# INFO:tensorflow:Epoch:32
# INFO:tensorflow:Step:20000 Time:28.60021 Reg Loss:0.33809 Train Loss:0.61224: Accuracy:0.74052
# INFO:tensorflow:Step:20250 Time:22.72282 Reg Loss:0.33857 Train Loss:1.10448: Accuracy:0.74035
# INFO:tensorflow:Step:20500 Time:22.67845 Reg Loss:0.34347 Train Loss:1.18644: Accuracy:0.73998
# INFO:tensorflow:Step:20541: Valid Loss:1.00889:Valid Accuracy:0.76550
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:20541: Test Loss:1.03002: Test Accuracy:0.76120
# INFO:tensorflow:Epoch:33
# INFO:tensorflow:Step:20750 Time:28.47863 Reg Loss:0.33944 Train Loss:0.90548: Accuracy:0.76214
# INFO:tensorflow:Step:21000 Time:22.69320 Reg Loss:0.34855 Train Loss:1.17357: Accuracy:0.76160
# INFO:tensorflow:Step:21164: Valid Loss:1.16387:Valid Accuracy:0.74113
# INFO:tensorflow:Epoch:34
# INFO:tensorflow:Step:21250 Time:26.26957 Reg Loss:0.34753 Train Loss:0.62159: Accuracy:0.89844
# INFO:tensorflow:Step:21500 Time:22.74432 Reg Loss:0.35000 Train Loss:1.06686: Accuracy:0.80469
# INFO:tensorflow:Step:21750 Time:22.71922 Reg Loss:0.35384 Train Loss:1.18051: Accuracy:0.75521
# INFO:tensorflow:Step:21786: Valid Loss:1.11423:Valid Accuracy:0.74942
# INFO:tensorflow:Epoch:35
# INFO:tensorflow:Step:22000 Time:26.28107 Reg Loss:0.34904 Train Loss:0.76847: Accuracy:0.83594
# INFO:tensorflow:Step:22250 Time:22.70350 Reg Loss:0.35605 Train Loss:1.22529: Accuracy:0.77734
# INFO:tensorflow:Step:22409: Valid Loss:1.19803:Valid Accuracy:0.71246
# INFO:tensorflow:Epoch:36
# INFO:tensorflow:Step:22500 Time:26.35152 Reg Loss:0.35634 Train Loss:0.67222: Accuracy:0.88281
# INFO:tensorflow:Step:22750 Time:22.69727 Reg Loss:0.35719 Train Loss:1.08759: Accuracy:0.81641
# INFO:tensorflow:Step:23000 Time:22.74250 Reg Loss:0.36049 Train Loss:1.08551: Accuracy:0.79948
# INFO:tensorflow:Step:23031: Valid Loss:1.03198:Valid Accuracy:0.76531
# INFO:tensorflow:Epoch:37
# INFO:tensorflow:Step:23250 Time:26.32641 Reg Loss:0.35683 Train Loss:0.78270: Accuracy:0.84375
# INFO:tensorflow:Step:23500 Time:22.71904 Reg Loss:0.36301 Train Loss:1.26978: Accuracy:0.78125
# INFO:tensorflow:Step:23654: Valid Loss:1.01013:Valid Accuracy:0.79154
# INFO:tensorflow:Epoch:38
# INFO:tensorflow:Step:23750 Time:26.31890 Reg Loss:0.36166 Train Loss:0.77671: Accuracy:0.87500
# INFO:tensorflow:Step:24000 Time:22.70337 Reg Loss:0.36129 Train Loss:1.20229: Accuracy:0.80078
# INFO:tensorflow:Step:24250 Time:22.70281 Reg Loss:0.36742 Train Loss:1.07635: Accuracy:0.78125
# INFO:tensorflow:Step:24276: Valid Loss:0.95411:Valid Accuracy:0.79728
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:24276: Test Loss:0.97732: Test Accuracy:0.79990
# INFO:tensorflow:Epoch:39
# INFO:tensorflow:Step:24500 Time:28.45425 Reg Loss:0.36248 Train Loss:1.02257: Accuracy:0.79937
# INFO:tensorflow:Step:24750 Time:22.69625 Reg Loss:0.36754 Train Loss:1.14916: Accuracy:0.79836
# INFO:tensorflow:Step:24899: Valid Loss:1.15505:Valid Accuracy:0.73528
# INFO:tensorflow:Epoch:40
# INFO:tensorflow:Step:25000 Time:26.28578 Reg Loss:0.36911 Train Loss:0.74990: Accuracy:0.86719
# INFO:tensorflow:Step:25250 Time:22.70270 Reg Loss:0.36980 Train Loss:1.09810: Accuracy:0.80469
# INFO:tensorflow:Step:25500 Time:22.71114 Reg Loss:0.37251 Train Loss:1.13067: Accuracy:0.77604
# INFO:tensorflow:Step:25521: Valid Loss:1.08205:Valid Accuracy:0.77013
# INFO:tensorflow:Epoch:41
# INFO:tensorflow:Step:25750 Time:26.25817 Reg Loss:0.37076 Train Loss:1.10804: Accuracy:0.73438
# INFO:tensorflow:Step:26000 Time:22.72332 Reg Loss:0.37832 Train Loss:1.10314: Accuracy:0.72656
# INFO:tensorflow:Step:26144: Valid Loss:1.14360:Valid Accuracy:0.75195
# INFO:tensorflow:Epoch:42
# INFO:tensorflow:Step:26250 Time:26.33462 Reg Loss:0.37467 Train Loss:0.70236: Accuracy:0.87500
# INFO:tensorflow:Step:26500 Time:22.68794 Reg Loss:0.37773 Train Loss:1.24854: Accuracy:0.76953
# INFO:tensorflow:Step:26750 Time:22.69016 Reg Loss:0.37953 Train Loss:1.36662: Accuracy:0.71875
# INFO:tensorflow:Step:26766: Valid Loss:1.75944:Valid Accuracy:0.62394
# INFO:tensorflow:Epoch:43
# INFO:tensorflow:Step:27000 Time:26.26327 Reg Loss:0.37434 Train Loss:0.98035: Accuracy:0.74219
# INFO:tensorflow:Step:27250 Time:22.70322 Reg Loss:0.38195 Train Loss:1.17533: Accuracy:0.75391
# INFO:tensorflow:Step:27389: Valid Loss:1.10985:Valid Accuracy:0.75546
# INFO:tensorflow:Epoch:44
# INFO:tensorflow:Step:27500 Time:26.25653 Reg Loss:0.38074 Train Loss:0.60974: Accuracy:0.91406
# INFO:tensorflow:Step:27750 Time:22.69940 Reg Loss:0.38175 Train Loss:1.00052: Accuracy:0.83203
# INFO:tensorflow:Step:28000 Time:22.68695 Reg Loss:0.38476 Train Loss:1.14418: Accuracy:0.80208
# INFO:tensorflow:Step:28011: Valid Loss:1.04569:Valid Accuracy:0.77725
# INFO:tensorflow:Epoch:45
# INFO:tensorflow:Step:28250 Time:26.27942 Reg Loss:0.37920 Train Loss:0.82020: Accuracy:0.82812
# INFO:tensorflow:Step:28500 Time:22.73883 Reg Loss:0.38558 Train Loss:1.24052: Accuracy:0.77344
# INFO:tensorflow:Step:28634: Valid Loss:1.19004:Valid Accuracy:0.73957
# INFO:tensorflow:Epoch:46
# INFO:tensorflow:Step:28750 Time:26.32336 Reg Loss:0.38259 Train Loss:0.63869: Accuracy:0.92969
# INFO:tensorflow:Step:29000 Time:22.68153 Reg Loss:0.38569 Train Loss:1.12713: Accuracy:0.83594
# INFO:tensorflow:Step:29250 Time:22.71373 Reg Loss:0.38781 Train Loss:1.04332: Accuracy:0.80729
# INFO:tensorflow:Step:29256: Valid Loss:1.01091:Valid Accuracy:0.78891
# INFO:tensorflow:Epoch:47
# INFO:tensorflow:Step:29500 Time:26.30300 Reg Loss:0.38367 Train Loss:1.14492: Accuracy:0.71875
# INFO:tensorflow:Step:29750 Time:22.71207 Reg Loss:0.39174 Train Loss:1.18794: Accuracy:0.71094
# INFO:tensorflow:Step:29879: Valid Loss:1.04238:Valid Accuracy:0.78140
# INFO:tensorflow:Epoch:48
# INFO:tensorflow:Step:30000 Time:26.32894 Reg Loss:0.38772 Train Loss:0.68990: Accuracy:0.89062
# INFO:tensorflow:Step:30250 Time:22.71417 Reg Loss:0.39117 Train Loss:0.97838: Accuracy:0.84375
# INFO:tensorflow:Step:30500 Time:23.02445 Reg Loss:0.39673 Train Loss:1.22038: Accuracy:0.81771
# INFO:tensorflow:Step:30501: Valid Loss:1.25686:Valid Accuracy:0.72910
# INFO:tensorflow:Epoch:49
# INFO:tensorflow:Step:30750 Time:27.26020 Reg Loss:0.38946 Train Loss:0.85210: Accuracy:0.86719
# INFO:tensorflow:Step:31000 Time:22.84081 Reg Loss:0.39676 Train Loss:1.07676: Accuracy:0.81641
# INFO:tensorflow:Step:31124: Valid Loss:1.02033:Valid Accuracy:0.79358
# INFO:tensorflow:Epoch:50
# INFO:tensorflow:Step:31250 Time:26.62124 Reg Loss:0.39391 Train Loss:0.71293: Accuracy:0.90625
# INFO:tensorflow:Step:31500 Time:22.62965 Reg Loss:0.39596 Train Loss:0.93788: Accuracy:0.86328
# INFO:tensorflow:Step:31747: Valid Loss:0.97360:Valid Accuracy:0.80909
# INFO:tensorflow:Epoch:51
# INFO:tensorflow:Step:31750 Time:26.24190 Reg Loss:0.39963 Train Loss:0.75165: Accuracy:0.88281
# INFO:tensorflow:Step:32000 Time:22.59291 Reg Loss:0.39373 Train Loss:1.01935: Accuracy:0.84766
# INFO:tensorflow:Step:32250 Time:23.18704 Reg Loss:0.40137 Train Loss:1.02752: Accuracy:0.82812
# INFO:tensorflow:Step:32369: Valid Loss:1.07469:Valid Accuracy:0.77783
# INFO:tensorflow:Epoch:52
# INFO:tensorflow:Step:32500 Time:28.83750 Reg Loss:0.39758 Train Loss:0.85465: Accuracy:0.87500
# INFO:tensorflow:Step:32750 Time:25.43507 Reg Loss:0.39981 Train Loss:0.97311: Accuracy:0.82031
# INFO:tensorflow:Step:32992: Valid Loss:1.15811:Valid Accuracy:0.76385
# INFO:tensorflow:Epoch:53
# INFO:tensorflow:Step:33000 Time:29.42724 Reg Loss:0.40445 Train Loss:0.68685: Accuracy:0.92969
# INFO:tensorflow:Step:33250 Time:25.19415 Reg Loss:0.39779 Train Loss:0.91365: Accuracy:0.89453
# INFO:tensorflow:Step:33500 Time:23.78376 Reg Loss:0.40523 Train Loss:1.08760: Accuracy:0.85417
# INFO:tensorflow:Step:33614: Valid Loss:1.06578:Valid Accuracy:0.78929
# INFO:tensorflow:Epoch:54
# INFO:tensorflow:Step:33750 Time:26.46167 Reg Loss:0.40165 Train Loss:0.75608: Accuracy:0.88281
# INFO:tensorflow:Step:34000 Time:22.67755 Reg Loss:0.40588 Train Loss:1.01059: Accuracy:0.83594
# INFO:tensorflow:Step:34237: Valid Loss:1.05836:Valid Accuracy:0.78003
# INFO:tensorflow:Epoch:55
# INFO:tensorflow:Step:34250 Time:26.26764 Reg Loss:0.40572 Train Loss:0.66813: Accuracy:0.92188
# INFO:tensorflow:Step:34500 Time:22.73114 Reg Loss:0.39978 Train Loss:1.19488: Accuracy:0.81641
# INFO:tensorflow:Step:34750 Time:23.21973 Reg Loss:0.40736 Train Loss:1.14501: Accuracy:0.78125
# INFO:tensorflow:Step:34859: Valid Loss:1.05078:Valid Accuracy:0.78072
# INFO:tensorflow:Epoch:56
# INFO:tensorflow:Step:35000 Time:27.07753 Reg Loss:0.39948 Train Loss:0.67714: Accuracy:0.90625
# INFO:tensorflow:Step:35250 Time:23.77614 Reg Loss:0.40600 Train Loss:0.96595: Accuracy:0.85547
# INFO:tensorflow:Step:35482: Valid Loss:0.96379:Valid Accuracy:0.81230
# INFO:tensorflow:Epoch:57
# INFO:tensorflow:Step:35500 Time:27.25622 Reg Loss:0.40807 Train Loss:0.61765: Accuracy:0.93750
# INFO:tensorflow:Step:35750 Time:22.79708 Reg Loss:0.40625 Train Loss:0.94940: Accuracy:0.87109
# INFO:tensorflow:Step:36000 Time:23.71735 Reg Loss:0.41218 Train Loss:1.15419: Accuracy:0.83594
# INFO:tensorflow:Step:36104: Valid Loss:0.98826:Valid Accuracy:0.80335
# INFO:tensorflow:Epoch:58
# INFO:tensorflow:Step:36250 Time:27.34450 Reg Loss:0.40656 Train Loss:0.83264: Accuracy:0.85938
# INFO:tensorflow:Step:36500 Time:23.13124 Reg Loss:0.41245 Train Loss:1.15600: Accuracy:0.81250
# INFO:tensorflow:Step:36727: Valid Loss:1.06602:Valid Accuracy:0.78461
# INFO:tensorflow:Epoch:59
# INFO:tensorflow:Step:36750 Time:26.86249 Reg Loss:0.41259 Train Loss:0.61026: Accuracy:0.93750
# INFO:tensorflow:Step:37000 Time:23.31379 Reg Loss:0.41041 Train Loss:0.92374: Accuracy:0.87109
# INFO:tensorflow:Step:37250 Time:23.35013 Reg Loss:0.41738 Train Loss:1.30135: Accuracy:0.81510
# INFO:tensorflow:Step:37349: Valid Loss:1.01080:Valid Accuracy:0.80277
# INFO:tensorflow:Epoch:60
# INFO:tensorflow:Step:37500 Time:27.16840 Reg Loss:0.41024 Train Loss:0.79655: Accuracy:0.89062
# INFO:tensorflow:Step:37750 Time:23.32096 Reg Loss:0.41443 Train Loss:1.28116: Accuracy:0.80078
# INFO:tensorflow:Step:37972: Valid Loss:0.95233:Valid Accuracy:0.81104
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:37972: Test Loss:0.95855: Test Accuracy:0.80960
# INFO:tensorflow:Epoch:61
# INFO:tensorflow:Step:38000 Time:29.86044 Reg Loss:0.41618 Train Loss:0.61335: Accuracy:0.81122
# INFO:tensorflow:Step:38250 Time:24.05920 Reg Loss:0.39870 Train Loss:0.76264: Accuracy:0.81182
# INFO:tensorflow:Step:38500 Time:23.31066 Reg Loss:0.38405 Train Loss:0.87019: Accuracy:0.81163
# INFO:tensorflow:Step:38594: Valid Loss:0.68147:Valid Accuracy:0.89436
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:38594: Test Loss:0.69352: Test Accuracy:0.89390
# INFO:tensorflow:Epoch:62
# INFO:tensorflow:Step:38750 Time:29.42501 Reg Loss:0.36813 Train Loss:0.45205: Accuracy:0.89494
# INFO:tensorflow:Step:39000 Time:22.89331 Reg Loss:0.35572 Train Loss:0.83254: Accuracy:0.89421
# INFO:tensorflow:Step:39217: Valid Loss:0.64243:Valid Accuracy:0.89762
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:39217: Test Loss:0.66739: Test Accuracy:0.89090
# INFO:tensorflow:Epoch:63
# INFO:tensorflow:Step:39250 Time:29.79435 Reg Loss:0.34397 Train Loss:0.39352: Accuracy:0.89208
# INFO:tensorflow:Step:39500 Time:23.28563 Reg Loss:0.33049 Train Loss:0.58184: Accuracy:0.89245
# INFO:tensorflow:Step:39750 Time:22.85659 Reg Loss:0.32209 Train Loss:0.80773: Accuracy:0.89176
# INFO:tensorflow:Step:39839: Valid Loss:0.63706:Valid Accuracy:0.89233
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:39839: Test Loss:0.66527: Test Accuracy:0.88180
# INFO:tensorflow:Epoch:64
# INFO:tensorflow:Step:40000 Time:29.37770 Reg Loss:0.30992 Train Loss:0.37567: Accuracy:0.88300
# INFO:tensorflow:Step:40250 Time:23.33813 Reg Loss:0.30205 Train Loss:0.65278: Accuracy:0.88280
# INFO:tensorflow:Step:40462: Valid Loss:0.60685:Valid Accuracy:0.89275
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:40462: Test Loss:0.62174: Test Accuracy:0.88930
# INFO:tensorflow:Epoch:65
# INFO:tensorflow:Step:40500 Time:29.87566 Reg Loss:0.29489 Train Loss:0.36138: Accuracy:0.89040
# INFO:tensorflow:Step:40750 Time:23.39653 Reg Loss:0.28444 Train Loss:0.57566: Accuracy:0.89041
# INFO:tensorflow:Step:41000 Time:23.43064 Reg Loss:0.28048 Train Loss:0.55118: Accuracy:0.89041
# INFO:tensorflow:Step:41084: Valid Loss:0.61862:Valid Accuracy:0.88559
# INFO:tensorflow:Epoch:66
# INFO:tensorflow:Step:41250 Time:26.76123 Reg Loss:0.27133 Train Loss:0.29286: Accuracy:0.99219
# INFO:tensorflow:Step:41500 Time:23.70824 Reg Loss:0.26755 Train Loss:0.66982: Accuracy:0.93359
# INFO:tensorflow:Step:41707: Valid Loss:0.61852:Valid Accuracy:0.88222
# INFO:tensorflow:Epoch:67
# INFO:tensorflow:Step:41750 Time:26.77819 Reg Loss:0.26343 Train Loss:0.32886: Accuracy:0.99219
# INFO:tensorflow:Step:42000 Time:23.49654 Reg Loss:0.25556 Train Loss:0.50819: Accuracy:0.95703
# INFO:tensorflow:Step:42250 Time:23.07967 Reg Loss:0.25459 Train Loss:0.66253: Accuracy:0.91406
# INFO:tensorflow:Step:42329: Valid Loss:0.58930:Valid Accuracy:0.88733
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:42329: Test Loss:0.60554: Test Accuracy:0.88210
# INFO:tensorflow:Epoch:68
# INFO:tensorflow:Step:42500 Time:29.74314 Reg Loss:0.24718 Train Loss:0.29074: Accuracy:0.88349
# INFO:tensorflow:Step:42750 Time:23.67364 Reg Loss:0.24666 Train Loss:0.61452: Accuracy:0.88339
# INFO:tensorflow:Step:42952: Valid Loss:0.57117:Valid Accuracy:0.89080
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:42952: Test Loss:0.59471: Test Accuracy:0.88360
# INFO:tensorflow:Epoch:69
# INFO:tensorflow:Step:43000 Time:30.03925 Reg Loss:0.24475 Train Loss:0.29435: Accuracy:0.88487
# INFO:tensorflow:Step:43250 Time:23.66834 Reg Loss:0.23844 Train Loss:0.69842: Accuracy:0.88456
# INFO:tensorflow:Step:43500 Time:23.60650 Reg Loss:0.23968 Train Loss:0.55927: Accuracy:0.88473
# INFO:tensorflow:Step:43574: Valid Loss:0.57109:Valid Accuracy:0.88588
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:43574: Test Loss:0.58542: Test Accuracy:0.88440
# INFO:tensorflow:Epoch:70
# INFO:tensorflow:Step:43750 Time:29.86417 Reg Loss:0.23335 Train Loss:0.30771: Accuracy:0.88566
# INFO:tensorflow:Step:44000 Time:23.16074 Reg Loss:0.23385 Train Loss:0.60102: Accuracy:0.88563
# INFO:tensorflow:Step:44197: Valid Loss:0.62065:Valid Accuracy:0.87578
# INFO:tensorflow:Epoch:71
# INFO:tensorflow:Step:44250 Time:27.78536 Reg Loss:0.23324 Train Loss:0.26310: Accuracy:1.00000
# INFO:tensorflow:Step:44500 Time:23.76137 Reg Loss:0.22859 Train Loss:0.51302: Accuracy:0.94922
# INFO:tensorflow:Step:44750 Time:23.36665 Reg Loss:0.23100 Train Loss:0.78754: Accuracy:0.90104
# INFO:tensorflow:Step:44819: Valid Loss:0.64525:Valid Accuracy:0.86633
# INFO:tensorflow:Epoch:72
# INFO:tensorflow:Step:45000 Time:27.72532 Reg Loss:0.22568 Train Loss:0.30928: Accuracy:0.96094
# INFO:tensorflow:Step:45250 Time:23.63725 Reg Loss:0.22746 Train Loss:0.60322: Accuracy:0.91797
# INFO:tensorflow:Step:45442: Valid Loss:0.55399:Valid Accuracy:0.88846
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:45442: Test Loss:0.58278: Test Accuracy:0.88470
# INFO:tensorflow:Epoch:73
# INFO:tensorflow:Step:45500 Time:29.35872 Reg Loss:0.22751 Train Loss:0.25687: Accuracy:0.88606
# INFO:tensorflow:Step:45750 Time:22.92435 Reg Loss:0.22355 Train Loss:0.50912: Accuracy:0.88621
# INFO:tensorflow:Step:46000 Time:23.19592 Reg Loss:0.22685 Train Loss:0.56226: Accuracy:0.88598
# INFO:tensorflow:Step:46064: Valid Loss:0.66965:Valid Accuracy:0.86036
# INFO:tensorflow:Epoch:74
# INFO:tensorflow:Step:46250 Time:27.90332 Reg Loss:0.22150 Train Loss:0.26112: Accuracy:0.99219
# INFO:tensorflow:Step:46500 Time:23.50851 Reg Loss:0.22422 Train Loss:0.63798: Accuracy:0.93359
# INFO:tensorflow:Step:46687: Valid Loss:0.58804:Valid Accuracy:0.88309
# INFO:tensorflow:Epoch:75
# INFO:tensorflow:Step:46750 Time:26.86037 Reg Loss:0.22496 Train Loss:0.24525: Accuracy:1.00000
# INFO:tensorflow:Step:47000 Time:23.96421 Reg Loss:0.22200 Train Loss:0.53065: Accuracy:0.93750
# INFO:tensorflow:Step:47250 Time:24.99129 Reg Loss:0.22593 Train Loss:0.68117: Accuracy:0.90885
# INFO:tensorflow:Step:47309: Valid Loss:0.55679:Valid Accuracy:0.89493
# INFO:tensorflow:Epoch:76
# INFO:tensorflow:Step:47500 Time:28.94247 Reg Loss:0.22068 Train Loss:0.32408: Accuracy:0.96875
# INFO:tensorflow:Step:47750 Time:25.06231 Reg Loss:0.22413 Train Loss:0.60192: Accuracy:0.91406
# INFO:tensorflow:Step:47932: Valid Loss:0.66671:Valid Accuracy:0.85540
# INFO:tensorflow:Epoch:77
# INFO:tensorflow:Step:48000 Time:28.99322 Reg Loss:0.22488 Train Loss:0.25454: Accuracy:1.00000
# INFO:tensorflow:Step:48250 Time:24.98584 Reg Loss:0.22222 Train Loss:0.49515: Accuracy:0.96094
# INFO:tensorflow:Step:48500 Time:25.13256 Reg Loss:0.22652 Train Loss:0.55336: Accuracy:0.94271
# INFO:tensorflow:Step:48554: Valid Loss:0.58100:Valid Accuracy:0.88482
# INFO:tensorflow:Epoch:78
# INFO:tensorflow:Step:48750 Time:28.94705 Reg Loss:0.22127 Train Loss:0.31332: Accuracy:0.96094
# INFO:tensorflow:Step:49000 Time:25.04651 Reg Loss:0.22536 Train Loss:0.81310: Accuracy:0.91016
# INFO:tensorflow:Step:49177: Valid Loss:0.55517:Valid Accuracy:0.89216
# INFO:tensorflow:Epoch:79
# INFO:tensorflow:Step:49250 Time:28.97424 Reg Loss:0.22531 Train Loss:0.26942: Accuracy:0.98438
# INFO:tensorflow:Step:49500 Time:25.08650 Reg Loss:0.22245 Train Loss:0.60595: Accuracy:0.91016
# INFO:tensorflow:Step:49750 Time:24.84524 Reg Loss:0.22706 Train Loss:0.52531: Accuracy:0.90885
# INFO:tensorflow:Step:49799: Valid Loss:0.59133:Valid Accuracy:0.88559
# INFO:tensorflow:Epoch:80
# INFO:tensorflow:Step:50000 Time:28.49806 Reg Loss:0.22174 Train Loss:0.28960: Accuracy:0.96875
# INFO:tensorflow:Step:50250 Time:25.10781 Reg Loss:0.22557 Train Loss:0.47945: Accuracy:0.92969
# INFO:tensorflow:Step:50422: Valid Loss:0.55421:Valid Accuracy:0.88992
# INFO:tensorflow:Epoch:81
# INFO:tensorflow:Step:50500 Time:29.06715 Reg Loss:0.22590 Train Loss:0.27527: Accuracy:0.98438
# INFO:tensorflow:Step:50750 Time:22.76670 Reg Loss:0.22374 Train Loss:0.54219: Accuracy:0.94531
# INFO:tensorflow:Step:51000 Time:22.64400 Reg Loss:0.22839 Train Loss:0.63211: Accuracy:0.90885
# INFO:tensorflow:Step:51044: Valid Loss:0.58537:Valid Accuracy:0.88540
# INFO:tensorflow:Epoch:82
# INFO:tensorflow:Step:51250 Time:26.22515 Reg Loss:0.22313 Train Loss:0.36426: Accuracy:0.96094
# INFO:tensorflow:Step:51500 Time:22.62034 Reg Loss:0.22723 Train Loss:0.51436: Accuracy:0.91797
# INFO:tensorflow:Step:51667: Valid Loss:0.59010:Valid Accuracy:0.88475
# INFO:tensorflow:Epoch:83
# INFO:tensorflow:Step:51750 Time:26.23247 Reg Loss:0.22789 Train Loss:0.26440: Accuracy:0.99219
# INFO:tensorflow:Step:52000 Time:22.63639 Reg Loss:0.22602 Train Loss:0.44538: Accuracy:0.96094
# INFO:tensorflow:Step:52250 Time:22.67500 Reg Loss:0.22993 Train Loss:0.63031: Accuracy:0.92708
# INFO:tensorflow:Step:52289: Valid Loss:0.54114:Valid Accuracy:0.89715
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:52289: Test Loss:0.55901: Test Accuracy:0.89250
# INFO:tensorflow:Epoch:84
# INFO:tensorflow:Step:52500 Time:28.65768 Reg Loss:0.22434 Train Loss:0.44491: Accuracy:0.89287
# INFO:tensorflow:Step:52750 Time:22.60507 Reg Loss:0.22894 Train Loss:0.61049: Accuracy:0.89236
# INFO:tensorflow:Step:52912: Valid Loss:0.57456:Valid Accuracy:0.89177
# INFO:tensorflow:Epoch:85
# INFO:tensorflow:Step:53000 Time:26.19507 Reg Loss:0.22879 Train Loss:0.24989: Accuracy:1.00000
# INFO:tensorflow:Step:53250 Time:22.73196 Reg Loss:0.22704 Train Loss:0.60017: Accuracy:0.94922
# INFO:tensorflow:Step:53500 Time:23.22440 Reg Loss:0.23159 Train Loss:0.58446: Accuracy:0.91146
# INFO:tensorflow:Step:53534: Valid Loss:0.58573:Valid Accuracy:0.88704
# INFO:tensorflow:Epoch:86
# INFO:tensorflow:Step:53750 Time:27.19811 Reg Loss:0.22635 Train Loss:0.39602: Accuracy:0.95312
# INFO:tensorflow:Step:54000 Time:22.97504 Reg Loss:0.23139 Train Loss:0.63644: Accuracy:0.91797
# INFO:tensorflow:Step:54157: Valid Loss:0.58910:Valid Accuracy:0.88621
# INFO:tensorflow:Epoch:87
# INFO:tensorflow:Step:54250 Time:27.65739 Reg Loss:0.23131 Train Loss:0.25366: Accuracy:1.00000
# INFO:tensorflow:Step:54500 Time:22.66251 Reg Loss:0.22975 Train Loss:0.52160: Accuracy:0.94922
# INFO:tensorflow:Step:54750 Time:23.07604 Reg Loss:0.23430 Train Loss:0.55313: Accuracy:0.92969
# INFO:tensorflow:Step:54779: Valid Loss:0.60790:Valid Accuracy:0.88579
# INFO:tensorflow:Epoch:88
# INFO:tensorflow:Step:55000 Time:26.64535 Reg Loss:0.22841 Train Loss:0.44892: Accuracy:0.96094
# INFO:tensorflow:Step:55250 Time:23.01769 Reg Loss:0.23342 Train Loss:0.67604: Accuracy:0.91016
# INFO:tensorflow:Step:55402: Valid Loss:0.65958:Valid Accuracy:0.87012
# INFO:tensorflow:Epoch:89
# INFO:tensorflow:Step:55500 Time:28.53932 Reg Loss:0.23275 Train Loss:0.29689: Accuracy:0.98438
# INFO:tensorflow:Step:55750 Time:25.28206 Reg Loss:0.23147 Train Loss:0.57191: Accuracy:0.93750
# INFO:tensorflow:Step:56000 Time:23.57209 Reg Loss:0.23615 Train Loss:0.53058: Accuracy:0.93229
# INFO:tensorflow:Step:56024: Valid Loss:0.59192:Valid Accuracy:0.88492
# INFO:tensorflow:Epoch:90
# INFO:tensorflow:Step:56250 Time:27.54587 Reg Loss:0.22992 Train Loss:0.46374: Accuracy:0.92188
# INFO:tensorflow:Step:56500 Time:25.02482 Reg Loss:0.23479 Train Loss:0.68422: Accuracy:0.90234
# INFO:tensorflow:Step:56647: Valid Loss:0.62204:Valid Accuracy:0.88007
# INFO:tensorflow:Epoch:91
# INFO:tensorflow:Step:56750 Time:28.99145 Reg Loss:0.23477 Train Loss:0.24820: Accuracy:1.00000
# INFO:tensorflow:Step:57000 Time:24.96280 Reg Loss:0.23316 Train Loss:0.62777: Accuracy:0.92578
# INFO:tensorflow:Step:57250 Time:23.64970 Reg Loss:0.23710 Train Loss:0.61023: Accuracy:0.90365
# INFO:tensorflow:Step:57269: Valid Loss:0.61443:Valid Accuracy:0.88444
# INFO:tensorflow:Epoch:92
# INFO:tensorflow:Step:57500 Time:27.50506 Reg Loss:0.23073 Train Loss:0.34354: Accuracy:0.96875
# INFO:tensorflow:Step:57750 Time:22.85007 Reg Loss:0.23567 Train Loss:0.56038: Accuracy:0.93750
# INFO:tensorflow:Step:57892: Valid Loss:0.56534:Valid Accuracy:0.89577
# INFO:tensorflow:Epoch:93
# INFO:tensorflow:Step:58000 Time:27.04277 Reg Loss:0.23458 Train Loss:0.25297: Accuracy:0.99219
# INFO:tensorflow:Step:58250 Time:23.99751 Reg Loss:0.23391 Train Loss:0.55167: Accuracy:0.94531
# INFO:tensorflow:Step:58500 Time:23.80122 Reg Loss:0.23897 Train Loss:0.68755: Accuracy:0.90885
# INFO:tensorflow:Step:58514: Valid Loss:0.59140:Valid Accuracy:0.88819
# INFO:tensorflow:Epoch:94
# INFO:tensorflow:Step:58750 Time:26.87126 Reg Loss:0.23276 Train Loss:0.48019: Accuracy:0.90625
# INFO:tensorflow:Step:59000 Time:23.12500 Reg Loss:0.23806 Train Loss:0.54400: Accuracy:0.89453
# INFO:tensorflow:Step:59137: Valid Loss:0.57545:Valid Accuracy:0.89177
# INFO:tensorflow:Epoch:95
# INFO:tensorflow:Step:59250 Time:27.88258 Reg Loss:0.23684 Train Loss:0.24360: Accuracy:1.00000
# INFO:tensorflow:Step:59500 Time:24.47620 Reg Loss:0.23658 Train Loss:0.63958: Accuracy:0.92188
# INFO:tensorflow:Step:59750 Time:23.27060 Reg Loss:0.24121 Train Loss:0.58530: Accuracy:0.89583
# INFO:tensorflow:Step:59759: Valid Loss:0.58921:Valid Accuracy:0.89070
# INFO:tensorflow:Epoch:96
# INFO:tensorflow:Step:60000 Time:27.41516 Reg Loss:0.23467 Train Loss:0.47587: Accuracy:0.91406
# INFO:tensorflow:Step:60250 Time:23.79028 Reg Loss:0.23994 Train Loss:0.64702: Accuracy:0.87500
# INFO:tensorflow:Step:60382: Valid Loss:0.58613:Valid Accuracy:0.88787
# INFO:tensorflow:Epoch:97
# INFO:tensorflow:Step:60500 Time:26.27270 Reg Loss:0.23818 Train Loss:0.29169: Accuracy:0.96875
# INFO:tensorflow:Step:60750 Time:22.66300 Reg Loss:0.23834 Train Loss:0.46974: Accuracy:0.93750
# INFO:tensorflow:Step:61000 Time:22.62601 Reg Loss:0.24263 Train Loss:0.65951: Accuracy:0.91146
# INFO:tensorflow:Step:61004: Valid Loss:0.56007:Valid Accuracy:0.89734
# INFO:tensorflow:Epoch:98
# INFO:tensorflow:Step:61250 Time:26.22458 Reg Loss:0.23604 Train Loss:0.52661: Accuracy:0.89844
# INFO:tensorflow:Step:61500 Time:22.62131 Reg Loss:0.24107 Train Loss:0.62948: Accuracy:0.89062
# INFO:tensorflow:Step:61627: Valid Loss:0.62505:Valid Accuracy:0.87929
# INFO:tensorflow:Epoch:99
# INFO:tensorflow:Step:61750 Time:26.20323 Reg Loss:0.23955 Train Loss:0.26977: Accuracy:0.99219
# INFO:tensorflow:Step:62000 Time:22.66588 Reg Loss:0.23974 Train Loss:0.44528: Accuracy:0.96094
# INFO:tensorflow:Step:62250: Valid Loss:0.59628:Valid Accuracy:0.89255
# INFO:tensorflow:Epoch:100
# INFO:tensorflow:Step:62500 Time:48.80884 Reg Loss:0.23802 Train Loss:0.41784: Accuracy:0.94531
# INFO:tensorflow:Step:62750 Time:22.63081 Reg Loss:0.24329 Train Loss:0.55371: Accuracy:0.92188
# INFO:tensorflow:Step:62873: Valid Loss:0.62550:Valid Accuracy:0.88017
# INFO:tensorflow:Epoch:101
# INFO:tensorflow:Step:63000 Time:26.21212 Reg Loss:0.24133 Train Loss:0.25913: Accuracy:0.99219
# INFO:tensorflow:Step:63250 Time:22.69314 Reg Loss:0.24195 Train Loss:0.70276: Accuracy:0.90234
# INFO:tensorflow:Step:63496: Valid Loss:0.59348:Valid Accuracy:0.88602
# INFO:tensorflow:Epoch:102
# INFO:tensorflow:Step:63500 Time:27.03587 Reg Loss:0.24580 Train Loss:0.33671: Accuracy:0.98438
# INFO:tensorflow:Step:63750 Time:23.71306 Reg Loss:0.23885 Train Loss:0.49134: Accuracy:0.94922
# INFO:tensorflow:Step:64000 Time:23.69948 Reg Loss:0.24371 Train Loss:0.58783: Accuracy:0.91667
# INFO:tensorflow:Step:64118: Valid Loss:0.65011:Valid Accuracy:0.87799
# INFO:tensorflow:Epoch:103
# INFO:tensorflow:Step:64250 Time:27.29153 Reg Loss:0.24119 Train Loss:0.26054: Accuracy:0.99219
# INFO:tensorflow:Step:64500 Time:22.96285 Reg Loss:0.24171 Train Loss:0.53339: Accuracy:0.95312
# INFO:tensorflow:Step:64741: Valid Loss:0.60435:Valid Accuracy:0.88670
# INFO:tensorflow:Epoch:104
# INFO:tensorflow:Step:64750 Time:26.44804 Reg Loss:0.24563 Train Loss:0.31946: Accuracy:0.98438
# INFO:tensorflow:Step:65000 Time:22.60397 Reg Loss:0.23901 Train Loss:0.43327: Accuracy:0.95703
# INFO:tensorflow:Step:65250 Time:22.76220 Reg Loss:0.24445 Train Loss:0.57135: Accuracy:0.94010
# INFO:tensorflow:Step:65363: Valid Loss:0.65198:Valid Accuracy:0.87307
# INFO:tensorflow:Epoch:105
# INFO:tensorflow:Step:65500 Time:28.21527 Reg Loss:0.24203 Train Loss:0.25379: Accuracy:1.00000
# INFO:tensorflow:Step:65750 Time:24.72779 Reg Loss:0.24292 Train Loss:0.49398: Accuracy:0.95703
# INFO:tensorflow:Step:65986: Valid Loss:0.58114:Valid Accuracy:0.88807
# INFO:tensorflow:Epoch:106
# INFO:tensorflow:Step:66000 Time:28.10579 Reg Loss:0.24771 Train Loss:0.38184: Accuracy:0.96094
# INFO:tensorflow:Step:66250 Time:24.76006 Reg Loss:0.24159 Train Loss:0.48036: Accuracy:0.94141
# INFO:tensorflow:Step:66500 Time:24.15496 Reg Loss:0.24702 Train Loss:0.64302: Accuracy:0.92448
# INFO:tensorflow:Step:66608: Valid Loss:0.64165:Valid Accuracy:0.87837
# INFO:tensorflow:Epoch:107
# INFO:tensorflow:Step:66750 Time:28.76859 Reg Loss:0.24405 Train Loss:0.25735: Accuracy:1.00000
# INFO:tensorflow:Step:67000 Time:25.17495 Reg Loss:0.24528 Train Loss:0.62117: Accuracy:0.93750
# INFO:tensorflow:Step:67231: Valid Loss:0.58526:Valid Accuracy:0.89206
# INFO:tensorflow:Epoch:108
# INFO:tensorflow:Step:67250 Time:29.36620 Reg Loss:0.24941 Train Loss:0.33065: Accuracy:0.96875
# INFO:tensorflow:Step:67500 Time:23.69510 Reg Loss:0.24299 Train Loss:0.41984: Accuracy:0.95703
# INFO:tensorflow:Step:67750 Time:23.17596 Reg Loss:0.24794 Train Loss:0.54304: Accuracy:0.94010
# INFO:tensorflow:Step:67853: Valid Loss:0.59871:Valid Accuracy:0.89484
# INFO:tensorflow:Epoch:109
# INFO:tensorflow:Step:68000 Time:27.70936 Reg Loss:0.24511 Train Loss:0.25868: Accuracy:1.00000
# INFO:tensorflow:Step:68250 Time:24.42387 Reg Loss:0.24603 Train Loss:0.53864: Accuracy:0.94531
# INFO:tensorflow:Step:68476: Valid Loss:0.62816:Valid Accuracy:0.87559
# INFO:tensorflow:Epoch:110
# INFO:tensorflow:Step:68500 Time:27.32682 Reg Loss:0.24987 Train Loss:0.31167: Accuracy:0.97656
# INFO:tensorflow:Step:68750 Time:23.16947 Reg Loss:0.24384 Train Loss:0.40489: Accuracy:0.96484
# INFO:tensorflow:Step:69000 Time:23.69583 Reg Loss:0.24878 Train Loss:0.67097: Accuracy:0.92969
# INFO:tensorflow:Step:69098: Valid Loss:0.60087:Valid Accuracy:0.88665
# INFO:tensorflow:Epoch:111
# INFO:tensorflow:Step:69250 Time:28.89129 Reg Loss:0.24508 Train Loss:0.26134: Accuracy:1.00000
# INFO:tensorflow:Step:69500 Time:24.87845 Reg Loss:0.24718 Train Loss:0.62880: Accuracy:0.93359
# INFO:tensorflow:Step:69721: Valid Loss:0.57125:Valid Accuracy:0.89762
# INFO:tensorflow:Epoch:112
# INFO:tensorflow:Step:69750 Time:26.83391 Reg Loss:0.25048 Train Loss:0.29439: Accuracy:0.99219
# INFO:tensorflow:Step:70000 Time:23.92849 Reg Loss:0.24425 Train Loss:0.52969: Accuracy:0.94141
# INFO:tensorflow:Step:70250 Time:23.17836 Reg Loss:0.24910 Train Loss:0.54753: Accuracy:0.92448
# INFO:tensorflow:Step:70343: Valid Loss:0.63617:Valid Accuracy:0.88290
# INFO:tensorflow:Epoch:113
# INFO:tensorflow:Step:70500 Time:27.15786 Reg Loss:0.24557 Train Loss:0.26225: Accuracy:1.00000
# INFO:tensorflow:Step:70750 Time:23.78353 Reg Loss:0.24716 Train Loss:0.55485: Accuracy:0.95703
# INFO:tensorflow:Step:70966: Valid Loss:0.55485:Valid Accuracy:0.90259
# INFO:tensorflow:Epoch:114
# INFO:tensorflow:Step:71000 Time:27.43681 Reg Loss:0.25100 Train Loss:0.28422: Accuracy:0.99219
# INFO:tensorflow:Step:71250 Time:23.00886 Reg Loss:0.24549 Train Loss:0.57224: Accuracy:0.94922
# INFO:tensorflow:Step:71500 Time:23.33479 Reg Loss:0.25076 Train Loss:0.60974: Accuracy:0.91927
# INFO:tensorflow:Step:71588: Valid Loss:0.62248:Valid Accuracy:0.88521
# INFO:tensorflow:Epoch:115
# INFO:tensorflow:Step:71750 Time:29.06055 Reg Loss:0.24646 Train Loss:0.26128: Accuracy:0.99219
# INFO:tensorflow:Step:72000 Time:25.56028 Reg Loss:0.24824 Train Loss:0.65407: Accuracy:0.93359
# INFO:tensorflow:Step:72211: Valid Loss:0.58386:Valid Accuracy:0.89791
# INFO:tensorflow:Epoch:116
# INFO:tensorflow:Step:72250 Time:29.32004 Reg Loss:0.25194 Train Loss:0.29511: Accuracy:0.98438
# INFO:tensorflow:Step:72500 Time:25.36245 Reg Loss:0.24596 Train Loss:0.50744: Accuracy:0.94141
# INFO:tensorflow:Step:72750 Time:23.77881 Reg Loss:0.25131 Train Loss:0.61930: Accuracy:0.92188
# INFO:tensorflow:Step:72833: Valid Loss:0.58877:Valid Accuracy:0.89224
# INFO:tensorflow:Epoch:117
# INFO:tensorflow:Step:73000 Time:26.24541 Reg Loss:0.24703 Train Loss:0.26488: Accuracy:0.99219
# INFO:tensorflow:Step:73250 Time:22.68323 Reg Loss:0.25016 Train Loss:0.52580: Accuracy:0.96484
# INFO:tensorflow:Step:73456: Valid Loss:0.59933:Valid Accuracy:0.89187
# INFO:tensorflow:Epoch:118
# INFO:tensorflow:Step:73500 Time:26.65182 Reg Loss:0.25305 Train Loss:0.28284: Accuracy:0.99219
# INFO:tensorflow:Step:73750 Time:24.24591 Reg Loss:0.24747 Train Loss:0.37925: Accuracy:0.98438
# INFO:tensorflow:Step:74000 Time:22.93095 Reg Loss:0.25287 Train Loss:0.63733: Accuracy:0.94010
# INFO:tensorflow:Step:74078: Valid Loss:0.63441:Valid Accuracy:0.88482
# INFO:tensorflow:Epoch:119
# INFO:tensorflow:Step:74250 Time:26.83286 Reg Loss:0.24787 Train Loss:0.32727: Accuracy:0.98438
# INFO:tensorflow:Step:74500 Time:23.71351 Reg Loss:0.25040 Train Loss:0.56369: Accuracy:0.94531
# INFO:tensorflow:Step:74701: Valid Loss:0.62789:Valid Accuracy:0.88056
# INFO:tensorflow:Epoch:120
# INFO:tensorflow:Step:74750 Time:26.93784 Reg Loss:0.25355 Train Loss:0.28068: Accuracy:1.00000
# INFO:tensorflow:Step:75000 Time:23.94136 Reg Loss:0.24849 Train Loss:0.46667: Accuracy:0.95703
# INFO:tensorflow:Step:75250 Time:23.47278 Reg Loss:0.25326 Train Loss:0.55316: Accuracy:0.92969
# INFO:tensorflow:Step:75323: Valid Loss:0.61534:Valid Accuracy:0.89291
# INFO:tensorflow:Epoch:121
# INFO:tensorflow:Step:75500 Time:27.35524 Reg Loss:0.25284 Train Loss:0.31881: Accuracy:0.99219
# INFO:tensorflow:Step:75750 Time:23.56847 Reg Loss:0.25067 Train Loss:0.40164: Accuracy:0.96875
# INFO:tensorflow:Step:75946: Valid Loss:0.48683:Valid Accuracy:0.92638
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:75946: Test Loss:0.49423: Test Accuracy:0.92100
# INFO:tensorflow:Epoch:122
# INFO:tensorflow:Step:76000 Time:28.68537 Reg Loss:0.24861 Train Loss:0.26127: Accuracy:0.92200
# INFO:tensorflow:Step:76250 Time:23.07618 Reg Loss:0.24624 Train Loss:0.35589: Accuracy:0.92239
# INFO:tensorflow:Step:76500 Time:23.46641 Reg Loss:0.24433 Train Loss:0.38655: Accuracy:0.92277
# INFO:tensorflow:Step:76568: Valid Loss:0.47516:Valid Accuracy:0.92691
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:76568: Test Loss:0.48918: Test Accuracy:0.92310
# INFO:tensorflow:Epoch:123
# INFO:tensorflow:Step:76750 Time:29.17121 Reg Loss:0.24209 Train Loss:0.31011: Accuracy:0.92387
# INFO:tensorflow:Step:77000 Time:22.83549 Reg Loss:0.24006 Train Loss:0.37726: Accuracy:0.92395
# INFO:tensorflow:Step:77191: Valid Loss:0.46601:Valid Accuracy:0.93184
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:77191: Test Loss:0.47656: Test Accuracy:0.92790
# INFO:tensorflow:Epoch:124
# INFO:tensorflow:Step:77250 Time:28.42746 Reg Loss:0.23819 Train Loss:0.24448: Accuracy:0.92881
# INFO:tensorflow:Step:77500 Time:22.64725 Reg Loss:0.23593 Train Loss:0.44763: Accuracy:0.92882
# INFO:tensorflow:Step:77750 Time:22.63175 Reg Loss:0.23421 Train Loss:0.54068: Accuracy:0.92874
# INFO:tensorflow:Step:77813: Valid Loss:0.47287:Valid Accuracy:0.93047
# INFO:tensorflow:Epoch:125
# INFO:tensorflow:Step:78000 Time:26.22873 Reg Loss:0.23211 Train Loss:0.30383: Accuracy:0.97656
# INFO:tensorflow:Step:78250 Time:22.64107 Reg Loss:0.23019 Train Loss:0.38537: Accuracy:0.95703
# INFO:tensorflow:Step:78436: Valid Loss:0.47194:Valid Accuracy:0.92853
# INFO:tensorflow:Epoch:126
# INFO:tensorflow:Step:78500 Time:26.24901 Reg Loss:0.22842 Train Loss:0.23094: Accuracy:1.00000
# INFO:tensorflow:Step:78750 Time:22.62604 Reg Loss:0.22631 Train Loss:0.33023: Accuracy:0.98438
# INFO:tensorflow:Step:79000 Time:22.64816 Reg Loss:0.22471 Train Loss:0.49493: Accuracy:0.95573
# INFO:tensorflow:Step:79058: Valid Loss:0.46069:Valid Accuracy:0.93086
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:79058: Test Loss:0.47828: Test Accuracy:0.92560
# INFO:tensorflow:Epoch:127
# INFO:tensorflow:Step:79250 Time:28.39861 Reg Loss:0.22267 Train Loss:0.26852: Accuracy:0.92615
# INFO:tensorflow:Step:79500 Time:22.64575 Reg Loss:0.22095 Train Loss:0.36746: Accuracy:0.92638
# INFO:tensorflow:Step:79681: Valid Loss:0.45792:Valid Accuracy:0.92950
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:79681: Test Loss:0.46619: Test Accuracy:0.92840
# INFO:tensorflow:Epoch:128
# INFO:tensorflow:Step:79750 Time:28.49595 Reg Loss:0.21934 Train Loss:0.22286: Accuracy:0.92930
# INFO:tensorflow:Step:80000 Time:23.86508 Reg Loss:0.21734 Train Loss:0.32425: Accuracy:0.92950
# INFO:tensorflow:Step:80250 Time:22.73359 Reg Loss:0.21591 Train Loss:0.33886: Accuracy:0.92999
# INFO:tensorflow:Step:80303: Valid Loss:0.45229:Valid Accuracy:0.93201
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:80303: Test Loss:0.46051: Test Accuracy:0.92860
# INFO:tensorflow:Epoch:129
# INFO:tensorflow:Step:80500 Time:28.53016 Reg Loss:0.21397 Train Loss:0.28815: Accuracy:0.92911
# INFO:tensorflow:Step:80750 Time:22.70179 Reg Loss:0.21236 Train Loss:0.29605: Accuracy:0.92970
# INFO:tensorflow:Step:80926: Valid Loss:0.45211:Valid Accuracy:0.93038
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:80926: Test Loss:0.46149: Test Accuracy:0.92830
# INFO:tensorflow:Epoch:130
# INFO:tensorflow:Step:81000 Time:28.47709 Reg Loss:0.21086 Train Loss:0.21743: Accuracy:0.92921
# INFO:tensorflow:Step:81250 Time:22.71725 Reg Loss:0.20895 Train Loss:0.25511: Accuracy:0.92989
# INFO:tensorflow:Step:81500 Time:22.73870 Reg Loss:0.20768 Train Loss:0.37342: Accuracy:0.93037
# INFO:tensorflow:Step:81548: Valid Loss:0.45740:Valid Accuracy:0.93191
# INFO:tensorflow:Epoch:131
# INFO:tensorflow:Step:81750 Time:26.34100 Reg Loss:0.20584 Train Loss:0.22313: Accuracy:0.99219
# INFO:tensorflow:Step:82000 Time:22.69740 Reg Loss:0.20432 Train Loss:0.38880: Accuracy:0.96094
# INFO:tensorflow:Step:82171: Valid Loss:0.44928:Valid Accuracy:0.93214
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:82171: Test Loss:0.46612: Test Accuracy:0.92410
# INFO:tensorflow:Epoch:132
# INFO:tensorflow:Step:82250 Time:28.52680 Reg Loss:0.20295 Train Loss:0.20517: Accuracy:0.92506
# INFO:tensorflow:Step:82500 Time:22.72849 Reg Loss:0.20116 Train Loss:0.30645: Accuracy:0.92560
# INFO:tensorflow:Step:82750 Time:22.68556 Reg Loss:0.20004 Train Loss:0.31586: Accuracy:0.92594
# INFO:tensorflow:Step:82793: Valid Loss:0.44296:Valid Accuracy:0.93413
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:82793: Test Loss:0.45221: Test Accuracy:0.92810
# INFO:tensorflow:Epoch:133
# ...
# INFO:tensorflow:Step:96250 Time:22.72036 Reg Loss:0.14707 Train Loss:0.22271: Accuracy:0.98828
# INFO:tensorflow:Step:96489: Valid Loss:0.45970:Valid Accuracy:0.91790
# INFO:tensorflow:Epoch:155
# INFO:tensorflow:Step:96500 Time:26.35545 Reg Loss:0.14710 Train Loss:0.15027: Accuracy:1.00000
# INFO:tensorflow:Step:96750 Time:22.65428 Reg Loss:0.14583 Train Loss:0.19334: Accuracy:1.00000
# INFO:tensorflow:Step:97000 Time:22.72677 Reg Loss:0.14568 Train Loss:0.34047: Accuracy:0.98177
# INFO:tensorflow:Step:97111: Valid Loss:0.45841:Valid Accuracy:0.92315
# INFO:tensorflow:Epoch:156
# INFO:tensorflow:Step:97250 Time:26.31638 Reg Loss:0.14508 Train Loss:0.14705: Accuracy:1.00000
# INFO:tensorflow:Step:97500 Time:22.70290 Reg Loss:0.14439 Train Loss:0.31084: Accuracy:0.98047
# INFO:tensorflow:Step:97734: Valid Loss:0.43214:Valid Accuracy:0.92443
# INFO:tensorflow:Epoch:157
# INFO:tensorflow:Step:97750 Time:26.34511 Reg Loss:0.14451 Train Loss:0.15090: Accuracy:1.00000
# INFO:tensorflow:Step:98000 Time:22.68452 Reg Loss:0.14327 Train Loss:0.16558: Accuracy:0.99609
# INFO:tensorflow:Step:98250 Time:22.73282 Reg Loss:0.14315 Train Loss:0.31490: Accuracy:0.97656
# INFO:tensorflow:Step:98356: Valid Loss:0.46512:Valid Accuracy:0.91988
# INFO:tensorflow:Epoch:158
# INFO:tensorflow:Step:98500 Time:26.30764 Reg Loss:0.14256 Train Loss:0.14726: Accuracy:1.00000
# INFO:tensorflow:Step:98750 Time:22.70047 Reg Loss:0.14190 Train Loss:0.21613: Accuracy:0.98828
# INFO:tensorflow:Step:98979: Valid Loss:0.41161:Valid Accuracy:0.92892
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:98979: Test Loss:0.43909: Test Accuracy:0.91950
# INFO:tensorflow:Epoch:159
# INFO:tensorflow:Step:99000 Time:28.53041 Reg Loss:0.14198 Train Loss:0.15575: Accuracy:0.92052
# INFO:tensorflow:Step:99250 Time:22.67145 Reg Loss:0.14082 Train Loss:0.27274: Accuracy:0.92092
# INFO:tensorflow:Step:99500 Time:22.73179 Reg Loss:0.14080 Train Loss:0.30685: Accuracy:0.92113
# INFO:tensorflow:Step:99601: Valid Loss:0.43608:Valid Accuracy:0.92142
# INFO:tensorflow:Epoch:160
# INFO:tensorflow:Step:99750 Time:26.34487 Reg Loss:0.14025 Train Loss:0.14684: Accuracy:1.00000
# INFO:tensorflow:Step:100000 Time:22.70567 Reg Loss:0.13961 Train Loss:0.37912: Accuracy:0.96484
# INFO:tensorflow:Step:100224: Valid Loss:0.44562:Valid Accuracy:0.92385
# INFO:tensorflow:Epoch:161
# INFO:tensorflow:Step:100250 Time:26.32153 Reg Loss:0.13980 Train Loss:0.14610: Accuracy:1.00000
# INFO:tensorflow:Step:100500 Time:22.68250 Reg Loss:0.13954 Train Loss:0.23692: Accuracy:0.97266
# INFO:tensorflow:Step:100750 Time:22.72660 Reg Loss:0.13930 Train Loss:0.22349: Accuracy:0.97135
# INFO:tensorflow:Step:100846: Valid Loss:0.38557:Valid Accuracy:0.93634
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:100846: Test Loss:0.41019: Test Accuracy:0.92940
# INFO:tensorflow:Epoch:162
# INFO:tensorflow:Step:101000 Time:28.47394 Reg Loss:0.13904 Train Loss:0.14157: Accuracy:0.93029
# INFO:tensorflow:Step:101250 Time:22.72424 Reg Loss:0.13878 Train Loss:0.18226: Accuracy:0.93106
# INFO:tensorflow:Step:101469: Valid Loss:0.37948:Valid Accuracy:0.93574
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:101469: Test Loss:0.41338: Test Accuracy:0.92950
# INFO:tensorflow:Epoch:163
# INFO:tensorflow:Step:101500 Time:28.53743 Reg Loss:0.13854 Train Loss:0.14014: Accuracy:0.93039
# INFO:tensorflow:Step:101750 Time:22.70980 Reg Loss:0.13827 Train Loss:0.16999: Accuracy:0.93106
# INFO:tensorflow:Step:102000 Time:22.72436 Reg Loss:0.13803 Train Loss:0.20526: Accuracy:0.93153
# INFO:tensorflow:Step:102091: Valid Loss:0.37670:Valid Accuracy:0.93548
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:102091: Test Loss:0.40921: Test Accuracy:0.92980
# INFO:tensorflow:Epoch:164
# INFO:tensorflow:Step:102250 Time:28.50735 Reg Loss:0.13777 Train Loss:0.13866: Accuracy:0.93069
# INFO:tensorflow:Step:102500 Time:22.69705 Reg Loss:0.13752 Train Loss:0.20429: Accuracy:0.93106
# INFO:tensorflow:Step:102714: Valid Loss:0.37793:Valid Accuracy:0.93652
# INFO:tensorflow:Epoch:165
# INFO:tensorflow:Step:102750 Time:26.35270 Reg Loss:0.13728 Train Loss:0.14225: Accuracy:1.00000
# INFO:tensorflow:Step:103000 Time:22.72455 Reg Loss:0.13701 Train Loss:0.18378: Accuracy:0.99609
# INFO:tensorflow:Step:103250 Time:22.73265 Reg Loss:0.13678 Train Loss:0.24242: Accuracy:0.98177
# INFO:tensorflow:Step:103336: Valid Loss:0.37343:Valid Accuracy:0.93846
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:103336: Test Loss:0.41116: Test Accuracy:0.93220
# INFO:tensorflow:Epoch:166
# INFO:tensorflow:Step:103500 Time:28.50628 Reg Loss:0.13652 Train Loss:0.14393: Accuracy:0.93296
# INFO:tensorflow:Step:103750 Time:23.26422 Reg Loss:0.13627 Train Loss:0.24112: Accuracy:0.93331
# INFO:tensorflow:Step:103959: Valid Loss:0.37462:Valid Accuracy:0.93535
# INFO:tensorflow:Epoch:167
# INFO:tensorflow:Step:104000 Time:27.11175 Reg Loss:0.13603 Train Loss:0.13757: Accuracy:1.00000
# INFO:tensorflow:Step:104250 Time:23.69481 Reg Loss:0.13576 Train Loss:0.23036: Accuracy:0.97656
# INFO:tensorflow:Step:104500 Time:23.19316 Reg Loss:0.13553 Train Loss:0.19596: Accuracy:0.97917
# INFO:tensorflow:Step:104581: Valid Loss:0.37707:Valid Accuracy:0.93615
# INFO:tensorflow:Epoch:168
# INFO:tensorflow:Step:104750 Time:26.25267 Reg Loss:0.13528 Train Loss:0.13632: Accuracy:1.00000
# INFO:tensorflow:Step:105000 Time:22.63859 Reg Loss:0.13503 Train Loss:0.18919: Accuracy:0.98828
# INFO:tensorflow:Step:105204: Valid Loss:0.37660:Valid Accuracy:0.93809
# INFO:tensorflow:Epoch:169
# INFO:tensorflow:Step:105250 Time:26.23252 Reg Loss:0.13480 Train Loss:0.13562: Accuracy:1.00000
# INFO:tensorflow:Step:105500 Time:22.66436 Reg Loss:0.13454 Train Loss:0.20148: Accuracy:0.98438
# INFO:tensorflow:Step:105750 Time:22.63818 Reg Loss:0.13431 Train Loss:0.17479: Accuracy:0.98438
# INFO:tensorflow:Step:105826: Valid Loss:0.37702:Valid Accuracy:0.93798
# INFO:tensorflow:Epoch:170
# INFO:tensorflow:Step:106000 Time:26.24895 Reg Loss:0.13406 Train Loss:0.13838: Accuracy:1.00000
# INFO:tensorflow:Step:106250 Time:22.64482 Reg Loss:0.13382 Train Loss:0.16806: Accuracy:0.99219
# INFO:tensorflow:Step:106449: Valid Loss:0.38158:Valid Accuracy:0.93584
# INFO:tensorflow:Epoch:171
# INFO:tensorflow:Step:106500 Time:26.24031 Reg Loss:0.13360 Train Loss:0.13493: Accuracy:1.00000
# INFO:tensorflow:Step:106750 Time:22.66120 Reg Loss:0.13334 Train Loss:0.18853: Accuracy:0.99219
# INFO:tensorflow:Step:107000 Time:22.62849 Reg Loss:0.13311 Train Loss:0.22845: Accuracy:0.98177
# INFO:tensorflow:Step:107071: Valid Loss:0.38255:Valid Accuracy:0.93625
# INFO:tensorflow:Epoch:172
# INFO:tensorflow:Step:107250 Time:26.26680 Reg Loss:0.13286 Train Loss:0.14167: Accuracy:1.00000
# INFO:tensorflow:Step:107500 Time:22.66448 Reg Loss:0.13262 Train Loss:0.17352: Accuracy:0.99219
# INFO:tensorflow:Step:107694: Valid Loss:0.38105:Valid Accuracy:0.93730
# INFO:tensorflow:Epoch:173
# INFO:tensorflow:Step:107750 Time:26.99671 Reg Loss:0.13239 Train Loss:0.13277: Accuracy:1.00000
# INFO:tensorflow:Step:108000 Time:22.86784 Reg Loss:0.13214 Train Loss:0.20828: Accuracy:0.98828
# INFO:tensorflow:Step:108250 Time:22.71310 Reg Loss:0.13192 Train Loss:0.17513: Accuracy:0.98698
# INFO:tensorflow:Step:108316: Valid Loss:0.38202:Valid Accuracy:0.93711
# INFO:tensorflow:Epoch:174
# INFO:tensorflow:Step:108500 Time:26.29417 Reg Loss:0.13167 Train Loss:0.19615: Accuracy:0.98438
# INFO:tensorflow:Step:108750 Time:22.71971 Reg Loss:0.13143 Train Loss:0.24583: Accuracy:0.96875
# INFO:tensorflow:Step:108939: Valid Loss:0.38593:Valid Accuracy:0.93535
# INFO:tensorflow:Epoch:175
# INFO:tensorflow:Step:109000 Time:26.27589 Reg Loss:0.13121 Train Loss:0.13204: Accuracy:1.00000
# INFO:tensorflow:Step:109250 Time:22.71168 Reg Loss:0.13096 Train Loss:0.19697: Accuracy:0.98828
# INFO:tensorflow:Step:109500 Time:22.69789 Reg Loss:0.13074 Train Loss:0.18678: Accuracy:0.98698
# INFO:tensorflow:Step:109561: Valid Loss:0.38757:Valid Accuracy:0.93509
# INFO:tensorflow:Epoch:176
# INFO:tensorflow:Step:109750 Time:26.29727 Reg Loss:0.13049 Train Loss:0.17777: Accuracy:0.98438
# INFO:tensorflow:Step:110000 Time:22.69890 Reg Loss:0.13026 Train Loss:0.19034: Accuracy:0.98047
# INFO:tensorflow:Step:110184: Valid Loss:0.38978:Valid Accuracy:0.93535
# INFO:tensorflow:Epoch:177
# INFO:tensorflow:Step:110250 Time:26.31096 Reg Loss:0.13004 Train Loss:0.13078: Accuracy:1.00000
# INFO:tensorflow:Step:110500 Time:22.70879 Reg Loss:0.12979 Train Loss:0.16571: Accuracy:0.99609
# INFO:tensorflow:Step:110750 Time:22.72824 Reg Loss:0.12958 Train Loss:0.20604: Accuracy:0.99219
# INFO:tensorflow:Step:110806: Valid Loss:0.39083:Valid Accuracy:0.93586
# INFO:tensorflow:Epoch:178
# INFO:tensorflow:Step:111000 Time:26.26639 Reg Loss:0.12934 Train Loss:0.14241: Accuracy:0.99219
# INFO:tensorflow:Step:111250 Time:22.70883 Reg Loss:0.12911 Train Loss:0.20460: Accuracy:0.98047
# INFO:tensorflow:Step:111429: Valid Loss:0.38667:Valid Accuracy:0.93584
# INFO:tensorflow:Epoch:179
# INFO:tensorflow:Step:111500 Time:26.30054 Reg Loss:0.12889 Train Loss:0.13102: Accuracy:1.00000
# INFO:tensorflow:Step:111750 Time:22.70588 Reg Loss:0.12864 Train Loss:0.17072: Accuracy:0.98828
# INFO:tensorflow:Step:112000 Time:22.70716 Reg Loss:0.12843 Train Loss:0.21847: Accuracy:0.98438
# INFO:tensorflow:Step:112051: Valid Loss:0.38871:Valid Accuracy:0.93683
# INFO:tensorflow:Epoch:180
# INFO:tensorflow:Step:112250 Time:26.29929 Reg Loss:0.12819 Train Loss:0.13652: Accuracy:1.00000
# INFO:tensorflow:Step:112500 Time:22.71950 Reg Loss:0.12796 Train Loss:0.20789: Accuracy:0.98438
# INFO:tensorflow:Step:112674: Valid Loss:0.38560:Valid Accuracy:0.93379
# INFO:tensorflow:Epoch:181
# INFO:tensorflow:Step:112750 Time:26.67714 Reg Loss:0.12774 Train Loss:0.13039: Accuracy:1.00000
# INFO:tensorflow:Step:113000 Time:23.10847 Reg Loss:0.12750 Train Loss:0.16794: Accuracy:0.99609
# INFO:tensorflow:Step:113250 Time:23.14084 Reg Loss:0.12729 Train Loss:0.18576: Accuracy:0.98958
# INFO:tensorflow:Step:113296: Valid Loss:0.38944:Valid Accuracy:0.93711
# INFO:tensorflow:Epoch:182
# INFO:tensorflow:Step:113500 Time:26.66591 Reg Loss:0.12705 Train Loss:0.16678: Accuracy:0.99219
# INFO:tensorflow:Step:113750 Time:22.85203 Reg Loss:0.12682 Train Loss:0.19626: Accuracy:0.98047
# INFO:tensorflow:Step:113919: Valid Loss:0.38448:Valid Accuracy:0.93477
# INFO:tensorflow:Epoch:183
# INFO:tensorflow:Step:114000 Time:26.36319 Reg Loss:0.12661 Train Loss:0.12742: Accuracy:1.00000
# INFO:tensorflow:Step:114250 Time:22.78554 Reg Loss:0.12638 Train Loss:0.17082: Accuracy:0.99219
# INFO:tensorflow:Step:114500 Time:22.63284 Reg Loss:0.12617 Train Loss:0.17828: Accuracy:0.99219
# INFO:tensorflow:Step:114541: Valid Loss:0.38276:Valid Accuracy:0.93654
# INFO:tensorflow:Epoch:184
# INFO:tensorflow:Step:114750 Time:26.31119 Reg Loss:0.12593 Train Loss:0.14960: Accuracy:0.99219
# INFO:tensorflow:Step:115000 Time:23.25227 Reg Loss:0.12572 Train Loss:0.19091: Accuracy:0.99219
# INFO:tensorflow:Step:115164: Valid Loss:0.38121:Valid Accuracy:0.93701
# INFO:tensorflow:Epoch:185
# INFO:tensorflow:Step:115250 Time:27.68497 Reg Loss:0.12550 Train Loss:0.12586: Accuracy:1.00000
# INFO:tensorflow:Step:115500 Time:23.54693 Reg Loss:0.12526 Train Loss:0.17470: Accuracy:0.98828
# INFO:tensorflow:Step:115750 Time:23.12553 Reg Loss:0.12506 Train Loss:0.14728: Accuracy:0.98698
# INFO:tensorflow:Step:115786: Valid Loss:0.38575:Valid Accuracy:0.93625
# INFO:tensorflow:Epoch:186
# INFO:tensorflow:Step:116000 Time:26.84012 Reg Loss:0.12483 Train Loss:0.15179: Accuracy:0.97656
# INFO:tensorflow:Step:116250 Time:23.07332 Reg Loss:0.12461 Train Loss:0.15285: Accuracy:0.98047
# INFO:tensorflow:Step:116409: Valid Loss:0.38288:Valid Accuracy:0.93750
# INFO:tensorflow:Epoch:187
# INFO:tensorflow:Step:116500 Time:28.14784 Reg Loss:0.12440 Train Loss:0.12480: Accuracy:1.00000
# INFO:tensorflow:Step:116750 Time:23.28639 Reg Loss:0.12416 Train Loss:0.14746: Accuracy:0.99219
# INFO:tensorflow:Step:117000 Time:22.69806 Reg Loss:0.12396 Train Loss:0.20338: Accuracy:0.98958
# INFO:tensorflow:Step:117031: Valid Loss:0.39450:Valid Accuracy:0.93346
# INFO:tensorflow:Epoch:188
# INFO:tensorflow:Step:117250 Time:26.43399 Reg Loss:0.12373 Train Loss:0.14332: Accuracy:1.00000
# INFO:tensorflow:Step:117500 Time:23.44852 Reg Loss:0.12352 Train Loss:0.19895: Accuracy:0.98438
# INFO:tensorflow:Step:117654: Valid Loss:0.38868:Valid Accuracy:0.93516
# INFO:tensorflow:Epoch:189
# INFO:tensorflow:Step:117750 Time:27.55921 Reg Loss:0.12331 Train Loss:0.12354: Accuracy:1.00000
# INFO:tensorflow:Step:118000 Time:25.21797 Reg Loss:0.12308 Train Loss:0.20313: Accuracy:0.98047
# INFO:tensorflow:Step:118250 Time:25.20539 Reg Loss:0.12288 Train Loss:0.14690: Accuracy:0.98438
# INFO:tensorflow:Step:118276: Valid Loss:0.38473:Valid Accuracy:0.93683
# INFO:tensorflow:Epoch:190
# INFO:tensorflow:Step:118500 Time:29.20959 Reg Loss:0.12264 Train Loss:0.13965: Accuracy:1.00000
# INFO:tensorflow:Step:118750 Time:25.21900 Reg Loss:0.12244 Train Loss:0.15290: Accuracy:0.99609
# INFO:tensorflow:Step:118899: Valid Loss:0.38231:Valid Accuracy:0.93643
# INFO:tensorflow:Epoch:191
# INFO:tensorflow:Step:119000 Time:28.64792 Reg Loss:0.12223 Train Loss:0.12282: Accuracy:1.00000
# INFO:tensorflow:Step:119250 Time:23.78104 Reg Loss:0.12200 Train Loss:0.14592: Accuracy:0.99609
# INFO:tensorflow:Step:119500 Time:23.90232 Reg Loss:0.12182 Train Loss:0.20807: Accuracy:0.98698
# INFO:tensorflow:Step:119521: Valid Loss:0.38618:Valid Accuracy:0.93789
# INFO:tensorflow:Epoch:192
# INFO:tensorflow:Step:119750 Time:27.37447 Reg Loss:0.12158 Train Loss:0.13836: Accuracy:0.99219
# INFO:tensorflow:Step:120000 Time:23.37454 Reg Loss:0.12138 Train Loss:0.15325: Accuracy:0.98828
# INFO:tensorflow:Step:120144: Valid Loss:0.37803:Valid Accuracy:0.93721
# INFO:tensorflow:Epoch:193
# INFO:tensorflow:Step:120250 Time:27.90720 Reg Loss:0.12117 Train Loss:0.12202: Accuracy:1.00000
# INFO:tensorflow:Step:120500 Time:23.33050 Reg Loss:0.12095 Train Loss:0.16368: Accuracy:0.99219
# INFO:tensorflow:Step:120750 Time:23.44426 Reg Loss:0.12077 Train Loss:0.15456: Accuracy:0.99219
# INFO:tensorflow:Step:120766: Valid Loss:0.38474:Valid Accuracy:0.93789
# INFO:tensorflow:Epoch:194
# INFO:tensorflow:Step:121000 Time:26.98640 Reg Loss:0.12053 Train Loss:0.13156: Accuracy:1.00000
# INFO:tensorflow:Step:121250 Time:23.11489 Reg Loss:0.12033 Train Loss:0.16197: Accuracy:0.99609
# INFO:tensorflow:Step:121389: Valid Loss:0.39082:Valid Accuracy:0.93448
# INFO:tensorflow:Epoch:195
# INFO:tensorflow:Step:121500 Time:27.25469 Reg Loss:0.12013 Train Loss:0.12049: Accuracy:1.00000
# INFO:tensorflow:Step:121750 Time:23.01865 Reg Loss:0.11991 Train Loss:0.24618: Accuracy:0.98828
# INFO:tensorflow:Step:122000 Time:23.77530 Reg Loss:0.11972 Train Loss:0.16884: Accuracy:0.98958
# INFO:tensorflow:Step:122011: Valid Loss:0.38336:Valid Accuracy:0.93837
# INFO:tensorflow:Epoch:196
# INFO:tensorflow:Step:122250 Time:27.06032 Reg Loss:0.11949 Train Loss:0.13074: Accuracy:0.99219
# INFO:tensorflow:Step:122500 Time:23.16745 Reg Loss:0.11929 Train Loss:0.21056: Accuracy:0.97656
# INFO:tensorflow:Step:122634: Valid Loss:0.38951:Valid Accuracy:0.93730
# INFO:tensorflow:Epoch:197
# INFO:tensorflow:Step:122750 Time:26.58257 Reg Loss:0.11909 Train Loss:0.11931: Accuracy:1.00000
# INFO:tensorflow:Step:123000 Time:23.12457 Reg Loss:0.11888 Train Loss:0.15665: Accuracy:0.99219
# INFO:tensorflow:Step:123250 Time:23.33656 Reg Loss:0.11869 Train Loss:0.20416: Accuracy:0.98438
# INFO:tensorflow:Step:123256: Valid Loss:0.39086:Valid Accuracy:0.93529
# INFO:tensorflow:Epoch:198
# INFO:tensorflow:Step:123500 Time:26.79527 Reg Loss:0.11846 Train Loss:0.13756: Accuracy:0.99219
# INFO:tensorflow:Step:123750 Time:23.65838 Reg Loss:0.11827 Train Loss:0.15520: Accuracy:0.99219
# INFO:tensorflow:Step:123879: Valid Loss:0.39044:Valid Accuracy:0.93652
# INFO:tensorflow:Epoch:199
# INFO:tensorflow:Step:124000 Time:28.90840 Reg Loss:0.11806 Train Loss:0.11838: Accuracy:1.00000
# INFO:tensorflow:Step:124250 Time:25.14735 Reg Loss:0.11785 Train Loss:0.17147: Accuracy:0.99219
# INFO:tensorflow:Step:124500 Time:25.08411 Reg Loss:0.11767 Train Loss:0.16975: Accuracy:0.98958
# INFO:tensorflow:Step:124501: Valid Loss:0.38919:Valid Accuracy:0.93740
# INFO:tensorflow:Step:124501: Valid Loss:0.42138:Valid Accuracy:0.93320

# %% [markdown]
# The best model was saved at *epoch 165* and the corresponding **Test Accuracy: 0.93220**
#
# > INFO:tensorflow:Epoch:165
# INFO:tensorflow:Step:102750 Time:26.35270 Reg Loss:0.13728 Train Loss:0.14225: Accuracy:1.00000
# INFO:tensorflow:Step:103000 Time:22.72455 Reg Loss:0.13701 Train Loss:0.18378: Accuracy:0.99609
# INFO:tensorflow:Step:103250 Time:22.73265 Reg Loss:0.13678 Train Loss:0.24242: Accuracy:0.98177
# INFO:tensorflow:Step:103336: Valid Loss:0.37343:Valid Accuracy:0.93846
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:103336: Test Loss:0.41116: Test Accuracy:0.93220
