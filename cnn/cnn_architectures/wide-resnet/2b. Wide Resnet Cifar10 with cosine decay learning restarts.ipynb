# %% [markdown]
# # Wide Residual network using tensorflow
#
# paper: https://arxiv.org/pdf/1605.07146.pdf
# ________________________________
# > Classification of Cifar 10 dataset. Here learnnig rate with cosine annealing and warm restarts are applied.
#
# > **The model that will be attempted is wide-dropout :**
#
# <img src='w-resnet.png'>

# %%
# load the necessary
import matplotlib.pylab as plt
# %matplotlib inline
import os
import numpy as np
import math as m
import sys
print('Python version:',sys.version)
import tensorflow as tf
print('TF version:',tf.__version__)
from data_utils import input_pipeline
slim = tf.contrib.slim
from tensorflow.contrib.layers.python.layers import initializers
from colorama import Fore, Style
from datetime import datetime
import time
import glob
# Out:
# Python version: 3.5.2 (default, Nov 23 2017, 16:37:01)
# [GCC 5.4.0 20160609]
# TF version: 1.8.0

# %% [markdown]
# ## Model definition

# %%
# Define the conv function
KEEP_PROB = 1.
WEIGHT_DECAY = 0.0005
def resnet_block(input_layer, out_features, training=True, scope=None):
    
    with tf.variable_scope(scope):
        
        with slim.arg_scope([slim.batch_norm],
                            is_training = training, scale=True,
                            decay=0.9, epsilon=1e-5,updates_collections=None,
                            param_initializers={
                                "beta": tf.constant_initializer(value=0),
                                "gamma": tf.random_normal_initializer(mean=1., stddev=0.01)}):

            # 1st Conv 3x3

            # batch norm        
            net = slim.batch_norm(input_layer)
            # Relu
            net = tf.nn.relu(net)
            #convolution
            net = slim.conv2d(net, out_features)
            #dropout
            net = slim.dropout(net,keep_prob=KEEP_PROB,is_training=training)

            # 2nd Conv 3x3
            # batch norm
            net = slim.batch_norm(net)
            # Relu
            net = tf.nn.relu(net)
            #convolution
            net = slim.conv2d(net, out_features)

            #concat with the input                    
            net += input_layer
    
    return net

def wide_resnet(inputs,
                num_classes=10,
                is_training=True,
                k = 6,
                depth = 22,
                scope='wide_resnet'):
    
    # number of filters at various stages
    filters = [16, 16*k, 32*k, 64*k]
    # from their code https://github.com/szagoruyko/wide-residual-networks/blob/master/models/wide-resnet.lua
    assert (depth - 4) % 6 == 0, 'depth should be 6n+4'
    n = int((depth - 4) / 6)
    
    # Set the weights to a small value initially and check whether the output is ln(num_of_classes) = ln(10) ~2.3
    #weights_initializer = tf.random_uniform_initializer(0,0.001)
    
    # He et all uniform weights
    #weights_initializer=tf.contrib.layers.variance_scaling_initializer(factor=2.0, 
    #                                       mode='FAN_IN', uniform=True)):
            
    with tf.variable_scope(scope, reuse=None):
        with tf.contrib.framework.arg_scope([slim.conv2d], 
                                             normalizer_fn=None,
                                             activation_fn=None,
                                             padding='SAME',
                                             kernel_size=(3,3),
                                             weights_initializer=initializers.variance_scaling_initializer(),
                                             weights_regularizer=slim.l2_regularizer(WEIGHT_DECAY),
                                             biases_initializer=None):


            #one conv at the beginning (spatial size: 32x32)
            net = slim.conv2d(inputs, filters[0], stride=(1,1), scope='first_conv' )
            # batch norm        
            net = slim.batch_norm(net, is_training =is_training, scale=True, updates_collections=None)
            # Relu
            net = tf.nn.relu(net)

            #block 1 -- Stage 1 (spatial size: 32x32)
            net = slim.conv2d(net,filters[1], stride=1)
            net = slim.repeat(net,n-1, resnet_block, filters[1], training=is_training, scope='block_1')
            print('block1:',net.get_shape().as_list())

            #block 2 -- Stage 2 (spatial size: 16x16)
            net = slim.conv2d(net,filters[2], stride=2)
            net = slim.repeat(net,n-1, resnet_block, filters[2], training=is_training, scope='block_2')
            print('block2:',net.get_shape().as_list())

            #block 3 -- Stage 3 (spatial size: 8x8)
            net = slim.conv2d(net,filters[3], stride=2)
            net = slim.repeat(net,n-1, resnet_block, filters[3], training=is_training, scope='block_3')
            print('block3:',net.get_shape().as_list())

            #average pooling 8x8
            net = slim.avg_pool2d(net, kernel_size=[8,8],padding='SAME',scope='avg_pool')

            # batch norm        
            net = slim.batch_norm(net, is_training =is_training, scale=True, updates_collections=None)
            # Relu
            net = tf.nn.relu(net)
            
            #flatten
            net = slim.flatten(net, scope='flatten')

            #logits
            net = slim.fully_connected(net, num_classes, activation_fn=None, scope='logits', 
                                       biases_regularizer=slim.l2_regularizer(WEIGHT_DECAY))

            return net

# %%
#checking the above graph
tf.reset_default_graph()
net = wide_resnet(tf.placeholder(tf.float32,(None, 32, 32, 3)),num_classes=10, is_training=True)
print('Variables in graph:')
for var in tf.global_variables():
    print(var.name)
# Out:
# block1: [None, 32, 32, 96]
# block2: [None, 16, 16, 192]
# block3: [None, 8, 8, 384]
# Variables in graph:
# wide_resnet/first_conv/weights:0
# wide_resnet/BatchNorm/beta:0
# wide_resnet/BatchNorm/gamma:0
# wide_resnet/BatchNorm/moving_mean:0
# wide_resnet/BatchNorm/moving_variance:0
# wide_resnet/Conv/weights:0
# wide_resnet/block_1/block_1_1/BatchNorm/beta:0
# wide_resnet/block_1/block_1_1/BatchNorm/gamma:0
# wide_resnet/block_1/block_1_1/BatchNorm/moving_mean:0
# wide_resnet/block_1/block_1_1/BatchNorm/moving_variance:0
# wide_resnet/block_1/block_1_1/Conv/weights:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/beta:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/gamma:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_1/block_1_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_1/block_1_1/Conv_1/weights:0
# wide_resnet/block_1/block_1_2/BatchNorm/beta:0
# wide_resnet/block_1/block_1_2/BatchNorm/gamma:0
# wide_resnet/block_1/block_1_2/BatchNorm/moving_mean:0
# wide_resnet/block_1/block_1_2/BatchNorm/moving_variance:0
# wide_resnet/block_1/block_1_2/Conv/weights:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/beta:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/gamma:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_1/block_1_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_1/block_1_2/Conv_1/weights:0
# wide_resnet/Conv_1/weights:0
# wide_resnet/block_2/block_2_1/BatchNorm/beta:0
# wide_resnet/block_2/block_2_1/BatchNorm/gamma:0
# wide_resnet/block_2/block_2_1/BatchNorm/moving_mean:0
# wide_resnet/block_2/block_2_1/BatchNorm/moving_variance:0
# wide_resnet/block_2/block_2_1/Conv/weights:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/beta:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/gamma:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_2/block_2_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_2/block_2_1/Conv_1/weights:0
# wide_resnet/block_2/block_2_2/BatchNorm/beta:0
# wide_resnet/block_2/block_2_2/BatchNorm/gamma:0
# wide_resnet/block_2/block_2_2/BatchNorm/moving_mean:0
# wide_resnet/block_2/block_2_2/BatchNorm/moving_variance:0
# wide_resnet/block_2/block_2_2/Conv/weights:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/beta:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/gamma:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_2/block_2_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_2/block_2_2/Conv_1/weights:0
# wide_resnet/Conv_2/weights:0
# wide_resnet/block_3/block_3_1/BatchNorm/beta:0
# wide_resnet/block_3/block_3_1/BatchNorm/gamma:0
# wide_resnet/block_3/block_3_1/BatchNorm/moving_mean:0
# wide_resnet/block_3/block_3_1/BatchNorm/moving_variance:0
# wide_resnet/block_3/block_3_1/Conv/weights:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/beta:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/gamma:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/moving_mean:0
# wide_resnet/block_3/block_3_1/BatchNorm_1/moving_variance:0
# wide_resnet/block_3/block_3_1/Conv_1/weights:0
# wide_resnet/block_3/block_3_2/BatchNorm/beta:0
# wide_resnet/block_3/block_3_2/BatchNorm/gamma:0
# wide_resnet/block_3/block_3_2/BatchNorm/moving_mean:0
# wide_resnet/block_3/block_3_2/BatchNorm/moving_variance:0
# wide_resnet/block_3/block_3_2/Conv/weights:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/beta:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/gamma:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/moving_mean:0
# wide_resnet/block_3/block_3_2/BatchNorm_1/moving_variance:0
# wide_resnet/block_3/block_3_2/Conv_1/weights:0
# wide_resnet/BatchNorm_1/beta:0
# wide_resnet/BatchNorm_1/gamma:0
# wide_resnet/BatchNorm_1/moving_mean:0
# wide_resnet/BatchNorm_1/moving_variance:0
# wide_resnet/logits/weights:0
# wide_resnet/logits/biases:0

# %% [markdown]
# ## Create the graph and run it in a session
# > The input pipelines for both train and validation can be dynamically switched.

# %%
#Create the graph

#Hyperparameters
N_EPOCH = 200
NUM_CLASSES = 10
BATCH_SIZE = 128
LEARNING_RATE = 0.1 #3e-4 
WIDTH = 32
HEIGHT = 32
LOG_FREQ = 250
N_TRAIN_SAMPLES = 50000
EARLY_STOP = False
CIFAR_LOCAL_FOLDER = '/home/vijay/datasets/image/cifar-10/cifar-10-batches-py'
MODEL_DIR = './slim_model/'

tf.reset_default_graph()

train_graph = tf.Graph()
with train_graph.as_default():
    global_step = tf.train.get_or_create_global_step()
    
    #-------------------------------------------
    #1. Create valid and train iterators
    #-------------------------------------------

    # placeholder for passing testing dataset
    test_filenames = tf.placeholder(tf.string, shape=[None], name='input')
    train_filenames = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'train*.tfrecords')))
    
    # Create valid and train iterators
    train_dataset = input_pipeline(train_filenames, BATCH_SIZE)
    test_dataset = input_pipeline(test_filenames, BATCH_SIZE*3,  validation=True)
    
    # A feedable iterator is defined by a handle placeholder and its structure.
    handle = tf.placeholder(tf.string, shape=[], name='handle')

    iterator = tf.data.Iterator.from_string_handle(handle, 
                                                   train_dataset.output_types, 
                                                   train_dataset.output_shapes)
    
    # Returns a batch of image and mask at every call
    image_batch, label_batch = iterator.get_next()
    
    image_batch = tf.identity(image_batch, 'images')
    label_batch = tf.identity(label_batch, 'labels')
    
    # Create a initializable iterator for valid dataset, 
    # so that the dataset is same for every valid loop.
    testing_iterator = test_dataset.make_initializable_iterator()
    training_iterator = train_dataset.make_initializable_iterator() #make_one_shot_iterator()
    
    
    # EDIT : the below not working for inference -https://github.com/tensorflow/tensorflow/issues/11679
    # Build the iterator SaveableObject.
    #saveable = tf.contrib.data.make_saveable_from_iterator(testing_iterator)

    # Save the iterator state by adding it to the saveable objects collection.
    #tf.add_to_collection(tf.GraphKeys.SAVEABLE_OBJECTS, saveable)
    
    #------------------------------------------------
    # 2. load Wide-resnet to the graph
    #------------------------------------------------
    
    # Placeholder definitions to handle incase of testing individual images
    X = tf.placeholder_with_default(image_batch, shape=[None,HEIGHT,WIDTH,3], name='X')
    y = tf.placeholder_with_default(label_batch, shape=[None], name='y')
    
    # A bool to switch between training loop and testing loop
    is_train = tf.placeholder(dtype=tf.bool, name='is_train')
    
    #wide-resnet logits
    logits = wide_resnet(X, num_classes=10, is_training=is_train)
    
    #------------------------------------------------
    # 3. Loss and accuracy
    #------------------------------------------------
        
    loss = tf.losses.softmax_cross_entropy(onehot_labels=tf.one_hot(y,NUM_CLASSES), logits=logits)
    
    #add regularization loss
    regularization_loss = tf.add_n(tf.losses.get_regularization_losses())
    loss += regularization_loss
        
    #learning_rate = tf.placeholder(dtype=tf.float32, name='learning_rate')
    
    # cosine dacay learning rate
    learning_rate = tf.train.cosine_decay_restarts(LEARNING_RATE, global_step,
                                          first_decay_steps=30000, t_mul=2.0,
                                          m_mul=1.0, alpha=0.0)
    
    # use Momentum optimizer    
    solver = tf.train.MomentumOptimizer(learning_rate, 0.9, use_nesterov=True)

    # create the train op
    train_op = slim.learning.create_train_op(loss, solver, global_step=global_step)
    
    # Probabilities of the outputs
    prob = tf.nn.softmax(logits, name='prob')
    
    # Prediction 
    pred = tf.argmax(prob, 1, name='pred')

    #accuracy create two different ops
    with tf.name_scope('train_metrics'):
        train_acc_op, train_accuracy = tf.metrics.accuracy(labels=tf.cast(y, tf.int32), predictions=tf.cast(pred, tf.int32))
    
    with tf.name_scope('test_metrics'):
        test_acc_op, test_accuracy = tf.metrics.accuracy(labels=tf.cast(y, tf.int32), predictions=tf.cast(pred, tf.int32))
    
    # Select accuracy for saving
    accuracy = tf.cond(is_train, lambda:train_accuracy, lambda:test_accuracy)
    accuracy = tf.identity(accuracy,name='accuracy')
    
    # Create summaries
    tf.summary.scalar('loss', loss)
    tf.summary.scalar('accuracy', accuracy)    
    tf.summary.scalar('learning_rate', learning_rate)
    my_summary_op = tf.summary.merge_all()
# Out:
# block1: [None, 32, 32, 96]
# block2: [None, 16, 16, 192]
# block3: [None, 8, 8, 384]

# %%
# Run the graph in the session

def testing_loop(_handle, file_names, writer, test=False):
    """ Testing/validation loop between trainings"""
    # do validation at each epoch
    _loss = 0.
    count = 0
    # Reset the iterator at every valid call, to go through the validation set
    sess.run(testing_iterator.initializer, {test_filenames: file_names})

    while True:
        try:
            _summaries, _l, _acc, _,_pred, _label = sess.run([my_summary_op, loss,test_accuracy, test_acc_op, pred, y], 
                                               {is_train:False, handle:_handle})  
            count += len(_label)
            _loss += _l*len(_label)
        except tf.errors.OutOfRangeError:
            break

    _loss = _loss/count
    
    if test:
        tf.logging.info(Fore.CYAN + Style.BRIGHT +'Step:{} Test Loss:{:.5f} Test Accuracy:{:.5f}'  
                .format(step,_loss, _acc)+Fore.RESET+Style.RESET_ALL)  
    else:
        tf.logging.info(Fore.GREEN + Style.BRIGHT +'Step:{} Valid Loss:{:.5f} Valid Accuracy:{:.5f}'  
                .format(step,_loss, _acc)+Fore.RESET+Style.RESET_ALL)  

    #write validation summaries
    writer.add_summary(_summaries, step)
    return _loss

with tf.Session(graph=train_graph) as sess:
    sess.run([tf.global_variables_initializer(), tf.local_variables_initializer()])
    # The `Iterator.string_handle()` method returns a tensor that can be evaluated
    # and used to feed the `handle` placeholder.
    valid_files = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'valid*.tfrecords')))
    test_files = sorted(glob.glob(os.path.join(CIFAR_LOCAL_FOLDER, '%s*' %'eval*.tfrecords')))
    train_handle = sess.run(training_iterator.string_handle())
    valid_handle = sess.run(testing_iterator.string_handle(), {test_filenames: valid_files})
    test_handle = sess.run(testing_iterator.string_handle(), {test_filenames: test_files})
    
    # variables for early exit
    best_v_loss = 10e10
    early_stopping = 0
    saver = tf.train.Saver()
    start_time = time.time()

    # Get the test/valid metrics variables to reset at each call
    stream_vars_test = [v for v in tf.local_variables() if 'test_metrics/' in v.name]
    # Get the train metrics variables to reset at each epoch
    stream_vars_train = [v for v in tf.local_variables() if 'train_metrics/' in v.name]

    #Summaries for validation and training
    summaries_dir = os.path.join(MODEL_DIR,'summaries')
    train_writer = tf.summary.FileWriter(summaries_dir + '/train', sess.graph)
    train_writer.flush()
    valid_writer = tf.summary.FileWriter(summaries_dir + '/valid', sess.graph)
    valid_writer.flush()
    test_writer = tf.summary.FileWriter(summaries_dir + '/test', sess.graph)
    test_writer.flush()

    
    for e in range(N_EPOCH):
        
        tf.logging.info(Fore.RED+ Style.BRIGHT +'Epoch:{} Time taken:{:.2f}s'.format(e,time.time()-start_time)+Fore.RESET+Style.RESET_ALL)
        start_time = time.time()
        # initialize the training iterator at every epoch
        sess.run(training_iterator.initializer)              
        while True:

            try:
                # The train images are passed
                _, l, _, step = sess.run([train_op, loss, train_acc_op, global_step], {is_train:True,handle:train_handle})  

                #print train logs
                if (step %LOG_FREQ) == 0:
                    train_summaries,acc, l, reg_loss = sess.run([my_summary_op, train_accuracy, loss,regularization_loss], 
                                                                {is_train:True,handle:train_handle})  
                    #Print train logs
                    tf.logging.info(Fore.BLUE + Style.BRIGHT +'Step:{} Reg Loss:{:.5f} Train Loss:{:.5f}: Accuracy:{:.5f}' 
                                    .format(step,reg_loss,l,acc)+Fore.RESET+Style.RESET_ALL)

                    # write train summaries
                    train_writer.add_summary(train_summaries, step)

            # catch end of dataset
            except tf.errors.OutOfRangeError:
                break
        
        # do validation at each epoch
        valid_loss = testing_loop(valid_handle, valid_files, valid_writer)
                
        # reset train and validation statistics every epoch
        sess.run(tf.variables_initializer(stream_vars_train))
        sess.run(tf.variables_initializer(stream_vars_test))

        # Save the best model based on valid loss and test the model on the testing set
        if (best_v_loss > valid_loss) and (step > 0):
            tf.logging.info(Fore.RED+ Style.BRIGHT +'Saving the model...'+Fore.RESET+Style.RESET_ALL)
            saver.save(sess, os.path.join(MODEL_DIR, 'wide_resnet'))
            best_v_loss = valid_loss
            early_stopping = 0
            
            # test when the validation set has a new minimum loss 
            
            testing_loop(test_handle, test_files, test_writer, test=True)
       
            #reset test statistics
            sess.run(tf.variables_initializer(stream_vars_test))

        
        else:
            early_stopping += 1

        # early stopping
        if early_stopping > 3 and EARLY_STOP:
            tf.logging.info(Fore.RED+ Style.BRIGHT +'Stopping the training...'+Fore.RESET+Style.RESET_ALL)
            break
    #One final testing    
    testing_loop(test_handle, test_files, test_writer, test=True)
# Out:
# INFO:tensorflow:Epoch:0 Time taken:1.14s
# INFO:tensorflow:Step:0 Reg Loss:1.69695 Train Loss:17.73261: Accuracy:0.14844
# INFO:tensorflow:Step:250 Reg Loss:2.77488 Train Loss:4.81545: Accuracy:0.18750
# INFO:tensorflow:Step:500 Reg Loss:2.16083 Train Loss:4.30770: Accuracy:0.20573
# INFO:tensorflow:Step:621 Valid Loss:4.16712 Valid Accuracy:0.21081
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:621 Test Loss:4.16727 Test Accuracy:0.20610
# INFO:tensorflow:Epoch:1 Time taken:64.28s
# INFO:tensorflow:Step:750 Reg Loss:1.68491 Train Loss:3.59711: Accuracy:0.20735
# INFO:tensorflow:Step:1000 Reg Loss:1.31556 Train Loss:3.16624: Accuracy:0.20817
# INFO:tensorflow:Step:1244 Valid Loss:3.26014 Valid Accuracy:0.20427
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:1244 Test Loss:3.25362 Test Accuracy:0.21180
# INFO:tensorflow:Epoch:2 Time taken:60.28s
# INFO:tensorflow:Step:1250 Reg Loss:1.02786 Train Loss:2.79243: Accuracy:0.21297
# INFO:tensorflow:Step:1500 Reg Loss:0.80709 Train Loss:2.60596: Accuracy:0.21422
# INFO:tensorflow:Step:1750 Reg Loss:0.63465 Train Loss:2.48662: Accuracy:0.21523
# INFO:tensorflow:Step:1866 Valid Loss:3.48074 Valid Accuracy:0.15774
# INFO:tensorflow:Epoch:3 Time taken:58.14s
# INFO:tensorflow:Step:2000 Reg Loss:0.50189 Train Loss:2.25572: Accuracy:0.42188
# INFO:tensorflow:Step:2250 Reg Loss:0.39865 Train Loss:2.19219: Accuracy:0.38672
# INFO:tensorflow:Step:2489 Valid Loss:2.88994 Valid Accuracy:0.17697
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:2489 Test Loss:2.87631 Test Accuracy:0.18050
# INFO:tensorflow:Epoch:4 Time taken:60.35s
# INFO:tensorflow:Step:2500 Reg Loss:0.31803 Train Loss:1.89682: Accuracy:0.18316
# INFO:tensorflow:Step:2750 Reg Loss:0.25827 Train Loss:2.10696: Accuracy:0.18487
# INFO:tensorflow:Step:3000 Reg Loss:0.21039 Train Loss:2.01068: Accuracy:0.18702
# INFO:tensorflow:Step:3111 Valid Loss:2.98175 Valid Accuracy:0.14638
# INFO:tensorflow:Epoch:5 Time taken:58.15s
# INFO:tensorflow:Step:3250 Reg Loss:0.17557 Train Loss:1.59542: Accuracy:0.49219
# INFO:tensorflow:Step:3500 Reg Loss:0.14924 Train Loss:1.76748: Accuracy:0.45312
# INFO:tensorflow:Step:3734 Valid Loss:2.86845 Valid Accuracy:0.15376
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:3734 Test Loss:2.85118 Test Accuracy:0.15380
# INFO:tensorflow:Epoch:6 Time taken:61.18s
# INFO:tensorflow:Step:3750 Reg Loss:0.12891 Train Loss:1.58732: Accuracy:0.15837
# INFO:tensorflow:Step:4000 Reg Loss:0.11720 Train Loss:1.71243: Accuracy:0.16264
# INFO:tensorflow:Step:4250 Reg Loss:0.10831 Train Loss:1.63590: Accuracy:0.16593
# INFO:tensorflow:Step:4356 Valid Loss:2.68556 Valid Accuracy:0.15678
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:4356 Test Loss:2.67227 Test Accuracy:0.14850
# INFO:tensorflow:Epoch:7 Time taken:60.42s
# INFO:tensorflow:Step:4500 Reg Loss:0.10420 Train Loss:1.29232: Accuracy:0.15383
# INFO:tensorflow:Step:4750 Reg Loss:0.10336 Train Loss:1.69277: Accuracy:0.15669
# INFO:tensorflow:Step:4979 Valid Loss:2.57648 Valid Accuracy:0.11203
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:4979 Test Loss:2.56700 Test Accuracy:0.10660
# INFO:tensorflow:Epoch:8 Time taken:60.51s
# INFO:tensorflow:Step:5000 Reg Loss:0.10376 Train Loss:1.12211: Accuracy:0.11365
# INFO:tensorflow:Step:5250 Reg Loss:0.10859 Train Loss:1.38348: Accuracy:0.11886
# INFO:tensorflow:Step:5500 Reg Loss:0.11263 Train Loss:1.35738: Accuracy:0.12404
# INFO:tensorflow:Step:5601 Valid Loss:2.55615 Valid Accuracy:0.11691
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:5601 Test Loss:2.54810 Test Accuracy:0.10410
# INFO:tensorflow:Epoch:9 Time taken:61.53s
# INFO:tensorflow:Step:5750 Reg Loss:0.11725 Train Loss:1.03795: Accuracy:0.11098
# INFO:tensorflow:Step:6000 Reg Loss:0.12311 Train Loss:1.42972: Accuracy:0.11622
# INFO:tensorflow:Step:6224 Valid Loss:2.21314 Valid Accuracy:0.24103
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:6224 Test Loss:2.21638 Test Accuracy:0.22960
# INFO:tensorflow:Epoch:10 Time taken:61.17s
# INFO:tensorflow:Step:6250 Reg Loss:0.12853 Train Loss:1.03665: Accuracy:0.23499
# INFO:tensorflow:Step:6500 Reg Loss:0.13398 Train Loss:1.20492: Accuracy:0.23937
# INFO:tensorflow:Step:6750 Reg Loss:0.14052 Train Loss:1.37378: Accuracy:0.24316
# INFO:tensorflow:Step:6846 Valid Loss:1.96329 Valid Accuracy:0.30884
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:6846 Test Loss:1.96855 Test Accuracy:0.29720
# INFO:tensorflow:Epoch:11 Time taken:61.89s
# INFO:tensorflow:Step:7000 Reg Loss:0.14595 Train Loss:0.87069: Accuracy:0.30312
# INFO:tensorflow:Step:7250 Reg Loss:0.15263 Train Loss:1.29299: Accuracy:0.30675
# INFO:tensorflow:Step:7469 Valid Loss:1.80692 Valid Accuracy:0.37988
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:7469 Test Loss:1.81811 Test Accuracy:0.36540
# INFO:tensorflow:Epoch:12 Time taken:60.49s
# INFO:tensorflow:Step:7500 Reg Loss:0.15832 Train Loss:0.96163: Accuracy:0.36977
# INFO:tensorflow:Step:7750 Reg Loss:0.16287 Train Loss:1.38062: Accuracy:0.37198
# INFO:tensorflow:Step:8000 Reg Loss:0.16882 Train Loss:1.34659: Accuracy:0.37442
# INFO:tensorflow:Step:8091 Valid Loss:1.66522 Valid Accuracy:0.44087
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:8091 Test Loss:1.67207 Test Accuracy:0.42730
# INFO:tensorflow:Epoch:13 Time taken:60.47s
# INFO:tensorflow:Step:8250 Reg Loss:0.17252 Train Loss:0.86466: Accuracy:0.43167
# INFO:tensorflow:Step:8500 Reg Loss:0.17757 Train Loss:1.19395: Accuracy:0.43399
# INFO:tensorflow:Step:8714 Valid Loss:1.41975 Valid Accuracy:0.62559
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:8714 Test Loss:1.43951 Test Accuracy:0.61220
# INFO:tensorflow:Epoch:14 Time taken:60.44s
# INFO:tensorflow:Step:8750 Reg Loss:0.18188 Train Loss:0.81007: Accuracy:0.61424
# INFO:tensorflow:Step:9000 Reg Loss:0.18723 Train Loss:1.17167: Accuracy:0.61505
# INFO:tensorflow:Step:9250 Reg Loss:0.19125 Train Loss:1.28783: Accuracy:0.61479
# INFO:tensorflow:Step:9336 Valid Loss:1.38883 Valid Accuracy:0.62279
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:9336 Test Loss:1.39952 Test Accuracy:0.62160
# INFO:tensorflow:Epoch:15 Time taken:60.63s
# INFO:tensorflow:Step:9500 Reg Loss:0.19400 Train Loss:0.67828: Accuracy:0.62441
# INFO:tensorflow:Step:9750 Reg Loss:0.20001 Train Loss:0.94092: Accuracy:0.62607
# INFO:tensorflow:Step:9959 Valid Loss:1.28119 Valid Accuracy:0.64470
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:9959 Test Loss:1.30546 Test Accuracy:0.62700
# INFO:tensorflow:Epoch:16 Time taken:61.42s
# INFO:tensorflow:Step:10000 Reg Loss:0.20360 Train Loss:0.68167: Accuracy:0.62934
# INFO:tensorflow:Step:10250 Reg Loss:0.20770 Train Loss:0.96257: Accuracy:0.63007
# INFO:tensorflow:Step:10500 Reg Loss:0.21229 Train Loss:1.15572: Accuracy:0.63059
# INFO:tensorflow:Step:10581 Valid Loss:1.12026 Valid Accuracy:0.70917
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:10581 Test Loss:1.13957 Test Accuracy:0.70100
# INFO:tensorflow:Epoch:17 Time taken:60.52s
# INFO:tensorflow:Step:10750 Reg Loss:0.21494 Train Loss:0.77727: Accuracy:0.70251
# INFO:tensorflow:Step:11000 Reg Loss:0.21933 Train Loss:1.11082: Accuracy:0.70222
# INFO:tensorflow:Step:11204 Valid Loss:1.12709 Valid Accuracy:0.67736
# INFO:tensorflow:Epoch:18 Time taken:58.41s
# INFO:tensorflow:Step:11250 Reg Loss:0.22304 Train Loss:0.64271: Accuracy:0.84375
# INFO:tensorflow:Step:11500 Reg Loss:0.22631 Train Loss:1.07931: Accuracy:0.77344
# INFO:tensorflow:Step:11750 Reg Loss:0.23098 Train Loss:0.99789: Accuracy:0.75521
# INFO:tensorflow:Step:11826 Valid Loss:1.04447 Valid Accuracy:0.71841
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:11826 Test Loss:1.05673 Test Accuracy:0.71280
# INFO:tensorflow:Epoch:19 Time taken:60.48s
# INFO:tensorflow:Step:12000 Reg Loss:0.23167 Train Loss:0.72487: Accuracy:0.71436
# INFO:tensorflow:Step:12250 Reg Loss:0.23649 Train Loss:1.15421: Accuracy:0.71373
# INFO:tensorflow:Step:12449 Valid Loss:1.06446 Valid Accuracy:0.71938
# INFO:tensorflow:Epoch:20 Time taken:58.36s
# INFO:tensorflow:Step:12500 Reg Loss:0.23757 Train Loss:0.53587: Accuracy:0.90625
# INFO:tensorflow:Step:12750 Reg Loss:0.24073 Train Loss:1.03083: Accuracy:0.80469
# INFO:tensorflow:Step:13000 Reg Loss:0.24380 Train Loss:1.01137: Accuracy:0.80208
# INFO:tensorflow:Step:13071 Valid Loss:1.02949 Valid Accuracy:0.72920
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:13071 Test Loss:1.04227 Test Accuracy:0.72310
# INFO:tensorflow:Epoch:21 Time taken:61.17s
# INFO:tensorflow:Step:13250 Reg Loss:0.24388 Train Loss:0.61230: Accuracy:0.72522
# INFO:tensorflow:Step:13500 Reg Loss:0.24751 Train Loss:1.02952: Accuracy:0.72523
# INFO:tensorflow:Step:13694 Valid Loss:0.89126 Valid Accuracy:0.78325
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:13694 Test Loss:0.92136 Test Accuracy:0.77400
# INFO:tensorflow:Epoch:22 Time taken:60.61s
# INFO:tensorflow:Step:13750 Reg Loss:0.24790 Train Loss:0.50861: Accuracy:0.77597
# INFO:tensorflow:Step:14000 Reg Loss:0.25039 Train Loss:0.97701: Accuracy:0.77574
# INFO:tensorflow:Step:14250 Reg Loss:0.25224 Train Loss:1.02699: Accuracy:0.77523
# INFO:tensorflow:Step:14316 Valid Loss:0.94365 Valid Accuracy:0.76897
# INFO:tensorflow:Epoch:23 Time taken:58.25s
# INFO:tensorflow:Step:14500 Reg Loss:0.25215 Train Loss:0.69617: Accuracy:0.85156
# INFO:tensorflow:Step:14750 Reg Loss:0.25481 Train Loss:0.98958: Accuracy:0.80078
# INFO:tensorflow:Step:14939 Valid Loss:0.82740 Valid Accuracy:0.80480
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:14939 Test Loss:0.84205 Test Accuracy:0.80140
# INFO:tensorflow:Epoch:24 Time taken:60.57s
# INFO:tensorflow:Step:15000 Reg Loss:0.25431 Train Loss:0.56210: Accuracy:0.80263
# INFO:tensorflow:Step:15250 Reg Loss:0.25545 Train Loss:0.88595: Accuracy:0.80246
# INFO:tensorflow:Step:15500 Reg Loss:0.25703 Train Loss:0.86518: Accuracy:0.80229
# INFO:tensorflow:Step:15561 Valid Loss:0.82187 Valid Accuracy:0.80451
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:15561 Test Loss:0.84617 Test Accuracy:0.79870
# INFO:tensorflow:Epoch:25 Time taken:60.42s
# INFO:tensorflow:Step:15750 Reg Loss:0.25541 Train Loss:0.66956: Accuracy:0.79947
# INFO:tensorflow:Step:16000 Reg Loss:0.25768 Train Loss:0.91203: Accuracy:0.79914
# INFO:tensorflow:Step:16184 Valid Loss:0.90841 Valid Accuracy:0.77642
# INFO:tensorflow:Epoch:26 Time taken:58.30s
# INFO:tensorflow:Step:16250 Reg Loss:0.25668 Train Loss:0.50368: Accuracy:0.91406
# INFO:tensorflow:Step:16500 Reg Loss:0.25772 Train Loss:0.71914: Accuracy:0.86719
# INFO:tensorflow:Step:16750 Reg Loss:0.25833 Train Loss:1.01016: Accuracy:0.80990
# INFO:tensorflow:Step:16806 Valid Loss:0.79354 Valid Accuracy:0.81645
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:16806 Test Loss:0.82232 Test Accuracy:0.81180
# INFO:tensorflow:Epoch:27 Time taken:61.87s
# INFO:tensorflow:Step:17000 Reg Loss:0.25581 Train Loss:0.66059: Accuracy:0.81250
# INFO:tensorflow:Step:17250 Reg Loss:0.25704 Train Loss:0.82910: Accuracy:0.81230
# INFO:tensorflow:Step:17429 Valid Loss:0.86658 Valid Accuracy:0.79358
# INFO:tensorflow:Epoch:28 Time taken:58.29s
# INFO:tensorflow:Step:17500 Reg Loss:0.25506 Train Loss:0.37905: Accuracy:0.96094
# INFO:tensorflow:Step:17750 Reg Loss:0.25528 Train Loss:0.73915: Accuracy:0.88281
# INFO:tensorflow:Step:18000 Reg Loss:0.25579 Train Loss:0.85711: Accuracy:0.85938
# INFO:tensorflow:Step:18051 Valid Loss:0.79064 Valid Accuracy:0.81818
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:18051 Test Loss:0.81617 Test Accuracy:0.80840
# INFO:tensorflow:Epoch:29 Time taken:60.51s
# INFO:tensorflow:Step:18250 Reg Loss:0.25292 Train Loss:0.56197: Accuracy:0.81003
# INFO:tensorflow:Step:18500 Reg Loss:0.25337 Train Loss:0.77848: Accuracy:0.81045
# INFO:tensorflow:Step:18674 Valid Loss:0.80166 Valid Accuracy:0.81572
# INFO:tensorflow:Epoch:30 Time taken:58.39s
# INFO:tensorflow:Step:18750 Reg Loss:0.25042 Train Loss:0.39110: Accuracy:0.93750
# INFO:tensorflow:Step:19000 Reg Loss:0.24921 Train Loss:0.76252: Accuracy:0.87891
# INFO:tensorflow:Step:19250 Reg Loss:0.24900 Train Loss:0.84641: Accuracy:0.83854
# INFO:tensorflow:Step:19296 Valid Loss:0.66178 Valid Accuracy:0.85487
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:19296 Test Loss:0.66590 Test Accuracy:0.85340
# INFO:tensorflow:Epoch:31 Time taken:60.40s
# INFO:tensorflow:Step:19500 Reg Loss:0.24404 Train Loss:0.67204: Accuracy:0.85357
# INFO:tensorflow:Step:19750 Reg Loss:0.24502 Train Loss:1.09108: Accuracy:0.85189
# INFO:tensorflow:Step:19919 Valid Loss:0.76403 Valid Accuracy:0.82576
# INFO:tensorflow:Epoch:32 Time taken:59.32s
# INFO:tensorflow:Step:20000 Reg Loss:0.24252 Train Loss:0.35319: Accuracy:0.95312
# INFO:tensorflow:Step:20250 Reg Loss:0.24066 Train Loss:0.74720: Accuracy:0.87891
# INFO:tensorflow:Step:20500 Reg Loss:0.24006 Train Loss:0.89361: Accuracy:0.83854
# INFO:tensorflow:Step:20541 Valid Loss:0.77527 Valid Accuracy:0.82252
# INFO:tensorflow:Epoch:33 Time taken:58.28s
# INFO:tensorflow:Step:20750 Reg Loss:0.23443 Train Loss:0.50974: Accuracy:0.90625
# INFO:tensorflow:Step:21000 Reg Loss:0.23506 Train Loss:0.77308: Accuracy:0.85156
# INFO:tensorflow:Step:21164 Valid Loss:0.72544 Valid Accuracy:0.83619
# INFO:tensorflow:Epoch:34 Time taken:58.27s
# INFO:tensorflow:Step:21250 Reg Loss:0.23189 Train Loss:0.30792: Accuracy:0.96875
# INFO:tensorflow:Step:21500 Reg Loss:0.22891 Train Loss:0.77092: Accuracy:0.89844
# INFO:tensorflow:Step:21750 Reg Loss:0.22852 Train Loss:0.62157: Accuracy:0.89323
# INFO:tensorflow:Step:21786 Valid Loss:0.61480 Valid Accuracy:0.86893
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:21786 Test Loss:0.62425 Test Accuracy:0.86610
# INFO:tensorflow:Epoch:35 Time taken:61.68s
# INFO:tensorflow:Step:22000 Reg Loss:0.22283 Train Loss:0.40689: Accuracy:0.86710
# INFO:tensorflow:Step:22250 Reg Loss:0.22244 Train Loss:0.69963: Accuracy:0.86661
# INFO:tensorflow:Step:22409 Valid Loss:0.59677 Valid Accuracy:0.87081
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:22409 Test Loss:0.62417 Test Accuracy:0.86660
# INFO:tensorflow:Epoch:36 Time taken:60.59s
# INFO:tensorflow:Step:22500 Reg Loss:0.21939 Train Loss:0.25960: Accuracy:0.86809
# INFO:tensorflow:Step:22750 Reg Loss:0.21615 Train Loss:0.55764: Accuracy:0.86817
# INFO:tensorflow:Step:23000 Reg Loss:0.21569 Train Loss:0.63467: Accuracy:0.86797
# INFO:tensorflow:Step:23031 Valid Loss:0.56962 Valid Accuracy:0.88010
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:23031 Test Loss:0.58779 Test Accuracy:0.87610
# INFO:tensorflow:Epoch:37 Time taken:60.89s
# INFO:tensorflow:Step:23250 Reg Loss:0.21098 Train Loss:0.40996: Accuracy:0.87688
# INFO:tensorflow:Step:23500 Reg Loss:0.20989 Train Loss:0.58978: Accuracy:0.87666
# INFO:tensorflow:Step:23654 Valid Loss:0.57189 Valid Accuracy:0.88183
# INFO:tensorflow:Epoch:38 Time taken:58.47s
# INFO:tensorflow:Step:23750 Reg Loss:0.20734 Train Loss:0.24678: Accuracy:0.99219
# INFO:tensorflow:Step:24000 Reg Loss:0.20434 Train Loss:0.66651: Accuracy:0.93359
# INFO:tensorflow:Step:24250 Reg Loss:0.20324 Train Loss:0.59917: Accuracy:0.90625
# INFO:tensorflow:Step:24276 Valid Loss:0.53732 Valid Accuracy:0.89185
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:24276 Test Loss:0.55016 Test Accuracy:0.88480
# INFO:tensorflow:Epoch:39 Time taken:60.64s
# INFO:tensorflow:Step:24500 Reg Loss:0.19987 Train Loss:0.33792: Accuracy:0.88556
# INFO:tensorflow:Step:24750 Reg Loss:0.19852 Train Loss:0.54598: Accuracy:0.88534
# INFO:tensorflow:Step:24899 Valid Loss:0.55321 Valid Accuracy:0.88612
# INFO:tensorflow:Epoch:40 Time taken:58.50s
# INFO:tensorflow:Step:25000 Reg Loss:0.19651 Train Loss:0.21501: Accuracy:1.00000
# INFO:tensorflow:Step:25250 Reg Loss:0.19423 Train Loss:0.46361: Accuracy:0.94531
# INFO:tensorflow:Step:25500 Reg Loss:0.19297 Train Loss:0.56490: Accuracy:0.92188
# INFO:tensorflow:Step:25521 Valid Loss:0.49833 Valid Accuracy:0.90302
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:25521 Test Loss:0.51011 Test Accuracy:0.89950
# INFO:tensorflow:Epoch:41 Time taken:60.59s
# INFO:tensorflow:Step:25750 Reg Loss:0.19077 Train Loss:0.32888: Accuracy:0.90028
# INFO:tensorflow:Step:26000 Reg Loss:0.18953 Train Loss:0.59150: Accuracy:0.90016
# INFO:tensorflow:Step:26144 Valid Loss:0.48675 Valid Accuracy:0.90386
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:26144 Test Loss:0.50252 Test Accuracy:0.89720
# INFO:tensorflow:Epoch:42 Time taken:61.10s
# INFO:tensorflow:Step:26250 Reg Loss:0.18816 Train Loss:0.19803: Accuracy:0.89850
# INFO:tensorflow:Step:26500 Reg Loss:0.18676 Train Loss:0.47625: Accuracy:0.89869
# INFO:tensorflow:Step:26750 Reg Loss:0.18582 Train Loss:0.44596: Accuracy:0.89898
# INFO:tensorflow:Step:26766 Valid Loss:0.47875 Valid Accuracy:0.91025
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:26766 Test Loss:0.48287 Test Accuracy:0.90510
# INFO:tensorflow:Epoch:43 Time taken:60.58s
# INFO:tensorflow:Step:27000 Reg Loss:0.18464 Train Loss:0.29245: Accuracy:0.90590
# INFO:tensorflow:Step:27250 Reg Loss:0.18385 Train Loss:0.53063: Accuracy:0.90591
# INFO:tensorflow:Step:27389 Valid Loss:0.46810 Valid Accuracy:0.90991
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:27389 Test Loss:0.48206 Test Accuracy:0.90610
# INFO:tensorflow:Epoch:44 Time taken:60.65s
# INFO:tensorflow:Step:27500 Reg Loss:0.18310 Train Loss:0.19644: Accuracy:0.90729
# INFO:tensorflow:Step:27750 Reg Loss:0.18245 Train Loss:0.45588: Accuracy:0.90766
# INFO:tensorflow:Step:28000 Reg Loss:0.18197 Train Loss:0.41338: Accuracy:0.90784
# INFO:tensorflow:Step:28011 Valid Loss:0.45557 Valid Accuracy:0.91670
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:28011 Test Loss:0.46853 Test Accuracy:0.90980
# INFO:tensorflow:Epoch:45 Time taken:60.53s
# INFO:tensorflow:Step:28250 Reg Loss:0.18154 Train Loss:0.26218: Accuracy:0.91064
# INFO:tensorflow:Step:28500 Reg Loss:0.18123 Train Loss:0.44588: Accuracy:0.91069
# INFO:tensorflow:Step:28634 Valid Loss:0.45976 Valid Accuracy:0.91332
# INFO:tensorflow:Epoch:46 Time taken:58.46s
# INFO:tensorflow:Step:28750 Reg Loss:0.18100 Train Loss:0.18972: Accuracy:1.00000
# INFO:tensorflow:Step:29000 Reg Loss:0.18085 Train Loss:0.41017: Accuracy:0.95703
# INFO:tensorflow:Step:29250 Reg Loss:0.18075 Train Loss:0.54439: Accuracy:0.94010
# INFO:tensorflow:Step:29256 Valid Loss:0.45798 Valid Accuracy:0.91593
# INFO:tensorflow:Epoch:47 Time taken:58.61s
# INFO:tensorflow:Step:29500 Reg Loss:0.18070 Train Loss:0.35223: Accuracy:0.92969
# INFO:tensorflow:Step:29750 Reg Loss:0.18069 Train Loss:0.46649: Accuracy:0.90625
# INFO:tensorflow:Step:29879 Valid Loss:0.45896 Valid Accuracy:0.91459
# INFO:tensorflow:Epoch:48 Time taken:58.55s
# INFO:tensorflow:Step:30000 Reg Loss:0.18050 Train Loss:0.18445: Accuracy:1.00000
# INFO:tensorflow:Step:30250 Reg Loss:0.28275 Train Loss:1.02282: Accuracy:0.88281
# INFO:tensorflow:Step:30500 Reg Loss:0.31390 Train Loss:1.13671: Accuracy:0.82292
# INFO:tensorflow:Step:30501 Valid Loss:2.52928 Valid Accuracy:0.58686
# INFO:tensorflow:Epoch:49 Time taken:59.32s
# INFO:tensorflow:Step:30750 Reg Loss:0.33050 Train Loss:0.99481: Accuracy:0.79688
# INFO:tensorflow:Step:31000 Reg Loss:0.34709 Train Loss:1.09609: Accuracy:0.77344
# INFO:tensorflow:Step:31124 Valid Loss:1.13924 Valid Accuracy:0.75848
# INFO:tensorflow:Epoch:50 Time taken:58.34s
# INFO:tensorflow:Step:31250 Reg Loss:0.35444 Train Loss:0.64563: Accuracy:0.91406
# INFO:tensorflow:Step:31500 Reg Loss:0.36211 Train Loss:1.24986: Accuracy:0.79297
# INFO:tensorflow:Step:31747 Valid Loss:1.13118 Valid Accuracy:0.74629
# INFO:tensorflow:Epoch:51 Time taken:59.96s
# INFO:tensorflow:Step:31750 Reg Loss:0.37097 Train Loss:0.78280: Accuracy:0.83594
# INFO:tensorflow:Step:32000 Reg Loss:0.37234 Train Loss:1.01523: Accuracy:0.79297
# INFO:tensorflow:Step:32250 Reg Loss:0.37917 Train Loss:1.14542: Accuracy:0.78906
# INFO:tensorflow:Step:32369 Valid Loss:1.85918 Valid Accuracy:0.61527
# INFO:tensorflow:Epoch:52 Time taken:61.45s
# INFO:tensorflow:Step:32500 Reg Loss:0.37819 Train Loss:0.65562: Accuracy:0.91406
# INFO:tensorflow:Step:32750 Reg Loss:0.38112 Train Loss:1.00946: Accuracy:0.84766
# INFO:tensorflow:Step:32992 Valid Loss:1.02458 Valid Accuracy:0.78822
# INFO:tensorflow:Epoch:53 Time taken:60.53s
# INFO:tensorflow:Step:33000 Reg Loss:0.38358 Train Loss:0.74974: Accuracy:0.89062
# INFO:tensorflow:Step:33250 Reg Loss:0.38416 Train Loss:0.94438: Accuracy:0.85156
# INFO:tensorflow:Step:33500 Reg Loss:0.38864 Train Loss:1.10852: Accuracy:0.81771
# INFO:tensorflow:Step:33614 Valid Loss:0.96057 Valid Accuracy:0.80518
# INFO:tensorflow:Epoch:54 Time taken:60.73s
# INFO:tensorflow:Step:33750 Reg Loss:0.38590 Train Loss:0.74227: Accuracy:0.88281
# INFO:tensorflow:Step:34000 Reg Loss:0.39096 Train Loss:1.07597: Accuracy:0.80469
# INFO:tensorflow:Step:34237 Valid Loss:1.09422 Valid Accuracy:0.76073
# INFO:tensorflow:Epoch:55 Time taken:59.30s
# INFO:tensorflow:Step:34250 Reg Loss:0.39168 Train Loss:0.77967: Accuracy:0.86719
# INFO:tensorflow:Step:34500 Reg Loss:0.39048 Train Loss:1.02739: Accuracy:0.81250
# INFO:tensorflow:Step:34750 Reg Loss:0.39421 Train Loss:0.98443: Accuracy:0.81250
# INFO:tensorflow:Step:34859 Valid Loss:1.13769 Valid Accuracy:0.75742
# INFO:tensorflow:Epoch:56 Time taken:59.64s
# INFO:tensorflow:Step:35000 Reg Loss:0.39236 Train Loss:0.58446: Accuracy:0.91406
# INFO:tensorflow:Step:35250 Reg Loss:0.39631 Train Loss:1.25971: Accuracy:0.79297
# INFO:tensorflow:Step:35482 Valid Loss:1.01386 Valid Accuracy:0.78978
# INFO:tensorflow:Epoch:57 Time taken:62.26s
# INFO:tensorflow:Step:35500 Reg Loss:0.39640 Train Loss:0.59669: Accuracy:0.94531
# INFO:tensorflow:Step:35750 Reg Loss:0.39573 Train Loss:1.02946: Accuracy:0.87109
# INFO:tensorflow:Step:36000 Reg Loss:0.39844 Train Loss:1.16935: Accuracy:0.82031
# INFO:tensorflow:Step:36104 Valid Loss:0.98236 Valid Accuracy:0.80181
# INFO:tensorflow:Epoch:58 Time taken:61.45s
# INFO:tensorflow:Step:36250 Reg Loss:0.39703 Train Loss:0.57997: Accuracy:0.92188
# INFO:tensorflow:Step:36500 Reg Loss:0.40189 Train Loss:1.13444: Accuracy:0.83203
# INFO:tensorflow:Step:36727 Valid Loss:1.01227 Valid Accuracy:0.79982
# INFO:tensorflow:Epoch:59 Time taken:61.81s
# INFO:tensorflow:Step:36750 Reg Loss:0.40263 Train Loss:0.74714: Accuracy:0.89844
# INFO:tensorflow:Step:37000 Reg Loss:0.40138 Train Loss:1.01942: Accuracy:0.85938
# INFO:tensorflow:Step:37250 Reg Loss:0.40637 Train Loss:1.26902: Accuracy:0.80469
# INFO:tensorflow:Step:37349 Valid Loss:1.10988 Valid Accuracy:0.76550
# INFO:tensorflow:Epoch:60 Time taken:64.85s
# INFO:tensorflow:Step:37500 Reg Loss:0.40164 Train Loss:0.56358: Accuracy:0.95312
# INFO:tensorflow:Step:37750 Reg Loss:0.40607 Train Loss:0.96459: Accuracy:0.86719
# INFO:tensorflow:Step:37972 Valid Loss:0.93772 Valid Accuracy:0.82030
# INFO:tensorflow:Epoch:61 Time taken:61.21s
# INFO:tensorflow:Step:38000 Reg Loss:0.40401 Train Loss:0.65386: Accuracy:0.92969
# INFO:tensorflow:Step:38250 Reg Loss:0.40250 Train Loss:1.06283: Accuracy:0.84375
# INFO:tensorflow:Step:38500 Reg Loss:0.40694 Train Loss:1.07413: Accuracy:0.83594
# INFO:tensorflow:Step:38594 Valid Loss:1.06878 Valid Accuracy:0.78842
# INFO:tensorflow:Epoch:62 Time taken:58.43s
# INFO:tensorflow:Step:38750 Reg Loss:0.40577 Train Loss:0.61670: Accuracy:0.91406
# INFO:tensorflow:Step:39000 Reg Loss:0.41205 Train Loss:1.11440: Accuracy:0.83594
# INFO:tensorflow:Step:39217 Valid Loss:1.03771 Valid Accuracy:0.79817
# INFO:tensorflow:Epoch:63 Time taken:58.32s
# INFO:tensorflow:Step:39250 Reg Loss:0.40865 Train Loss:0.60307: Accuracy:0.93750
# INFO:tensorflow:Step:39500 Reg Loss:0.40788 Train Loss:0.96744: Accuracy:0.87109
# INFO:tensorflow:Step:39750 Reg Loss:0.41071 Train Loss:1.16956: Accuracy:0.82292
# INFO:tensorflow:Step:39839 Valid Loss:1.02301 Valid Accuracy:0.80133
# INFO:tensorflow:Epoch:64 Time taken:58.22s
# INFO:tensorflow:Step:40000 Reg Loss:0.40777 Train Loss:0.67320: Accuracy:0.92969
# INFO:tensorflow:Step:40250 Reg Loss:0.41362 Train Loss:1.19125: Accuracy:0.82422
# INFO:tensorflow:Step:40462 Valid Loss:1.14402 Valid Accuracy:0.77740
# INFO:tensorflow:Epoch:65 Time taken:58.50s
# INFO:tensorflow:Step:40500 Reg Loss:0.41316 Train Loss:0.66510: Accuracy:0.90625
# INFO:tensorflow:Step:40750 Reg Loss:0.41202 Train Loss:0.96529: Accuracy:0.85938
# INFO:tensorflow:Step:41000 Reg Loss:0.41697 Train Loss:1.10477: Accuracy:0.82812
# INFO:tensorflow:Step:41084 Valid Loss:0.98255 Valid Accuracy:0.80605
# INFO:tensorflow:Epoch:66 Time taken:58.20s
# INFO:tensorflow:Step:41250 Reg Loss:0.41221 Train Loss:0.90080: Accuracy:0.85938
# INFO:tensorflow:Step:41500 Reg Loss:0.41560 Train Loss:1.03104: Accuracy:0.83203
# INFO:tensorflow:Step:41707 Valid Loss:1.01065 Valid Accuracy:0.80304
# INFO:tensorflow:Epoch:67 Time taken:58.45s
# INFO:tensorflow:Step:41750 Reg Loss:0.41409 Train Loss:0.61037: Accuracy:0.92188
# INFO:tensorflow:Step:42000 Reg Loss:0.41261 Train Loss:0.98398: Accuracy:0.85547
# INFO:tensorflow:Step:42250 Reg Loss:0.41737 Train Loss:1.14475: Accuracy:0.81510
# INFO:tensorflow:Step:42329 Valid Loss:1.02876 Valid Accuracy:0.79757
# INFO:tensorflow:Epoch:68 Time taken:58.35s
# INFO:tensorflow:Step:42500 Reg Loss:0.41423 Train Loss:0.65742: Accuracy:0.89062
# INFO:tensorflow:Step:42750 Reg Loss:0.42022 Train Loss:1.09467: Accuracy:0.84375
# INFO:tensorflow:Step:42952 Valid Loss:1.04431 Valid Accuracy:0.80421
# INFO:tensorflow:Epoch:69 Time taken:58.27s
# INFO:tensorflow:Step:43000 Reg Loss:0.42089 Train Loss:0.62216: Accuracy:0.95312
# INFO:tensorflow:Step:43250 Reg Loss:0.41738 Train Loss:0.95621: Accuracy:0.87891
# INFO:tensorflow:Step:43500 Reg Loss:0.42217 Train Loss:1.19468: Accuracy:0.82552
# INFO:tensorflow:Step:43574 Valid Loss:0.94730 Valid Accuracy:0.83455
# INFO:tensorflow:Epoch:70 Time taken:58.23s
# INFO:tensorflow:Step:43750 Reg Loss:0.41747 Train Loss:0.68128: Accuracy:0.91406
# INFO:tensorflow:Step:44000 Reg Loss:0.42268 Train Loss:1.00803: Accuracy:0.84375
# INFO:tensorflow:Step:44197 Valid Loss:0.95164 Valid Accuracy:0.81972
# INFO:tensorflow:Epoch:71 Time taken:58.33s
# INFO:tensorflow:Step:44250 Reg Loss:0.42203 Train Loss:0.67340: Accuracy:0.93750
# INFO:tensorflow:Step:44500 Reg Loss:0.42195 Train Loss:0.95694: Accuracy:0.87500
# INFO:tensorflow:Step:44750 Reg Loss:0.42453 Train Loss:1.00564: Accuracy:0.83854
# INFO:tensorflow:Step:44819 Valid Loss:0.93432 Valid Accuracy:0.83166
# INFO:tensorflow:Epoch:72 Time taken:58.32s
# INFO:tensorflow:Step:45000 Reg Loss:0.41967 Train Loss:0.73037: Accuracy:0.88281
# INFO:tensorflow:Step:45250 Reg Loss:0.42369 Train Loss:0.97753: Accuracy:0.88281
# INFO:tensorflow:Step:45442 Valid Loss:0.92247 Valid Accuracy:0.83785
# INFO:tensorflow:Epoch:73 Time taken:58.78s
# INFO:tensorflow:Step:45500 Reg Loss:0.42242 Train Loss:0.68746: Accuracy:0.91406
# INFO:tensorflow:Step:45750 Reg Loss:0.42072 Train Loss:0.90391: Accuracy:0.87891
# INFO:tensorflow:Step:46000 Reg Loss:0.42518 Train Loss:1.02770: Accuracy:0.84896
# INFO:tensorflow:Step:46064 Valid Loss:0.94703 Valid Accuracy:0.82030
# INFO:tensorflow:Epoch:74 Time taken:58.41s
# INFO:tensorflow:Step:46250 Reg Loss:0.41896 Train Loss:0.79641: Accuracy:0.88281
# INFO:tensorflow:Step:46500 Reg Loss:0.42433 Train Loss:1.04866: Accuracy:0.83203
# INFO:tensorflow:Step:46687 Valid Loss:0.95205 Valid Accuracy:0.82332
# INFO:tensorflow:Epoch:75 Time taken:58.22s
# INFO:tensorflow:Step:46750 Reg Loss:0.42344 Train Loss:0.64194: Accuracy:0.91406
# INFO:tensorflow:Step:47000 Reg Loss:0.42216 Train Loss:1.12036: Accuracy:0.83203
# INFO:tensorflow:Step:47250 Reg Loss:0.42546 Train Loss:1.06606: Accuracy:0.82812
# INFO:tensorflow:Step:47309 Valid Loss:0.97462 Valid Accuracy:0.82656
# INFO:tensorflow:Epoch:76 Time taken:58.08s
# INFO:tensorflow:Step:47500 Reg Loss:0.41882 Train Loss:0.76190: Accuracy:0.86719
# INFO:tensorflow:Step:47750 Reg Loss:0.42695 Train Loss:0.93389: Accuracy:0.84766
# INFO:tensorflow:Step:47932 Valid Loss:1.05619 Valid Accuracy:0.79017
# INFO:tensorflow:Epoch:77 Time taken:58.18s
# INFO:tensorflow:Step:48000 Reg Loss:0.42301 Train Loss:0.62750: Accuracy:0.94531
# INFO:tensorflow:Step:48250 Reg Loss:0.42388 Train Loss:0.91671: Accuracy:0.90234
# INFO:tensorflow:Step:48500 Reg Loss:0.42591 Train Loss:0.89326: Accuracy:0.88281
# INFO:tensorflow:Step:48554 Valid Loss:1.03358 Valid Accuracy:0.80114
# INFO:tensorflow:Epoch:78 Time taken:58.06s
# INFO:tensorflow:Step:48750 Reg Loss:0.41991 Train Loss:0.70956: Accuracy:0.88281
# INFO:tensorflow:Step:49000 Reg Loss:0.42311 Train Loss:1.02340: Accuracy:0.82812
# INFO:tensorflow:Step:49177 Valid Loss:0.94818 Valid Accuracy:0.81942
# INFO:tensorflow:Epoch:79 Time taken:58.15s
# INFO:tensorflow:Step:49250 Reg Loss:0.42173 Train Loss:0.51310: Accuracy:0.97656
# INFO:tensorflow:Step:49500 Reg Loss:0.42116 Train Loss:0.97065: Accuracy:0.89453
# INFO:tensorflow:Step:49750 Reg Loss:0.42290 Train Loss:1.15247: Accuracy:0.84896
# INFO:tensorflow:Step:49799 Valid Loss:0.86664 Valid Accuracy:0.85064
# INFO:tensorflow:Epoch:80 Time taken:58.40s
# INFO:tensorflow:Step:50000 Reg Loss:0.41819 Train Loss:0.72288: Accuracy:0.86719
# INFO:tensorflow:Step:50250 Reg Loss:0.42258 Train Loss:0.97834: Accuracy:0.83984
# INFO:tensorflow:Step:50422 Valid Loss:0.93476 Valid Accuracy:0.83015
# INFO:tensorflow:Epoch:81 Time taken:58.19s
# INFO:tensorflow:Step:50500 Reg Loss:0.42058 Train Loss:0.74757: Accuracy:0.89062
# INFO:tensorflow:Step:50750 Reg Loss:0.42079 Train Loss:1.09441: Accuracy:0.83203
# INFO:tensorflow:Step:51000 Reg Loss:0.42359 Train Loss:1.12576: Accuracy:0.79167
# INFO:tensorflow:Step:51044 Valid Loss:0.85221 Valid Accuracy:0.85015
# INFO:tensorflow:Epoch:82 Time taken:58.24s
# INFO:tensorflow:Step:51250 Reg Loss:0.41791 Train Loss:0.85990: Accuracy:0.83594
# INFO:tensorflow:Step:51500 Reg Loss:0.42221 Train Loss:1.04264: Accuracy:0.82422
# INFO:tensorflow:Step:51667 Valid Loss:0.96084 Valid Accuracy:0.81972
# INFO:tensorflow:Epoch:83 Time taken:58.23s
# INFO:tensorflow:Step:51750 Reg Loss:0.41840 Train Loss:0.56734: Accuracy:0.93750
# INFO:tensorflow:Step:52000 Reg Loss:0.41655 Train Loss:0.89218: Accuracy:0.87109
# INFO:tensorflow:Step:52250 Reg Loss:0.42178 Train Loss:1.07754: Accuracy:0.84115
# INFO:tensorflow:Step:52289 Valid Loss:0.87988 Valid Accuracy:0.83985
# INFO:tensorflow:Epoch:84 Time taken:58.10s
# INFO:tensorflow:Step:52500 Reg Loss:0.41391 Train Loss:0.70913: Accuracy:0.89844
# INFO:tensorflow:Step:52750 Reg Loss:0.41694 Train Loss:0.97351: Accuracy:0.86719
# INFO:tensorflow:Step:52912 Valid Loss:0.89350 Valid Accuracy:0.84653
# INFO:tensorflow:Epoch:85 Time taken:58.16s
# INFO:tensorflow:Step:53000 Reg Loss:0.41179 Train Loss:0.67236: Accuracy:0.94531
# INFO:tensorflow:Step:53250 Reg Loss:0.41108 Train Loss:0.92225: Accuracy:0.87500
# INFO:tensorflow:Step:53500 Reg Loss:0.41588 Train Loss:1.13244: Accuracy:0.83854
# INFO:tensorflow:Step:53534 Valid Loss:0.82662 Valid Accuracy:0.85959
# INFO:tensorflow:Epoch:86 Time taken:58.55s
# INFO:tensorflow:Step:53750 Reg Loss:0.41042 Train Loss:0.80195: Accuracy:0.84375
# INFO:tensorflow:Step:54000 Reg Loss:0.41295 Train Loss:0.96307: Accuracy:0.83203
# INFO:tensorflow:Step:54157 Valid Loss:0.85415 Valid Accuracy:0.85560
# INFO:tensorflow:Epoch:87 Time taken:58.15s
# INFO:tensorflow:Step:54250 Reg Loss:0.40904 Train Loss:0.55430: Accuracy:0.94531
# INFO:tensorflow:Step:54500 Reg Loss:0.40983 Train Loss:0.85554: Accuracy:0.89453
# INFO:tensorflow:Step:54750 Reg Loss:0.41295 Train Loss:0.88311: Accuracy:0.88542
# INFO:tensorflow:Step:54779 Valid Loss:1.03192 Valid Accuracy:0.80133
# INFO:tensorflow:Epoch:88 Time taken:58.04s
# INFO:tensorflow:Step:55000 Reg Loss:0.40638 Train Loss:0.65171: Accuracy:0.89844
# INFO:tensorflow:Step:55250 Reg Loss:0.41235 Train Loss:1.07135: Accuracy:0.83203
# INFO:tensorflow:Step:55402 Valid Loss:0.90759 Valid Accuracy:0.83298
# INFO:tensorflow:Epoch:89 Time taken:58.17s
# INFO:tensorflow:Step:55500 Reg Loss:0.40584 Train Loss:0.45242: Accuracy:0.97656
# INFO:tensorflow:Step:55750 Reg Loss:0.40790 Train Loss:0.84734: Accuracy:0.90234
# INFO:tensorflow:Step:56000 Reg Loss:0.41048 Train Loss:1.01083: Accuracy:0.86719
# INFO:tensorflow:Step:56024 Valid Loss:0.90144 Valid Accuracy:0.84129
# INFO:tensorflow:Epoch:90 Time taken:59.67s
# INFO:tensorflow:Step:56250 Reg Loss:0.39866 Train Loss:0.67989: Accuracy:0.87500
# INFO:tensorflow:Step:56500 Reg Loss:0.40369 Train Loss:0.88930: Accuracy:0.85938
# INFO:tensorflow:Step:56647 Valid Loss:0.81927 Valid Accuracy:0.86223
# INFO:tensorflow:Epoch:91 Time taken:59.41s
# INFO:tensorflow:Step:56750 Reg Loss:0.39761 Train Loss:0.48474: Accuracy:0.96875
# INFO:tensorflow:Step:57000 Reg Loss:0.39766 Train Loss:0.83037: Accuracy:0.91406
# INFO:tensorflow:Step:57250 Reg Loss:0.40070 Train Loss:0.95947: Accuracy:0.87500
# INFO:tensorflow:Step:57269 Valid Loss:0.80799 Valid Accuracy:0.86133
# INFO:tensorflow:Epoch:92 Time taken:58.35s
# INFO:tensorflow:Step:57500 Reg Loss:0.39314 Train Loss:0.72503: Accuracy:0.89062
# INFO:tensorflow:Step:57750 Reg Loss:0.39812 Train Loss:0.93682: Accuracy:0.85547
# INFO:tensorflow:Step:57892 Valid Loss:0.82998 Valid Accuracy:0.85833
# INFO:tensorflow:Epoch:93 Time taken:58.88s
# INFO:tensorflow:Step:58000 Reg Loss:0.39113 Train Loss:0.48525: Accuracy:0.94531
# INFO:tensorflow:Step:58250 Reg Loss:0.39359 Train Loss:0.88074: Accuracy:0.89453
# INFO:tensorflow:Step:58500 Reg Loss:0.39645 Train Loss:0.87216: Accuracy:0.86719
# INFO:tensorflow:Step:58514 Valid Loss:0.84566 Valid Accuracy:0.84707
# INFO:tensorflow:Epoch:94 Time taken:58.10s
# INFO:tensorflow:Step:58750 Reg Loss:0.38905 Train Loss:0.71888: Accuracy:0.89844
# INFO:tensorflow:Step:59000 Reg Loss:0.39113 Train Loss:0.88134: Accuracy:0.87109
# INFO:tensorflow:Step:59137 Valid Loss:0.76890 Valid Accuracy:0.87363
# INFO:tensorflow:Epoch:95 Time taken:58.68s
# INFO:tensorflow:Step:59250 Reg Loss:0.38409 Train Loss:0.45598: Accuracy:0.98438
# INFO:tensorflow:Step:59500 Reg Loss:0.38717 Train Loss:0.79856: Accuracy:0.91016
# INFO:tensorflow:Step:59750 Reg Loss:0.38930 Train Loss:1.08760: Accuracy:0.86458
# INFO:tensorflow:Step:59759 Valid Loss:0.79543 Valid Accuracy:0.86065
# INFO:tensorflow:Epoch:96 Time taken:58.14s
# INFO:tensorflow:Step:60000 Reg Loss:0.38106 Train Loss:0.69738: Accuracy:0.88281
# INFO:tensorflow:Step:60250 Reg Loss:0.38363 Train Loss:0.79575: Accuracy:0.87891
# INFO:tensorflow:Step:60382 Valid Loss:0.74428 Valid Accuracy:0.87793
# INFO:tensorflow:Epoch:97 Time taken:58.73s
# INFO:tensorflow:Step:60500 Reg Loss:0.37640 Train Loss:0.51462: Accuracy:0.94531
# INFO:tensorflow:Step:60750 Reg Loss:0.37887 Train Loss:0.85886: Accuracy:0.89062
# INFO:tensorflow:Step:61000 Reg Loss:0.38188 Train Loss:0.84852: Accuracy:0.87760
# INFO:tensorflow:Step:61004 Valid Loss:0.76544 Valid Accuracy:0.87375
# INFO:tensorflow:Epoch:98 Time taken:58.81s
# INFO:tensorflow:Step:61250 Reg Loss:0.37513 Train Loss:0.67111: Accuracy:0.91406
# INFO:tensorflow:Step:61500 Reg Loss:0.37869 Train Loss:0.72795: Accuracy:0.89453
# INFO:tensorflow:Step:61627 Valid Loss:0.79753 Valid Accuracy:0.86554
# INFO:tensorflow:Epoch:99 Time taken:58.64s
# INFO:tensorflow:Step:61750 Reg Loss:0.36913 Train Loss:0.42459: Accuracy:0.97656
# INFO:tensorflow:Step:62000 Reg Loss:0.37051 Train Loss:0.95128: Accuracy:0.89453
# INFO:tensorflow:Step:62250 Valid Loss:0.79433 Valid Accuracy:0.85979
# INFO:tensorflow:Epoch:100 Time taken:58.34s
# INFO:tensorflow:Step:62500 Reg Loss:0.36255 Train Loss:0.64414: Accuracy:0.89844
# INFO:tensorflow:Step:62750 Reg Loss:0.36723 Train Loss:0.83177: Accuracy:0.88672
# INFO:tensorflow:Step:62873 Valid Loss:0.74364 Valid Accuracy:0.87598
# INFO:tensorflow:Epoch:101 Time taken:58.18s
# INFO:tensorflow:Step:63000 Reg Loss:0.35808 Train Loss:0.40476: Accuracy:0.97656
# INFO:tensorflow:Step:63250 Reg Loss:0.35903 Train Loss:0.81746: Accuracy:0.92188
# INFO:tensorflow:Step:63496 Valid Loss:0.73028 Valid Accuracy:0.87802
# INFO:tensorflow:Epoch:102 Time taken:58.19s
# INFO:tensorflow:Step:63500 Reg Loss:0.36142 Train Loss:0.49663: Accuracy:0.95312
# INFO:tensorflow:Step:63750 Reg Loss:0.35223 Train Loss:0.68759: Accuracy:0.91797
# INFO:tensorflow:Step:64000 Reg Loss:0.35696 Train Loss:0.83196: Accuracy:0.89583
# INFO:tensorflow:Step:64118 Valid Loss:0.71607 Valid Accuracy:0.87702
# INFO:tensorflow:Epoch:103 Time taken:58.80s
# INFO:tensorflow:Step:64250 Reg Loss:0.34776 Train Loss:0.43643: Accuracy:0.97656
# INFO:tensorflow:Step:64500 Reg Loss:0.35012 Train Loss:0.74148: Accuracy:0.91797
# INFO:tensorflow:Step:64741 Valid Loss:0.69422 Valid Accuracy:0.88690
# INFO:tensorflow:Epoch:104 Time taken:60.36s
# INFO:tensorflow:Step:64750 Reg Loss:0.35232 Train Loss:0.50455: Accuracy:0.95312
# INFO:tensorflow:Step:65000 Reg Loss:0.34216 Train Loss:0.54022: Accuracy:0.93359
# INFO:tensorflow:Step:65250 Reg Loss:0.34641 Train Loss:0.70298: Accuracy:0.90625
# INFO:tensorflow:Step:65363 Valid Loss:0.67427 Valid Accuracy:0.89282
# INFO:tensorflow:Epoch:105 Time taken:60.76s
# INFO:tensorflow:Step:65500 Reg Loss:0.33658 Train Loss:0.38227: Accuracy:0.99219
# INFO:tensorflow:Step:65750 Reg Loss:0.33686 Train Loss:0.68310: Accuracy:0.92969
# INFO:tensorflow:Step:65986 Valid Loss:0.69487 Valid Accuracy:0.88456
# INFO:tensorflow:Epoch:106 Time taken:63.32s
# INFO:tensorflow:Step:66000 Reg Loss:0.33929 Train Loss:0.40514: Accuracy:0.98438
# INFO:tensorflow:Step:66250 Reg Loss:0.32991 Train Loss:0.62584: Accuracy:0.94141
# INFO:tensorflow:Step:66500 Reg Loss:0.33414 Train Loss:0.81631: Accuracy:0.89583
# INFO:tensorflow:Step:66608 Valid Loss:0.70582 Valid Accuracy:0.87933
# INFO:tensorflow:Epoch:107 Time taken:63.89s
# INFO:tensorflow:Step:66750 Reg Loss:0.32559 Train Loss:0.35494: Accuracy:0.99219
# INFO:tensorflow:Step:67000 Reg Loss:0.32617 Train Loss:0.75001: Accuracy:0.91406
# INFO:tensorflow:Step:67231 Valid Loss:0.66422 Valid Accuracy:0.89031
# INFO:tensorflow:Epoch:108 Time taken:64.23s
# INFO:tensorflow:Step:67250 Reg Loss:0.32804 Train Loss:0.35303: Accuracy:1.00000
# INFO:tensorflow:Step:67500 Reg Loss:0.31753 Train Loss:0.52964: Accuracy:0.94922
# INFO:tensorflow:Step:67750 Reg Loss:0.32153 Train Loss:0.80341: Accuracy:0.89323
# INFO:tensorflow:Step:67853 Valid Loss:0.65585 Valid Accuracy:0.88530
# INFO:tensorflow:Epoch:109 Time taken:61.47s
# INFO:tensorflow:Step:68000 Reg Loss:0.31326 Train Loss:0.33234: Accuracy:0.99219
# INFO:tensorflow:Step:68250 Reg Loss:0.31412 Train Loss:0.70311: Accuracy:0.92578
# INFO:tensorflow:Step:68476 Valid Loss:0.63542 Valid Accuracy:0.89080
# INFO:tensorflow:Epoch:110 Time taken:64.45s
# INFO:tensorflow:Step:68500 Reg Loss:0.31578 Train Loss:0.38235: Accuracy:0.98438
# INFO:tensorflow:Step:68750 Reg Loss:0.30564 Train Loss:0.50721: Accuracy:0.95703
# INFO:tensorflow:Step:69000 Reg Loss:0.30900 Train Loss:0.80992: Accuracy:0.91927
# INFO:tensorflow:Step:69098 Valid Loss:0.62844 Valid Accuracy:0.89773
# INFO:tensorflow:Epoch:111 Time taken:62.99s
# INFO:tensorflow:Step:69250 Reg Loss:0.30085 Train Loss:0.32333: Accuracy:0.99219
# INFO:tensorflow:Step:69500 Reg Loss:0.30119 Train Loss:0.75987: Accuracy:0.93359
# INFO:tensorflow:Step:69721 Valid Loss:0.61905 Valid Accuracy:0.89752
# INFO:tensorflow:Epoch:112 Time taken:59.93s
# INFO:tensorflow:Step:69750 Reg Loss:0.30224 Train Loss:0.34635: Accuracy:0.99219
# INFO:tensorflow:Step:70000 Reg Loss:0.29241 Train Loss:0.61745: Accuracy:0.95312
# INFO:tensorflow:Step:70250 Reg Loss:0.29576 Train Loss:0.73424: Accuracy:0.92188
# INFO:tensorflow:Step:70343 Valid Loss:0.69435 Valid Accuracy:0.87972
# INFO:tensorflow:Epoch:113 Time taken:62.94s
# INFO:tensorflow:Step:70500 Reg Loss:0.28858 Train Loss:0.29440: Accuracy:1.00000
# INFO:tensorflow:Step:70750 Reg Loss:0.28911 Train Loss:0.53407: Accuracy:0.96484
# INFO:tensorflow:Step:70966 Valid Loss:0.62473 Valid Accuracy:0.89343
# INFO:tensorflow:Epoch:114 Time taken:62.34s
# INFO:tensorflow:Step:71000 Reg Loss:0.28992 Train Loss:0.31424: Accuracy:0.99219
# INFO:tensorflow:Step:71250 Reg Loss:0.28091 Train Loss:0.52555: Accuracy:0.95703
# INFO:tensorflow:Step:71500 Reg Loss:0.28374 Train Loss:0.59234: Accuracy:0.93490
# INFO:tensorflow:Step:71588 Valid Loss:0.58313 Valid Accuracy:0.90293
# INFO:tensorflow:Epoch:115 Time taken:61.00s
# INFO:tensorflow:Step:71750 Reg Loss:0.27705 Train Loss:0.28862: Accuracy:1.00000
# INFO:tensorflow:Step:72000 Reg Loss:0.27624 Train Loss:0.62346: Accuracy:0.94922
# INFO:tensorflow:Step:72211 Valid Loss:0.57802 Valid Accuracy:0.90386
# INFO:tensorflow:Epoch:116 Time taken:59.82s
# INFO:tensorflow:Step:72250 Reg Loss:0.27620 Train Loss:0.29054: Accuracy:1.00000
# INFO:tensorflow:Step:72500 Reg Loss:0.26874 Train Loss:0.65323: Accuracy:0.94141
# INFO:tensorflow:Step:72750 Reg Loss:0.27035 Train Loss:0.63411: Accuracy:0.91146
# INFO:tensorflow:Step:72833 Valid Loss:0.58549 Valid Accuracy:0.90235
# INFO:tensorflow:Epoch:117 Time taken:59.18s
# INFO:tensorflow:Step:73000 Reg Loss:0.26405 Train Loss:0.27229: Accuracy:1.00000
# INFO:tensorflow:Step:73250 Reg Loss:0.26333 Train Loss:0.64355: Accuracy:0.91406
# INFO:tensorflow:Step:73456 Valid Loss:0.55684 Valid Accuracy:0.90971
# INFO:tensorflow:Epoch:118 Time taken:59.95s
# INFO:tensorflow:Step:73500 Reg Loss:0.26342 Train Loss:0.29170: Accuracy:0.99219
# INFO:tensorflow:Step:73750 Reg Loss:0.25656 Train Loss:0.42406: Accuracy:0.95703
# INFO:tensorflow:Step:74000 Reg Loss:0.25819 Train Loss:0.51899: Accuracy:0.95052
# INFO:tensorflow:Step:74078 Valid Loss:0.55698 Valid Accuracy:0.90620
# INFO:tensorflow:Epoch:119 Time taken:59.02s
# INFO:tensorflow:Step:74250 Reg Loss:0.25227 Train Loss:0.27248: Accuracy:0.99219
# INFO:tensorflow:Step:74500 Reg Loss:0.25086 Train Loss:0.55314: Accuracy:0.93750
# INFO:tensorflow:Step:74701 Valid Loss:0.52512 Valid Accuracy:0.91273
# INFO:tensorflow:Epoch:120 Time taken:58.60s
# INFO:tensorflow:Step:74750 Reg Loss:0.25035 Train Loss:0.28070: Accuracy:0.99219
# INFO:tensorflow:Step:75000 Reg Loss:0.24445 Train Loss:0.39415: Accuracy:0.96875
# INFO:tensorflow:Step:75250 Reg Loss:0.24535 Train Loss:0.59215: Accuracy:0.94271
# INFO:tensorflow:Step:75323 Valid Loss:0.51834 Valid Accuracy:0.91342
# INFO:tensorflow:Epoch:121 Time taken:58.22s
# INFO:tensorflow:Step:75500 Reg Loss:0.24025 Train Loss:0.25769: Accuracy:1.00000
# INFO:tensorflow:Step:75750 Reg Loss:0.23870 Train Loss:0.51932: Accuracy:0.94531
# INFO:tensorflow:Step:75946 Valid Loss:0.51392 Valid Accuracy:0.91429
# INFO:tensorflow:Epoch:122 Time taken:60.11s
# INFO:tensorflow:Step:76000 Reg Loss:0.23793 Train Loss:0.25892: Accuracy:1.00000
# INFO:tensorflow:Step:76250 Reg Loss:0.23297 Train Loss:0.42555: Accuracy:0.96484
# INFO:tensorflow:Step:76500 Reg Loss:0.23309 Train Loss:0.43862: Accuracy:0.95052
# INFO:tensorflow:Step:76568 Valid Loss:0.48550 Valid Accuracy:0.91612
# INFO:tensorflow:Epoch:123 Time taken:60.54s
# INFO:tensorflow:Step:76750 Reg Loss:0.22881 Train Loss:0.25260: Accuracy:0.98438
# INFO:tensorflow:Step:77000 Reg Loss:0.22705 Train Loss:0.48000: Accuracy:0.94531
# INFO:tensorflow:Step:77191 Valid Loss:0.49721 Valid Accuracy:0.91273
# INFO:tensorflow:Epoch:124 Time taken:59.88s
# INFO:tensorflow:Step:77250 Reg Loss:0.22613 Train Loss:0.23952: Accuracy:1.00000
# INFO:tensorflow:Step:77500 Reg Loss:0.22206 Train Loss:0.43474: Accuracy:0.96484
# INFO:tensorflow:Step:77750 Reg Loss:0.22181 Train Loss:0.49812: Accuracy:0.95052
# INFO:tensorflow:Step:77813 Valid Loss:0.48416 Valid Accuracy:0.92479
# INFO:tensorflow:Epoch:125 Time taken:62.59s
# INFO:tensorflow:Step:78000 Reg Loss:0.21821 Train Loss:0.23213: Accuracy:1.00000
# INFO:tensorflow:Step:78250 Reg Loss:0.21659 Train Loss:0.47953: Accuracy:0.96484
# INFO:tensorflow:Step:78436 Valid Loss:0.47240 Valid Accuracy:0.92560
# INFO:tensorflow:Epoch:126 Time taken:61.45s
# INFO:tensorflow:Step:78500 Reg Loss:0.21540 Train Loss:0.22204: Accuracy:1.00000
# INFO:tensorflow:Step:78750 Reg Loss:0.21191 Train Loss:0.31484: Accuracy:0.98438
# INFO:tensorflow:Step:79000 Reg Loss:0.21134 Train Loss:0.42191: Accuracy:0.96094
# INFO:tensorflow:Step:79058 Valid Loss:0.46549 Valid Accuracy:0.92421
# INFO:tensorflow:Epoch:127 Time taken:59.98s
# INFO:tensorflow:Step:79250 Reg Loss:0.20831 Train Loss:0.23898: Accuracy:0.99219
# INFO:tensorflow:Step:79500 Reg Loss:0.20683 Train Loss:0.34676: Accuracy:0.97656
# INFO:tensorflow:Step:79681 Valid Loss:0.49550 Valid Accuracy:0.91566
# INFO:tensorflow:Epoch:128 Time taken:60.59s
# INFO:tensorflow:Step:79750 Reg Loss:0.20565 Train Loss:0.20953: Accuracy:1.00000
# INFO:tensorflow:Step:80000 Reg Loss:0.20287 Train Loss:0.38460: Accuracy:0.97266
# INFO:tensorflow:Step:80250 Reg Loss:0.20199 Train Loss:0.31970: Accuracy:0.97135
# INFO:tensorflow:Step:80303 Valid Loss:0.45796 Valid Accuracy:0.92488
# INFO:tensorflow:Epoch:129 Time taken:59.74s
# INFO:tensorflow:Step:80500 Reg Loss:0.19961 Train Loss:0.24029: Accuracy:0.99219
# INFO:tensorflow:Step:80750 Reg Loss:0.19809 Train Loss:0.39276: Accuracy:0.96875
# INFO:tensorflow:Step:80926 Valid Loss:0.45155 Valid Accuracy:0.92619
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:80926 Test Loss:0.46547 Test Accuracy:0.91880
# INFO:tensorflow:Epoch:130 Time taken:60.55s
# INFO:tensorflow:Step:81000 Reg Loss:0.19672 Train Loss:0.20096: Accuracy:0.91983
# INFO:tensorflow:Step:81250 Reg Loss:0.19459 Train Loss:0.35265: Accuracy:0.92014
# INFO:tensorflow:Step:81500 Reg Loss:0.19362 Train Loss:0.35085: Accuracy:0.92026
# INFO:tensorflow:Step:81548 Valid Loss:0.44124 Valid Accuracy:0.92845
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:81548 Test Loss:0.44390 Test Accuracy:0.92690
# INFO:tensorflow:Epoch:131 Time taken:60.35s
# INFO:tensorflow:Step:81750 Reg Loss:0.19174 Train Loss:0.22834: Accuracy:0.92773
# INFO:tensorflow:Step:82000 Reg Loss:0.19044 Train Loss:0.31856: Accuracy:0.92785
# INFO:tensorflow:Step:82171 Valid Loss:0.44399 Valid Accuracy:0.92843
# INFO:tensorflow:Epoch:132 Time taken:59.63s
# INFO:tensorflow:Step:82250 Reg Loss:0.18933 Train Loss:0.19171: Accuracy:1.00000
# INFO:tensorflow:Step:82500 Reg Loss:0.18773 Train Loss:0.30362: Accuracy:0.98438
# INFO:tensorflow:Step:82750 Reg Loss:0.18684 Train Loss:0.35587: Accuracy:0.97656
# INFO:tensorflow:Step:82793 Valid Loss:0.43497 Valid Accuracy:0.92691
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:82793 Test Loss:0.44629 Test Accuracy:0.92260
# INFO:tensorflow:Epoch:133 Time taken:64.52s
# INFO:tensorflow:Step:83000 Reg Loss:0.18543 Train Loss:0.22192: Accuracy:0.92348
# INFO:tensorflow:Step:83250 Reg Loss:0.18440 Train Loss:0.25806: Accuracy:0.92414
# INFO:tensorflow:Step:83416 Valid Loss:0.42410 Valid Accuracy:0.93097
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:83416 Test Loss:0.42702 Test Accuracy:0.92620
# INFO:tensorflow:Epoch:134 Time taken:65.58s
# INFO:tensorflow:Step:83500 Reg Loss:0.18343 Train Loss:0.18541: Accuracy:0.92713
# INFO:tensorflow:Step:83750 Reg Loss:0.18230 Train Loss:0.23377: Accuracy:0.92794
# INFO:tensorflow:Step:84000 Reg Loss:0.18151 Train Loss:0.28664: Accuracy:0.92835
# INFO:tensorflow:Step:84038 Valid Loss:0.42753 Valid Accuracy:0.93442
# INFO:tensorflow:Epoch:135 Time taken:60.96s
# INFO:tensorflow:Step:84250 Reg Loss:0.18053 Train Loss:0.21460: Accuracy:0.98438
# INFO:tensorflow:Step:84500 Reg Loss:0.17975 Train Loss:0.32469: Accuracy:0.96875
# INFO:tensorflow:Step:84661 Valid Loss:0.41809 Valid Accuracy:0.93399
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:84661 Test Loss:0.42628 Test Accuracy:0.92650
# INFO:tensorflow:Epoch:136 Time taken:61.98s
# INFO:tensorflow:Step:84750 Reg Loss:0.17901 Train Loss:0.18016: Accuracy:0.92743
# INFO:tensorflow:Step:85000 Reg Loss:0.17828 Train Loss:0.26768: Accuracy:0.92785
# INFO:tensorflow:Step:85250 Reg Loss:0.17770 Train Loss:0.31045: Accuracy:0.92826
# INFO:tensorflow:Step:85283 Valid Loss:0.41174 Valid Accuracy:0.93692
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:85283 Test Loss:0.41794 Test Accuracy:0.92920
# INFO:tensorflow:Epoch:137 Time taken:63.49s
# INFO:tensorflow:Step:85500 Reg Loss:0.17708 Train Loss:0.20085: Accuracy:0.93000
# INFO:tensorflow:Step:85750 Reg Loss:0.17658 Train Loss:0.33232: Accuracy:0.93028
# INFO:tensorflow:Step:85906 Valid Loss:0.40688 Valid Accuracy:0.93760
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:85906 Test Loss:0.41270 Test Accuracy:0.93060
# INFO:tensorflow:Epoch:138 Time taken:66.24s
# INFO:tensorflow:Step:86000 Reg Loss:0.17612 Train Loss:0.17774: Accuracy:0.93148
# INFO:tensorflow:Step:86250 Reg Loss:0.17569 Train Loss:0.22850: Accuracy:0.93204
# INFO:tensorflow:Step:86500 Reg Loss:0.17534 Train Loss:0.32127: Accuracy:0.93230
# INFO:tensorflow:Step:86528 Valid Loss:0.40356 Valid Accuracy:0.93856
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:86528 Test Loss:0.40898 Test Accuracy:0.93130
# INFO:tensorflow:Epoch:139 Time taken:63.88s
# INFO:tensorflow:Step:86750 Reg Loss:0.17501 Train Loss:0.19976: Accuracy:0.93197
# INFO:tensorflow:Step:87000 Reg Loss:0.17473 Train Loss:0.22969: Accuracy:0.93253
# INFO:tensorflow:Step:87151 Valid Loss:0.40376 Valid Accuracy:0.93672
# INFO:tensorflow:Epoch:140 Time taken:58.39s
# ...
# INFO:tensorflow:Epoch:150 Time taken:58.75s
# INFO:tensorflow:Step:93500 Reg Loss:0.43520 Train Loss:0.75745: Accuracy:0.87500
# INFO:tensorflow:Step:93750 Reg Loss:0.43972 Train Loss:0.99833: Accuracy:0.84766
# INFO:tensorflow:Step:93999 Valid Loss:0.99498 Valid Accuracy:0.82040
# INFO:tensorflow:Epoch:151 Time taken:59.26s
# INFO:tensorflow:Step:94000 Reg Loss:0.44908 Train Loss:0.85045: Accuracy:0.87500
# INFO:tensorflow:Step:94250 Reg Loss:0.44331 Train Loss:0.93677: Accuracy:0.84375
# INFO:tensorflow:Step:94500 Reg Loss:0.45297 Train Loss:1.02950: Accuracy:0.83073
# INFO:tensorflow:Step:94621 Valid Loss:0.93464 Valid Accuracy:0.83946
# INFO:tensorflow:Epoch:152 Time taken:58.76s
# INFO:tensorflow:Step:94750 Reg Loss:0.45382 Train Loss:0.75018: Accuracy:0.89062
# INFO:tensorflow:Step:95000 Reg Loss:0.46181 Train Loss:1.04833: Accuracy:0.83984
# INFO:tensorflow:Step:95244 Valid Loss:1.14462 Valid Accuracy:0.77847
# INFO:tensorflow:Epoch:153 Time taken:58.24s
# INFO:tensorflow:Step:95250 Reg Loss:0.46849 Train Loss:0.74139: Accuracy:0.90625
# INFO:tensorflow:Step:95500 Reg Loss:0.46462 Train Loss:1.04119: Accuracy:0.84766
# INFO:tensorflow:Step:95750 Reg Loss:0.47113 Train Loss:1.13412: Accuracy:0.82292
# INFO:tensorflow:Step:95866 Valid Loss:0.95946 Valid Accuracy:0.83388
# INFO:tensorflow:Epoch:154 Time taken:58.14s
# INFO:tensorflow:Step:96000 Reg Loss:0.46767 Train Loss:0.76259: Accuracy:0.90625
# INFO:tensorflow:Step:96250 Reg Loss:0.46931 Train Loss:1.09470: Accuracy:0.85547
# INFO:tensorflow:Step:96489 Valid Loss:1.08338 Valid Accuracy:0.79622
# INFO:tensorflow:Epoch:155 Time taken:58.58s
# INFO:tensorflow:Step:96500 Reg Loss:0.47507 Train Loss:0.72861: Accuracy:0.89062
# INFO:tensorflow:Step:96750 Reg Loss:0.47353 Train Loss:1.01486: Accuracy:0.83203
# INFO:tensorflow:Step:97000 Reg Loss:0.47929 Train Loss:1.24096: Accuracy:0.80208
# INFO:tensorflow:Step:97111 Valid Loss:0.98510 Valid Accuracy:0.82492
# INFO:tensorflow:Epoch:156 Time taken:62.16s
# INFO:tensorflow:Step:97250 Reg Loss:0.47463 Train Loss:0.63557: Accuracy:0.93750
# INFO:tensorflow:Step:97500 Reg Loss:0.47842 Train Loss:1.09468: Accuracy:0.87891
# INFO:tensorflow:Step:97734 Valid Loss:0.99087 Valid Accuracy:0.82908
# INFO:tensorflow:Epoch:157 Time taken:60.52s
# INFO:tensorflow:Step:97750 Reg Loss:0.48082 Train Loss:0.70944: Accuracy:0.92969
# INFO:tensorflow:Step:98000 Reg Loss:0.47189 Train Loss:1.04222: Accuracy:0.87500
# INFO:tensorflow:Step:98250 Reg Loss:0.47921 Train Loss:1.03338: Accuracy:0.84896
# INFO:tensorflow:Step:98356 Valid Loss:1.07042 Valid Accuracy:0.80759
# INFO:tensorflow:Epoch:158 Time taken:59.03s
# INFO:tensorflow:Step:98500 Reg Loss:0.47373 Train Loss:0.67058: Accuracy:0.94531
# INFO:tensorflow:Step:98750 Reg Loss:0.47879 Train Loss:1.14223: Accuracy:0.84375
# INFO:tensorflow:Step:98979 Valid Loss:1.08544 Valid Accuracy:0.80216
# INFO:tensorflow:Epoch:159 Time taken:59.21s
# INFO:tensorflow:Step:99000 Reg Loss:0.48469 Train Loss:0.73070: Accuracy:0.91406
# INFO:tensorflow:Step:99250 Reg Loss:0.47716 Train Loss:0.90170: Accuracy:0.89062
# INFO:tensorflow:Step:99500 Reg Loss:0.48543 Train Loss:1.17202: Accuracy:0.85938
# INFO:tensorflow:Step:99601 Valid Loss:1.13777 Valid Accuracy:0.79690
# INFO:tensorflow:Epoch:160 Time taken:58.78s
# INFO:tensorflow:Step:99750 Reg Loss:0.47920 Train Loss:0.70899: Accuracy:0.92969
# INFO:tensorflow:Step:100000 Reg Loss:0.48566 Train Loss:1.22392: Accuracy:0.82812
# INFO:tensorflow:Step:100224 Valid Loss:1.04464 Valid Accuracy:0.81133
# INFO:tensorflow:Epoch:161 Time taken:58.37s
# INFO:tensorflow:Step:100250 Reg Loss:0.48533 Train Loss:0.78089: Accuracy:0.89062
# INFO:tensorflow:Step:100500 Reg Loss:0.48087 Train Loss:0.99936: Accuracy:0.84766
# INFO:tensorflow:Step:100750 Reg Loss:0.48590 Train Loss:1.11774: Accuracy:0.82552
# INFO:tensorflow:Step:100846 Valid Loss:1.00658 Valid Accuracy:0.82617
# INFO:tensorflow:Epoch:162 Time taken:58.57s
# INFO:tensorflow:Step:101000 Reg Loss:0.48060 Train Loss:0.59624: Accuracy:0.96094
# INFO:tensorflow:Step:101250 Reg Loss:0.48279 Train Loss:1.21131: Accuracy:0.85547
# INFO:tensorflow:Step:101469 Valid Loss:0.97309 Valid Accuracy:0.83892
# INFO:tensorflow:Epoch:163 Time taken:63.18s
# INFO:tensorflow:Step:101500 Reg Loss:0.48815 Train Loss:0.61183: Accuracy:0.95312
# INFO:tensorflow:Step:101750 Reg Loss:0.48689 Train Loss:0.89445: Accuracy:0.90625
# INFO:tensorflow:Step:102000 Reg Loss:0.49200 Train Loss:1.28987: Accuracy:0.84115
# INFO:tensorflow:Step:102091 Valid Loss:1.28568 Valid Accuracy:0.74114
# INFO:tensorflow:Epoch:164 Time taken:60.10s
# INFO:tensorflow:Step:102250 Reg Loss:0.48395 Train Loss:0.68532: Accuracy:0.92188
# INFO:tensorflow:Step:102500 Reg Loss:0.48866 Train Loss:1.10880: Accuracy:0.86328
# INFO:tensorflow:Step:102714 Valid Loss:0.92740 Valid Accuracy:0.85267
# INFO:tensorflow:Epoch:165 Time taken:60.47s
# INFO:tensorflow:Step:102750 Reg Loss:0.48812 Train Loss:0.72335: Accuracy:0.90625
# INFO:tensorflow:Step:103000 Reg Loss:0.48678 Train Loss:0.99587: Accuracy:0.87500
# INFO:tensorflow:Step:103250 Reg Loss:0.49163 Train Loss:1.23184: Accuracy:0.80990
# INFO:tensorflow:Step:103336 Valid Loss:1.06548 Valid Accuracy:0.81240
# INFO:tensorflow:Epoch:166 Time taken:63.12s
# INFO:tensorflow:Step:103500 Reg Loss:0.48338 Train Loss:0.90060: Accuracy:0.85938
# INFO:tensorflow:Step:103750 Reg Loss:0.48989 Train Loss:1.17854: Accuracy:0.81641
# INFO:tensorflow:Step:103959 Valid Loss:1.08689 Valid Accuracy:0.80577
# INFO:tensorflow:Epoch:167 Time taken:59.06s
# INFO:tensorflow:Step:104000 Reg Loss:0.49227 Train Loss:0.77611: Accuracy:0.89844
# INFO:tensorflow:Step:104250 Reg Loss:0.49215 Train Loss:1.21027: Accuracy:0.80859
# INFO:tensorflow:Step:104500 Reg Loss:0.49853 Train Loss:1.22296: Accuracy:0.79688
# INFO:tensorflow:Step:104581 Valid Loss:1.00934 Valid Accuracy:0.82849
# INFO:tensorflow:Epoch:168 Time taken:58.56s
# INFO:tensorflow:Step:104750 Reg Loss:0.48683 Train Loss:0.73292: Accuracy:0.92969
# INFO:tensorflow:Step:105000 Reg Loss:0.49375 Train Loss:1.00988: Accuracy:0.87500
# INFO:tensorflow:Step:105204 Valid Loss:0.94990 Valid Accuracy:0.84848
# INFO:tensorflow:Epoch:169 Time taken:58.61s
# INFO:tensorflow:Step:105250 Reg Loss:0.49337 Train Loss:0.70976: Accuracy:0.90625
# INFO:tensorflow:Step:105500 Reg Loss:0.49049 Train Loss:1.00149: Accuracy:0.86719
# INFO:tensorflow:Step:105750 Reg Loss:0.49644 Train Loss:1.18839: Accuracy:0.83854
# INFO:tensorflow:Step:105826 Valid Loss:1.01382 Valid Accuracy:0.82772
# INFO:tensorflow:Epoch:170 Time taken:58.17s
# INFO:tensorflow:Step:106000 Reg Loss:0.49024 Train Loss:0.85380: Accuracy:0.88281
# INFO:tensorflow:Step:106250 Reg Loss:0.49611 Train Loss:1.16810: Accuracy:0.82031
# INFO:tensorflow:Step:106449 Valid Loss:1.02509 Valid Accuracy:0.81972
# INFO:tensorflow:Epoch:171 Time taken:58.26s
# INFO:tensorflow:Step:106500 Reg Loss:0.49472 Train Loss:0.79694: Accuracy:0.89062
# INFO:tensorflow:Step:106750 Reg Loss:0.49091 Train Loss:1.00268: Accuracy:0.85156
# INFO:tensorflow:Step:107000 Reg Loss:0.49710 Train Loss:1.05323: Accuracy:0.82552
# INFO:tensorflow:Step:107071 Valid Loss:1.09706 Valid Accuracy:0.79391
# INFO:tensorflow:Epoch:172 Time taken:58.20s
# INFO:tensorflow:Step:107250 Reg Loss:0.49408 Train Loss:0.80664: Accuracy:0.89062
# INFO:tensorflow:Step:107500 Reg Loss:0.50157 Train Loss:1.23365: Accuracy:0.80859
# INFO:tensorflow:Step:107694 Valid Loss:1.04398 Valid Accuracy:0.81718
# INFO:tensorflow:Epoch:173 Time taken:58.27s
# INFO:tensorflow:Step:107750 Reg Loss:0.49628 Train Loss:0.60313: Accuracy:0.97656
# INFO:tensorflow:Step:108000 Reg Loss:0.49356 Train Loss:1.08057: Accuracy:0.89844
# INFO:tensorflow:Step:108250 Reg Loss:0.49821 Train Loss:1.08678: Accuracy:0.85677
# INFO:tensorflow:Step:108316 Valid Loss:1.01471 Valid Accuracy:0.82810
# INFO:tensorflow:Epoch:174 Time taken:59.50s
# INFO:tensorflow:Step:108500 Reg Loss:0.48825 Train Loss:0.81464: Accuracy:0.88281
# INFO:tensorflow:Step:108750 Reg Loss:0.49582 Train Loss:1.18812: Accuracy:0.83203
# INFO:tensorflow:Step:108939 Valid Loss:1.13175 Valid Accuracy:0.79924
# INFO:tensorflow:Epoch:175 Time taken:58.45s
# INFO:tensorflow:Step:109000 Reg Loss:0.49592 Train Loss:0.71756: Accuracy:0.92969
# INFO:tensorflow:Step:109250 Reg Loss:0.49642 Train Loss:1.02749: Accuracy:0.87109
# INFO:tensorflow:Step:109500 Reg Loss:0.50087 Train Loss:1.17547: Accuracy:0.82812
# INFO:tensorflow:Step:109561 Valid Loss:0.99509 Valid Accuracy:0.83648
# INFO:tensorflow:Epoch:176 Time taken:58.34s
# INFO:tensorflow:Step:109750 Reg Loss:0.49238 Train Loss:0.77132: Accuracy:0.88281
# INFO:tensorflow:Step:110000 Reg Loss:0.49808 Train Loss:1.24795: Accuracy:0.82812
# INFO:tensorflow:Step:110184 Valid Loss:1.17001 Valid Accuracy:0.77506
# INFO:tensorflow:Epoch:177 Time taken:58.42s
# INFO:tensorflow:Step:110250 Reg Loss:0.49591 Train Loss:0.76012: Accuracy:0.90625
# INFO:tensorflow:Step:110500 Reg Loss:0.49681 Train Loss:1.06683: Accuracy:0.86328
# INFO:tensorflow:Step:110750 Reg Loss:0.50189 Train Loss:1.19560: Accuracy:0.83073
# INFO:tensorflow:Step:110806 Valid Loss:1.02126 Valid Accuracy:0.82675
# INFO:tensorflow:Epoch:178 Time taken:58.33s
# INFO:tensorflow:Step:111000 Reg Loss:0.48920 Train Loss:0.79151: Accuracy:0.90625
# INFO:tensorflow:Step:111250 Reg Loss:0.49878 Train Loss:0.98536: Accuracy:0.87109
# INFO:tensorflow:Step:111429 Valid Loss:0.97395 Valid Accuracy:0.84146
# INFO:tensorflow:Epoch:179 Time taken:58.46s
# INFO:tensorflow:Step:111500 Reg Loss:0.49280 Train Loss:0.69670: Accuracy:0.92188
# INFO:tensorflow:Step:111750 Reg Loss:0.49393 Train Loss:1.13636: Accuracy:0.86328
# INFO:tensorflow:Step:112000 Reg Loss:0.50013 Train Loss:1.06337: Accuracy:0.85417
# INFO:tensorflow:Step:112051 Valid Loss:1.04184 Valid Accuracy:0.82502
# INFO:tensorflow:Epoch:180 Time taken:58.35s
# INFO:tensorflow:Step:112250 Reg Loss:0.49178 Train Loss:0.82620: Accuracy:0.90625
# INFO:tensorflow:Step:112500 Reg Loss:0.49849 Train Loss:1.02079: Accuracy:0.85938
# INFO:tensorflow:Step:112674 Valid Loss:1.12761 Valid Accuracy:0.79963
# INFO:tensorflow:Epoch:181 Time taken:58.42s
# INFO:tensorflow:Step:112750 Reg Loss:0.49330 Train Loss:0.70161: Accuracy:0.92969
# INFO:tensorflow:Step:113000 Reg Loss:0.49165 Train Loss:1.05284: Accuracy:0.87109
# INFO:tensorflow:Step:113250 Reg Loss:0.50065 Train Loss:1.01261: Accuracy:0.85417
# INFO:tensorflow:Step:113296 Valid Loss:0.97416 Valid Accuracy:0.84775
# INFO:tensorflow:Epoch:182 Time taken:58.35s
# INFO:tensorflow:Step:113500 Reg Loss:0.49517 Train Loss:0.81348: Accuracy:0.88281
# INFO:tensorflow:Step:113750 Reg Loss:0.49876 Train Loss:1.02007: Accuracy:0.85547
# INFO:tensorflow:Step:113919 Valid Loss:1.04968 Valid Accuracy:0.81669
# INFO:tensorflow:Epoch:183 Time taken:58.44s
# INFO:tensorflow:Step:114000 Reg Loss:0.49668 Train Loss:0.64671: Accuracy:0.94531
# INFO:tensorflow:Step:114250 Reg Loss:0.49414 Train Loss:1.08947: Accuracy:0.87109
# INFO:tensorflow:Step:114500 Reg Loss:0.50116 Train Loss:1.03601: Accuracy:0.86198
# INFO:tensorflow:Step:114541 Valid Loss:1.05237 Valid Accuracy:0.81269
# INFO:tensorflow:Epoch:184 Time taken:58.31s
# INFO:tensorflow:Step:114750 Reg Loss:0.49037 Train Loss:0.73228: Accuracy:0.90625
# INFO:tensorflow:Step:115000 Reg Loss:0.49645 Train Loss:1.01028: Accuracy:0.88672
# INFO:tensorflow:Step:115164 Valid Loss:1.01123 Valid Accuracy:0.82888
# INFO:tensorflow:Epoch:185 Time taken:58.41s
# INFO:tensorflow:Step:115250 Reg Loss:0.49274 Train Loss:0.64365: Accuracy:0.93750
# INFO:tensorflow:Step:115500 Reg Loss:0.49303 Train Loss:1.11638: Accuracy:0.87500
# INFO:tensorflow:Step:115750 Reg Loss:0.50057 Train Loss:1.29233: Accuracy:0.82031
# INFO:tensorflow:Step:115786 Valid Loss:0.93150 Valid Accuracy:0.85468
# INFO:tensorflow:Epoch:186 Time taken:58.35s
# INFO:tensorflow:Step:116000 Reg Loss:0.49086 Train Loss:0.82544: Accuracy:0.88281
# INFO:tensorflow:Step:116250 Reg Loss:0.49539 Train Loss:1.05739: Accuracy:0.82812
# INFO:tensorflow:Step:116409 Valid Loss:1.02030 Valid Accuracy:0.83317
# INFO:tensorflow:Epoch:187 Time taken:58.39s
# INFO:tensorflow:Step:116500 Reg Loss:0.49574 Train Loss:0.71257: Accuracy:0.91406
# INFO:tensorflow:Step:116750 Reg Loss:0.49038 Train Loss:1.06497: Accuracy:0.86328
# INFO:tensorflow:Step:117000 Reg Loss:0.49564 Train Loss:1.13647: Accuracy:0.83854
# INFO:tensorflow:Step:117031 Valid Loss:0.99516 Valid Accuracy:0.83523
# INFO:tensorflow:Epoch:188 Time taken:58.33s
# INFO:tensorflow:Step:117250 Reg Loss:0.48516 Train Loss:0.77468: Accuracy:0.88281
# INFO:tensorflow:Step:117500 Reg Loss:0.49393 Train Loss:1.06125: Accuracy:0.83203
# INFO:tensorflow:Step:117654 Valid Loss:1.04922 Valid Accuracy:0.81708
# INFO:tensorflow:Epoch:189 Time taken:58.40s
# INFO:tensorflow:Step:117750 Reg Loss:0.48815 Train Loss:0.73241: Accuracy:0.92969
# INFO:tensorflow:Step:118000 Reg Loss:0.48854 Train Loss:1.08118: Accuracy:0.87109
# INFO:tensorflow:Step:118250 Reg Loss:0.49689 Train Loss:1.14245: Accuracy:0.84896
# INFO:tensorflow:Step:118276 Valid Loss:0.96799 Valid Accuracy:0.84649
# INFO:tensorflow:Epoch:190 Time taken:58.32s
# INFO:tensorflow:Step:118500 Reg Loss:0.48905 Train Loss:0.88076: Accuracy:0.85156
# INFO:tensorflow:Step:118750 Reg Loss:0.49530 Train Loss:1.13309: Accuracy:0.82812
# INFO:tensorflow:Step:118899 Valid Loss:0.98287 Valid Accuracy:0.83639
# INFO:tensorflow:Epoch:191 Time taken:58.40s
# INFO:tensorflow:Step:119000 Reg Loss:0.49233 Train Loss:0.60695: Accuracy:0.96875
# INFO:tensorflow:Step:119250 Reg Loss:0.49362 Train Loss:1.02759: Accuracy:0.89062
# INFO:tensorflow:Step:119500 Reg Loss:0.49853 Train Loss:1.27326: Accuracy:0.82812
# INFO:tensorflow:Step:119521 Valid Loss:1.00198 Valid Accuracy:0.83272
# INFO:tensorflow:Epoch:192 Time taken:58.39s
# INFO:tensorflow:Step:119750 Reg Loss:0.48998 Train Loss:0.96770: Accuracy:0.83594
# INFO:tensorflow:Step:120000 Reg Loss:0.49610 Train Loss:1.08155: Accuracy:0.80469
# INFO:tensorflow:Step:120144 Valid Loss:1.04463 Valid Accuracy:0.82440
# INFO:tensorflow:Epoch:193 Time taken:58.42s
# INFO:tensorflow:Step:120250 Reg Loss:0.49216 Train Loss:0.77793: Accuracy:0.89062
# INFO:tensorflow:Step:120500 Reg Loss:0.49096 Train Loss:0.88269: Accuracy:0.88281
# INFO:tensorflow:Step:120750 Reg Loss:0.49461 Train Loss:1.08353: Accuracy:0.83854
# INFO:tensorflow:Step:120766 Valid Loss:0.98061 Valid Accuracy:0.83937
# INFO:tensorflow:Epoch:194 Time taken:58.36s
# INFO:tensorflow:Step:121000 Reg Loss:0.48477 Train Loss:0.81795: Accuracy:0.88281
# INFO:tensorflow:Step:121250 Reg Loss:0.49175 Train Loss:1.18987: Accuracy:0.83984
# INFO:tensorflow:Step:121389 Valid Loss:0.96111 Valid Accuracy:0.84263
# INFO:tensorflow:Epoch:195 Time taken:58.44s
# INFO:tensorflow:Step:121500 Reg Loss:0.48770 Train Loss:0.59345: Accuracy:0.97656
# INFO:tensorflow:Step:121750 Reg Loss:0.48997 Train Loss:1.02228: Accuracy:0.90625
# INFO:tensorflow:Step:122000 Reg Loss:0.49314 Train Loss:0.98761: Accuracy:0.86979
# INFO:tensorflow:Step:122011 Valid Loss:1.08603 Valid Accuracy:0.81587
# INFO:tensorflow:Epoch:196 Time taken:58.35s
# INFO:tensorflow:Step:122250 Reg Loss:0.48681 Train Loss:0.88470: Accuracy:0.86719
# INFO:tensorflow:Step:122500 Reg Loss:0.48990 Train Loss:1.08069: Accuracy:0.83594
# INFO:tensorflow:Step:122634 Valid Loss:0.91807 Valid Accuracy:0.86359
# INFO:tensorflow:Epoch:197 Time taken:58.47s
# INFO:tensorflow:Step:122750 Reg Loss:0.48389 Train Loss:0.72394: Accuracy:0.92969
# INFO:tensorflow:Step:123000 Reg Loss:0.48589 Train Loss:1.11456: Accuracy:0.85156
# INFO:tensorflow:Step:123250 Reg Loss:0.48985 Train Loss:1.03419: Accuracy:0.83333
# INFO:tensorflow:Step:123256 Valid Loss:0.93174 Valid Accuracy:0.85430
# INFO:tensorflow:Epoch:198 Time taken:58.43s
# INFO:tensorflow:Step:123500 Reg Loss:0.48055 Train Loss:0.85935: Accuracy:0.86719
# INFO:tensorflow:Step:123750 Reg Loss:0.48808 Train Loss:1.14633: Accuracy:0.84375
# INFO:tensorflow:Step:123879 Valid Loss:0.97024 Valid Accuracy:0.83814
# INFO:tensorflow:Epoch:199 Time taken:58.44s
# INFO:tensorflow:Step:124000 Reg Loss:0.47982 Train Loss:0.67565: Accuracy:0.92969
# INFO:tensorflow:Step:124250 Reg Loss:0.48625 Train Loss:1.08639: Accuracy:0.87500
# INFO:tensorflow:Step:124500 Reg Loss:0.49054 Train Loss:1.15527: Accuracy:0.84896
# INFO:tensorflow:Step:124501 Valid Loss:0.94338 Valid Accuracy:0.84312
# INFO:tensorflow:Step:124501 Test Loss:0.97922 Test Accuracy:0.83970

# %% [markdown]
# The best model was saved at *epoch 143* and the corresponding **Test Accuracy: 0.93230**
#
# > INFO:tensorflow:Epoch:143 Time taken:58.23s
# INFO:tensorflow:Step:89250 Reg Loss:0.17370 Train Loss:0.21408: Accuracy:0.99219
# INFO:tensorflow:Step:89500 Reg Loss:0.17369 Train Loss:0.25064: Accuracy:0.98438
# INFO:tensorflow:Step:89641 Valid Loss:0.40154 Valid Accuracy:0.93857
# INFO:tensorflow:Saving the model...
# INFO:tensorflow:Step:89641 Test Loss:0.40572 Test Accuracy:0.93230
